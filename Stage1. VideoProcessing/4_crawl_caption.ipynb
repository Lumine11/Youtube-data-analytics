# %%
import os
from dotenv import load_dotenv
from pathlib import Path

parent_env_path = Path.cwd().parent / ".env"
load_dotenv(dotenv_path=parent_env_path)
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = os.getenv("GOOGLE_APPLICATION_CREDENTIALS")
API_KEY = os.getenv("API_KEY_1")
project_id = os.getenv("PROJECT_ID")

# %%
#connect to BigQuery
from google.cloud import bigquery
from google.cloud import storage
from googleapiclient.discovery import build
import json
from datetime import datetime
import pandas as pd
import time
import StringIO
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api._errors import TranscriptsDisabled, NoTranscriptFound

# %%
#connect to prj_id, dataset_id = 2_cleaned_data, table_id: video_basic_info
client = bigquery.Client(project=project_id)
dataset_id = "2_cleaned_data"
table_id = "video_basic_info"
table_ref = client.dataset(dataset_id).table(table_id)
# Out:
# c:\Users\kt061\anaconda3\envs\min_ds\Lib\site-packages\google\auth\_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
#querry and get the channel_id
query = f"""
(
  SELECT DISTINCT id
  FROM `ytbdataanalyst.2_cleaned_data.video_basic_info`
)
EXCEPT DISTINCT
(
  SELECT DISTINCT id
  FROM `ytbdataanalyst.2_cleaned_data.video_transcript`
)
"""

# %%
# Thực thi truy vấn
query_job = client.query(query)
results = query_job.result()

# Lưu kết quả vào danh sách
video_list = [row.id for row in results]
len(video_list)
# Out:
# 1403

# %%
video_list = video_list[:500]  # Giới hạn danh sách video để tránh quá tải

# %%
def get_transcript_flexible(video_id):
    try:
        transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)

        # Ưu tiên phụ đề tiếng Anh
        try:
            return transcript_list.find_transcript(['en']).fetch(), 'en'
        except:
            pass

        # Nếu không có tiếng Anh, lấy bất kỳ cái nào fetch được
        for transcript in transcript_list:
            try:
                return transcript.fetch(), transcript.language_code
            except:
                continue

    except Exception as e:
        print(f"Không lấy được transcript cho video {video_id}: {e}")
        return None,None

# %%
# 0 to 4000
data = []
start = 0
end = 500
count = start
for v in video_list[start:end]:
    only_text = ''
    transcript,lang = get_transcript_flexible(v)

    if transcript is None:
        print(f"No transcript found for video {v}")
        data.append({'id': v, 'transcript': 'No Transcript', 'lang': 'N/A'})
        count += 1
        continue

    for item in transcript:
        # only_text += item['text'] + ' '
        only_text += item.text + ' '
    
    data.append({'id': v, 'transcript': only_text, 'lang': lang})
    print(f"Video {count}/{len(video_list)}: {v}")
    count += 1

    time.sleep(3)        
    if count % 100 == 0:
        time.sleep(60)  # sleep for 1 minute every 100 videos to avoid hitting API limits
# Out:
# Video 0/500: 5HYnlA8c8LA
# Video 1/500: 7l0G_awxFg0
# Video 2/500: LDOFrBnaS0o
# Không lấy được transcript cho video 7jVKwYQdKww:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=7jVKwYQdKww! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video 7jVKwYQdKww
# Không lấy được transcript cho video d6-clVn269o:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=d6-clVn269o! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video d6-clVn269o
# Video 5/500: udv-dOu4Efg
# Video 6/500: l8Rtx1V4aOo
# Video 7/500: 9s5oqC-UR7k
# Video 8/500: vz8Q0jfcr5Q
# Video 9/500: Dyd_O7goweI
# Video 10/500: mnu-cPgqD_s
# Video 11/500: HfG0_yYTcGI
# Video 12/500: XKae3FgKZnM
# Video 13/500: enxD6-tZ2lg
# Video 14/500: tqJ1eSakEbw
# Video 15/500: mO9z4HRfpbo
# Video 16/500: u76YVqPa9uw
# Video 17/500: _o7GiHIxWUw
# Video 18/500: oeaKoWpTGqg
# Video 19/500: vCVidqrpfUQ
# Không lấy được transcript cho video 1BxPUQ1cLE4:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=1BxPUQ1cLE4! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video 1BxPUQ1cLE4
# Video 21/500: LvC68w9JS4Y
# Video 22/500: 9q_Mnv_YZXQ
# Video 23/500: Ed3kUoFD9tY
# Video 24/500: hWJz8QubHhE
# Không lấy được transcript cho video Vq_sG7E9cyw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Vq_sG7E9cyw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video Vq_sG7E9cyw
# Video 26/500: XEvNnJa99_Q
# Video 27/500: x6jKO6vDrHE
# Video 28/500: PandMH2CqGA
# Video 29/500: xkFkYoHQC1I
# Video 30/500: 51Ihlt5tHeE
# Video 31/500: WNigRYxrP40
# Video 32/500: YM2JhWfTq_8
# Video 33/500: _5XCakt0ycU
# Video 34/500: Oqz2PjPeyi4
# Video 35/500: bZwpXEgG0to
# Không lấy được transcript cho video Y46zXHvUB1s:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Y46zXHvUB1s! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video Y46zXHvUB1s
# Không lấy được transcript cho video E5wVxai2xCk:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=E5wVxai2xCk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video E5wVxai2xCk
# Video 38/500: biAwn7KI2IQ
# Không lấy được transcript cho video DOXJ7s1D6iE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=DOXJ7s1D6iE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video DOXJ7s1D6iE
# Không lấy được transcript cho video WEFlPp1T7JM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=WEFlPp1T7JM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video WEFlPp1T7JM
# Video 41/500: t83chADIFz8
# Video 42/500: FosJ9XbYDvQ
# Không lấy được transcript cho video RpHQWQQN6N4:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=RpHQWQQN6N4! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video RpHQWQQN6N4
# Video 44/500: X6Tj2PT41v8
# Video 45/500: G0uUDjjQR-0
# Video 46/500: 2k_5WS9hwu8
# Video 47/500: iKiElebvNM4
# Video 48/500: ZW6WbpHEwsU
# Video 49/500: fA7bERkgQY0
# Video 50/500: LG2Q6aJ0oTM
# Video 51/500: QLxdFeTrd9E
# Video 52/500: ab4b5gYb9BQ
# Video 53/500: rcFKdG6P_ww
# Video 54/500: 8bNPeIzMmdU
# Video 55/500: IMXPqwdKLxk
# Video 56/500: sYqTFvolmlc
# Video 57/500: Y9PGnWswyGI
# Video 58/500: 9L9vNklbs1g
# Video 59/500: QTdVvuAI_mE
# Video 60/500: fJqh-4bkEkE
# Video 61/500: 21XtbPIujUo
# Video 62/500: anzSxTzXd_4
# Không lấy được transcript cho video PvI5JHb9iPM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=PvI5JHb9iPM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video PvI5JHb9iPM
# Không lấy được transcript cho video XV77dh1ulao:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=XV77dh1ulao! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video XV77dh1ulao
# Không lấy được transcript cho video ZCxC1AtbeNQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ZCxC1AtbeNQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video ZCxC1AtbeNQ
# Không lấy được transcript cho video JBdsznU9ApU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=JBdsznU9ApU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video JBdsznU9ApU
# Không lấy được transcript cho video eDHsPJ9dyDs:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=eDHsPJ9dyDs! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video eDHsPJ9dyDs
# Video 68/500: dCGVNN9FRsE
# Không lấy được transcript cho video LXosuQEOLn0:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=LXosuQEOLn0! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video LXosuQEOLn0
# Video 70/500: sH7QNmF4PCw
# Video 71/500: t0x6WNItdX4
# Không lấy được transcript cho video jHJF3VZ7a4o:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=jHJF3VZ7a4o! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video jHJF3VZ7a4o
# Không lấy được transcript cho video aGSY8UVLZe4:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=aGSY8UVLZe4! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video aGSY8UVLZe4
# Video 74/500: l0U9Sr1i4fc
# Video 75/500: -JnqmgST9c8
# Không lấy được transcript cho video Wwv-CaYh61A:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Wwv-CaYh61A! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video Wwv-CaYh61A
# Không lấy được transcript cho video UQ2jTUA2Yko:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=UQ2jTUA2Yko! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video UQ2jTUA2Yko
# Không lấy được transcript cho video wSgZr-HYKPo:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=wSgZr-HYKPo! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video wSgZr-HYKPo
# Video 79/500: QrhMqT8-Wdg
# Video 80/500: vvnrnky9Sag
# Video 81/500: afASVQXQ0q8
# Không lấy được transcript cho video 8ANVGgZNAbs:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=8ANVGgZNAbs! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video 8ANVGgZNAbs
# Không lấy được transcript cho video FN3P_bPb11c:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=FN3P_bPb11c! This is most likely caused by:
#
# The video is unplayable for the following reason: This video is private
#
# Additional Details:
#  - If the owner of this video has granted you access, please
#  - sign in
#  - .
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video FN3P_bPb11c
# Video 84/500: Tt-ozL2-bmA
# Video 85/500: uzFgDNx2A4A
# Video 86/500: _dEyKmvLEE0
# Video 87/500: I1DbksMZiE8
# Video 88/500: S9G3m7KZKQE
# Video 89/500: xozP9G-iZvg
# Video 90/500: NiUj3FBNpfM
# Video 91/500: 8VtKyn-tQ_8
# Không lấy được transcript cho video 0FgKQdc96k4:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=0FgKQdc96k4! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video 0FgKQdc96k4
# Không lấy được transcript cho video eaYbJW4IllM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=eaYbJW4IllM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video eaYbJW4IllM
# Không lấy được transcript cho video tfttyXlOums:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=tfttyXlOums! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video tfttyXlOums
# Không lấy được transcript cho video LDOvvcRh_DA:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=LDOvvcRh_DA! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video LDOvvcRh_DA
# Video 96/500: R6_3P5wr_fU
# Video 97/500: ZcALwHzYfNg
# Video 98/500: JROuGJeLXPA
# Video 99/500: ZFj3hQfVgCA
# Không lấy được transcript cho video 3xQ6ZHtSRYM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=3xQ6ZHtSRYM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video 3xQ6ZHtSRYM
# Không lấy được transcript cho video 5VUpMZqqb2Q:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=5VUpMZqqb2Q! This is most likely caused by:
#
# The video is unplayable for the following reason: This video is no longer available because the uploader has closed their YouTube account.
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video 5VUpMZqqb2Q
# Không lấy được transcript cho video yul4oKwtwzk:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=yul4oKwtwzk! This is most likely caused by:
#
# The video is unplayable for the following reason: This video is no longer available because the uploader has closed their YouTube account.
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video yul4oKwtwzk
# Không lấy được transcript cho video 4xfTCfQH2aI:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=4xfTCfQH2aI! This is most likely caused by:
#
# The video is unplayable for the following reason: This video is no longer available because the uploader has closed their YouTube account.
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video 4xfTCfQH2aI
# Video 104/500: XJnsOJeZnes
# Video 105/500: 6dqAwh2MCg0
# Không lấy được transcript cho video eNMgNQtIg5E:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=eNMgNQtIg5E! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video eNMgNQtIg5E
# Video 107/500: hECQOZbhPh4
# Video 108/500: wv79sAZdaS4
# Không lấy được transcript cho video uvX_PWqQUTg:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=uvX_PWqQUTg! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video uvX_PWqQUTg
# Video 110/500: A0fnbMZZ1HU
# Video 111/500: iPz5e21hprk
# Video 112/500: DPFENPTi6pE
# Video 113/500: Lw2wa7BiGCQ
# Video 114/500: U3qH3TFeJ7o
# Video 115/500: Gv6Lqo8zeZM
# Không lấy được transcript cho video KgHOdKBRJjE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=KgHOdKBRJjE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video KgHOdKBRJjE
# Video 117/500: qrQZRXeY9_E
# Video 118/500: -BT2JYDrSS0
# Video 119/500: ZwzIqbtRL7Y
# Video 120/500: _ks5nM-ScTE
# Video 121/500: H9M1jZllm80
# Video 122/500: tdLPvMYqL_Q
# Video 123/500: BI_4RY_22qo
# Video 124/500: KkRZ0PfJ06A
# Video 125/500: RDKv4EJOvDw
# Video 126/500: vht3d3YRBh0
# Không lấy được transcript cho video rwI2QTcNY48:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=rwI2QTcNY48! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video rwI2QTcNY48
# Không lấy được transcript cho video 6XAyt0nT15E:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=6XAyt0nT15E! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video 6XAyt0nT15E
# Không lấy được transcript cho video xh3mWYk_-EA:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=xh3mWYk_-EA! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video xh3mWYk_-EA
# Video 130/500: BVg4W7BLW6M
# Video 131/500: tCy1JT1zbvk
# Video 132/500: IEZHegxn-to
# Video 133/500: v2ELPHQF3Lk
# Không lấy được transcript cho video XjM5zV6R2Xw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=XjM5zV6R2Xw! This is most likely caused by:
#
# The video is unplayable for the following reason: This video is no longer available because the YouTube account associated with this video has been terminated.
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video XjM5zV6R2Xw
# Không lấy được transcript cho video SEIzAZxjlBg:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=SEIzAZxjlBg! This is most likely caused by:
#
# The video is unplayable for the following reason: This video is private
#
# Additional Details:
#  - If the owner of this video has granted you access, please
#  - sign in
#  - .
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video SEIzAZxjlBg
# Không lấy được transcript cho video QX98eTsU2HM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=QX98eTsU2HM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video QX98eTsU2HM
# Không lấy được transcript cho video zFxl7oLURDo:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=zFxl7oLURDo! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video zFxl7oLURDo
# Video 138/500: 60plRc8NKas
# Video 139/500: u4_U9lv4WG8
# Video 140/500: UGYi9A_nuvI
# Video 141/500: wSZfaKrTEdg
# Không lấy được transcript cho video ArMa7p86SR8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ArMa7p86SR8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video ArMa7p86SR8
# Video 143/500: rMrq1tRAD0A
# Video 144/500: G_yaHg-PQaI
# Video 145/500: pusrl_Nh0NA
# Video 146/500: ueJ0oEmVsfI
# Video 147/500: M6665mHLmmo
# Video 148/500: rwF-X5STYks
# Video 149/500: WQdDoK0bqnw
# Video 150/500: S57aKZ0mvNQ
# Video 151/500: 5t1nk9sP4Fc
# Không lấy được transcript cho video fZft41M93_U:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=fZft41M93_U! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video fZft41M93_U
# Không lấy được transcript cho video XXUIRkhOhJ8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=XXUIRkhOhJ8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video XXUIRkhOhJ8
# Video 154/500: CMeg7dlnqns
# Video 155/500: PXv-9wgHazw
# Không lấy được transcript cho video ULF0pMQ9iyA:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ULF0pMQ9iyA! This is most likely caused by:
#
# The video is unplayable for the following reason: This video is private
#
# Additional Details:
#  - If the owner of this video has granted you access, please
#  - sign in
#  - .
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video ULF0pMQ9iyA
# Không lấy được transcript cho video ewxwiu7pT2g:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ewxwiu7pT2g! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video ewxwiu7pT2g
# Video 158/500: nZBSoXEFliY
# Video 159/500: gl_kTmrXbCU
# Không lấy được transcript cho video BSh3rFhR43o:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=BSh3rFhR43o! This is most likely caused by:
#
# The video is unplayable for the following reason: This video is no longer available because the YouTube account associated with this video has been terminated.
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video BSh3rFhR43o
# Video 161/500: sR17xLvu-LE
# Video 162/500: MkqI0kbiXmY
# Không lấy được transcript cho video 3XSJMEMSUKA:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=3XSJMEMSUKA! This is most likely caused by:
#
# The video is unplayable for the following reason: This video is no longer available because the YouTube account associated with this video has been terminated.
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video 3XSJMEMSUKA
# Video 164/500: CInIIJQ72-c
# Video 165/500: 43FZAiHOe40
# Video 166/500: KARGSjn3SqQ
# Video 167/500: Y3yD96dVUoQ
# Không lấy được transcript cho video ZQRkTbETzuE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ZQRkTbETzuE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video ZQRkTbETzuE
# Không lấy được transcript cho video ikLpUUQr9Io:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ikLpUUQr9Io! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video ikLpUUQr9Io
# Video 170/500: bNk9Iv5cCTY
# Không lấy được transcript cho video pnWHmFl8-Zg:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=pnWHmFl8-Zg! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video pnWHmFl8-Zg
# Không lấy được transcript cho video mQnTk2ZK0Jw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=mQnTk2ZK0Jw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video mQnTk2ZK0Jw
# Video 173/500: zktptqOyGoU
# Video 174/500: zUHhmiTm3Pw
# Video 175/500: N9aNEntQDnM
# Không lấy được transcript cho video I2ErQrHGWx8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=I2ErQrHGWx8! This is most likely caused by:
#
# The video is unplayable for the following reason: This video has been removed by the uploader
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video I2ErQrHGWx8
# Không lấy được transcript cho video Ahh1tryqeiA:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Ahh1tryqeiA! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video Ahh1tryqeiA
# Video 178/500: BVyRsil7oGI
# Không lấy được transcript cho video -Uz9wSzPjwI:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=-Uz9wSzPjwI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video -Uz9wSzPjwI
# Không lấy được transcript cho video fqdFtA-4wrA:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=fqdFtA-4wrA! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video fqdFtA-4wrA
# Không lấy được transcript cho video 7KhOMyrQyT8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=7KhOMyrQyT8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video 7KhOMyrQyT8
# Không lấy được transcript cho video r6F4atXov0Y:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=r6F4atXov0Y! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video r6F4atXov0Y
# Video 183/500: XrHk8Pe7EQw
# Video 184/500: 07bEBNWHhF0
# Không lấy được transcript cho video gIy3XSMj0cc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=gIy3XSMj0cc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video gIy3XSMj0cc
# Không lấy được transcript cho video dWMzUuMXhMg:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=dWMzUuMXhMg! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video dWMzUuMXhMg
# Không lấy được transcript cho video 3nH-zyX_aDE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=3nH-zyX_aDE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video 3nH-zyX_aDE
# Video 188/500: VB0-YGC72qk
# Video 189/500: 5ROUtomUTsI
# Video 190/500: 1-pYY0W4cfk
# Video 191/500: B26DWutKNeE
# Không lấy được transcript cho video CqtCt8dNY7c:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=CqtCt8dNY7c! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video CqtCt8dNY7c
# Video 193/500: 4HbIfEdsuhg
# Video 194/500: vO9Z5zXSnhk
# Không lấy được transcript cho video 7aH3sBIAi9s:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=7aH3sBIAi9s! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video 7aH3sBIAi9s
# Video 196/500: maXdopJN5vg
# Không lấy được transcript cho video WVrBYUh_6co:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=WVrBYUh_6co! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video WVrBYUh_6co
# Video 198/500: xjghx8tiBNk
# Video 199/500: ZX3xbca-j08
# Video 200/500: zNYOD4untVA
# Video 201/500: O48huA6sSB4
# Video 202/500: iG5GOYce0gA
# Không lấy được transcript cho video EhNMCEyFkn8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=EhNMCEyFkn8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video EhNMCEyFkn8
# Không lấy được transcript cho video AQ2u1nZF9SY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=AQ2u1nZF9SY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video AQ2u1nZF9SY
# ...
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video g2fJshc0jtw
# Video 432/500: dz2n_ci3oyc
# Video 433/500: LT3tDSWjvVk
# Video 434/500: axkVJv8Bwpk
# Video 435/500: yIxM2XlGoyg
# Không lấy được transcript cho video ZJE8sYCWN-U:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ZJE8sYCWN-U! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video ZJE8sYCWN-U
# Không lấy được transcript cho video mxw2PYTt8nc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=mxw2PYTt8nc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video mxw2PYTt8nc
# Video 438/500: QjgXbZZ8YTE
# Video 439/500: _9ihJArJ0Xk
# Video 440/500: T9XfHLLvkTo
# Video 441/500: MVQYtU4Cu7Q
# Không lấy được transcript cho video 91H6S_809KY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=91H6S_809KY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video 91H6S_809KY
# Video 443/500: pncLncrEGQ0
# Không lấy được transcript cho video qu0m6fDQeoM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=qu0m6fDQeoM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video qu0m6fDQeoM
# Video 445/500: w12_0ujVAlw
# Không lấy được transcript cho video JCEMXfL35vA:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=JCEMXfL35vA! This is most likely caused by:
#
# The video is unplayable for the following reason: This video is private
#
# Additional Details:
#  - If the owner of this video has granted you access, please
#  - sign in
#  - .
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video JCEMXfL35vA
# Video 447/500: L_U9aFNdv0k
# Không lấy được transcript cho video 6hNvcLQbwo4:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=6hNvcLQbwo4! This is most likely caused by:
#
# The video is unplayable for the following reason: This video is private
#
# Additional Details:
#  - If the owner of this video has granted you access, please
#  - sign in
#  - .
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video 6hNvcLQbwo4
# Video 449/500: LMCxTNURH8M
# Video 450/500: LnN_jHR7E9k
# Video 451/500: 1xWnrzGuk3Y
# Video 452/500: 2h7k6_xLO_U
# Video 453/500: nm-7buWAorI
# Video 454/500: T8MYwyBLEq0
# Video 455/500: S8CWLrO0OIU
# Video 456/500: evXQ79LrDI8
# Video 457/500: HA5q9u1L7EM
# Video 458/500: yYfg9rEU9_I
# Video 459/500: 4nLh4dxv5pM
# Video 460/500: n7sgy67srTA
# Video 461/500: y3WIXqizHDg
# Video 462/500: Xfein50OwSI
# Video 463/500: Q5_-Guns28Q
# Video 464/500: DGM1XU9uezk
# Video 465/500: rrjZTT6tKdk
# Video 466/500: 0aXMBp1ogSY
# Video 467/500: hpa6lfpvK0g
# Không lấy được transcript cho video QzMos_oV6wA:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=QzMos_oV6wA! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video QzMos_oV6wA
# Video 469/500: wzNwyi50F-M
# Video 470/500: bwQB367sZHI
# Video 471/500: GiOehhZJWCg
# Không lấy được transcript cho video Q34-lZHWWNI:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Q34-lZHWWNI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video Q34-lZHWWNI
# Video 473/500: VfwHxIAtN6k
# Video 474/500: gYCcg9w2_gM
# Video 475/500: zjysX_jB7bs
# Video 476/500: 0lk-lmthp_w
# Không lấy được transcript cho video C4RcmSyJ0z0:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=C4RcmSyJ0z0! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video C4RcmSyJ0z0
# Không lấy được transcript cho video AfjBMHMhvOw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=AfjBMHMhvOw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video AfjBMHMhvOw
# Video 479/500: oHzMkTkFZhg
# Không lấy được transcript cho video lzaBbQKUtAA:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=lzaBbQKUtAA! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video lzaBbQKUtAA
# Video 481/500: a50h4-Aht9Q
# Video 482/500: zSkpMXK0yJE
# Không lấy được transcript cho video uVcBa6NXAbk:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=uVcBa6NXAbk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video uVcBa6NXAbk
# Video 484/500: 7CIi9CUONqM
# Video 485/500: yRMA6vaPUhQ
# Video 486/500: wL07Aujd0qY
# Không lấy được transcript cho video 41ZkOEVtzho:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=41ZkOEVtzho! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video 41ZkOEVtzho
# Không lấy được transcript cho video Hn6Tk4mR9B8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Hn6Tk4mR9B8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video Hn6Tk4mR9B8
# Không lấy được transcript cho video 4hlDndldE14:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=4hlDndldE14! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video 4hlDndldE14
# Không lấy được transcript cho video n-htkbWi1Og:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=n-htkbWi1Og! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video n-htkbWi1Og
# Không lấy được transcript cho video feBOiBzH12c:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=feBOiBzH12c! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video feBOiBzH12c
# Video 492/500: mhqyy8iAtrQ
# Không lấy được transcript cho video nNOpkqfJPlQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=nNOpkqfJPlQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video nNOpkqfJPlQ
# Không lấy được transcript cho video _oDkvUhy_Fc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=_oDkvUhy_Fc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video _oDkvUhy_Fc
# Video 495/500: nrvo5TKns7c
# Video 496/500: CInXqRYfP5M
# Không lấy được transcript cho video c3RAXlYMy9s:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=c3RAXlYMy9s! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video c3RAXlYMy9s
# Không lấy được transcript cho video y0aFor4ety4:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=y0aFor4ety4! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# No transcript found for video y0aFor4ety4
# Video 499/500: QzjcSnIscUE

# %%
#convert to dataframe
df = pd.DataFrame(data)

# %%
df
# Out:
#               id                                         transcript lang
# 0    5HYnlA8c8LA  అందరికీ నమస్కారం వెల్కమ్ బ్యాక్ టు వంశీ భవాని ...   te
# 1    7l0G_awxFg0  అందరికీ నమస్కారం వెల్కమ్ బ్యాక్ టు వంశీ భవాని ...   te
# 2    LDOFrBnaS0o  అందరికీ నమస్కారం వెల్కమ్ బ్యాక్ టు వంశీ భవాని ...   te
# 3    7jVKwYQdKww                                      No Transcript  N/A
# 4    d6-clVn269o                                      No Transcript  N/A
# ..           ...                                                ...  ...
# 495  nrvo5TKns7c  o loucodi está revolucionando o desenvolviment...   pt
# 496  CInXqRYfP5M                                   Ela chega e diz    pt
# 497  c3RAXlYMy9s                                      No Transcript  N/A
# 498  y0aFor4ety4                                      No Transcript  N/A
# 499  QzjcSnIscUE  ông Chín đi chợ Ông nhìn thấy con khỉ Thấy thư...   vi
#
# [500 rows x 3 columns]

# %%
#connect and save script to bigquery
# Load config
dataset_id = "2_cleaned_data"
table_id = 'video_transcript'
table_ref = f"{project_id}.{dataset_id}.{table_id}"
full_dataset_id = f"{project_id}.{dataset_id}"
client = bigquery.Client(project=project_id)
dataset = bigquery.Dataset(full_dataset_id)
# Out:
# c:\Users\kt061\anaconda3\envs\min_ds\Lib\site-packages\google\auth\_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
job_config = bigquery.LoadJobConfig(
    write_disposition=bigquery.WriteDisposition.WRITE_APPEND,  # Use WRITE_TRUNCATE to overwrite
    autodetect=True  # Let BigQuery detect schema from DataFrame
)

job = client.load_table_from_dataframe(df, table_ref, job_config=job_config)
job.result()  # Wait for the job to complete

print(f"✅ Data uploaded to BigQuery table: {table_id}")
# Out:
# c:\Users\kt061\anaconda3\envs\min_ds\Lib\site-packages\google\cloud\bigquery\_pandas_helpers.py:489: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# ✅ Data uploaded to BigQuery table: video_transcript

# %%
# bucket_name = "ytbdata"
# gcs_folder = "1_crawl"
# date_str = datetime.today().strftime("%Y%m%d")
# filename = f"video_transcript_{date_str}.json"
# blob_path = f"{gcs_folder}/video_transcript/{filename}"

# %%
# # --- Chuyển DataFrame thành CSV (nội dung dạng chuỗi) ---
# csv_buffer = StringIO()
# df.to_csv(csv_buffer, index=False, encoding='utf-8-sig')  # utf-8-sig giúp mở trong Excel không lỗi font

# client = storage.Client()
# bucket = client.bucket(bucket_name)
# blob = bucket.blob(blob_path)

# blob.upload_from_string(csv_buffer.getvalue(), content_type="text/csv")
# print(f"✅ Uploaded CSV to: gs://{bucket_name}/{blob_path}")
