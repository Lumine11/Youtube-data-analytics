# %%
import pandas as pd
from google.cloud import bigquery
import os
from langdetect import detect, DetectorFactory
from google.cloud import storage
from dotenv import load_dotenv
from pathlib import Path
from io import StringIO

# %%
DetectorFactory.seed = 0
pd.set_option('display.max_columns', None)

# %%
parent_env_path = Path.cwd().parent / ".env"
load_dotenv(dotenv_path=parent_env_path)
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = os.getenv("GOOGLE_APPLICATION_CREDENTIALS")
project_id = os.getenv("PROJECT_ID")

# %%
client = storage.Client(project=project_id)
bucket = client.bucket("ytbdata")
# Out:
# c:\Users\kt061\anaconda3\envs\min_ds\Lib\site-packages\google\auth\_default.py:76: UserWarning:
#
# Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.

# %%
#list hết các file trong bucket ytbdata/video_detailed_info
blobs = bucket.list_blobs(prefix=r"1_crawl/video_detailed_info/")

list_file = []
for blob in blobs:
    list_file.append(blob.name)
list_file
# Out:
# ['1_crawl/video_detailed_info/video_info_1000.json',
#  '1_crawl/video_detailed_info/video_info_2001.json',
#  '1_crawl/video_detailed_info/video_info_7322.json']

# %%
#đọc dữ liệu từ các file và concatenate lại
df = pd.DataFrame()
for i in range(len(list_file)):
    blob = bucket.blob(list_file[i])
    data = blob.download_as_text()
    df1 = pd.read_json(StringIO(data))
    df = pd.concat([df, df1], ignore_index=True)

# %%
df
# Out:
#                kind                         etag           id  \
# 0     youtube#video  XdTw0tvl3tzaOg9uxWTuOvR556Q  0MQEf_7qk4s
# 1     youtube#video  3mvpUDM9S69VWLeHiMtbQQaPKoU  RZdYlS6zvhY
# 2     youtube#video  Wu3tX7S65HWUyw28UBs71xJmOQM  GRlarIhf1Rw
# 3     youtube#video  y6IlQx3b9ATzJ0voyIEPMAq64XA  MOCPCwGm3Dw
# 4     youtube#video  ArKKKY639fShjmCAi5nbgaGUY5A  ObMnw8woAog
# ...             ...                          ...          ...
# 7315  youtube#video  1dYrmgMdxwUZZjOy5Y7l5x_QAAs  PTJ8yizhoIY
# 7316  youtube#video  sN8mENCPzbSWIkKQp3pfvgNtHu8  npz4RqhMORA
# 7317  youtube#video  tou2zgEBFsZ3wdcNJ0ecax2QWYw  CkNjj5nJbr8
# 7318  youtube#video  O-lPFW7l_Z1wH5RPauWvulKMsLA  hV1JcavDT98
# 7319  youtube#video  qiT9EvCcGh5WvnbnJYuuboZeaCk  si971R_ghg8
#
#                                                 snippet  \
# 0     {'publishedAt': '2024-12-03T17:01:38Z', 'chann...
# 1     {'publishedAt': '2024-12-26T04:53:04Z', 'chann...
# 2     {'publishedAt': '2024-08-17T12:24:50Z', 'chann...
# 3     {'publishedAt': '2025-03-20T13:00:25Z', 'chann...
# 4     {'publishedAt': '2023-05-18T16:08:40Z', 'chann...
# ...                                                 ...
# 7315  {'publishedAt': '2025-04-04T01:37:46Z', 'chann...
# 7316  {'publishedAt': '2024-10-28T05:00:35Z', 'chann...
# 7317  {'publishedAt': '2024-10-16T12:00:01Z', 'chann...
# 7318  {'publishedAt': '2024-01-11T13:49:31Z', 'chann...
# 7319  {'publishedAt': '2025-04-02T06:13:59Z', 'chann...
#
#                                          contentDetails  \
# 0     {'duration': 'PT8S', 'dimension': '2d', 'defin...
# 1     {'duration': 'PT12S', 'dimension': '2d', 'defi...
# 2     {'duration': 'PT18S', 'dimension': '2d', 'defi...
# 3     {'duration': 'PT34S', 'dimension': '2d', 'defi...
# 4     {'duration': 'PT36S', 'dimension': '2d', 'defi...
# ...                                                 ...
# 7315  {'duration': 'PT13M3S', 'dimension': '2d', 'de...
# 7316  {'duration': 'PT3M22S', 'dimension': '2d', 'de...
# 7317  {'duration': 'PT17S', 'dimension': '2d', 'defi...
# 7318  {'duration': 'PT3M7S', 'dimension': '2d', 'def...
# 7319  {'duration': 'PT11S', 'dimension': '2d', 'defi...
#
#                                              statistics
# 0     {'viewCount': '253586', 'likeCount': '14833', ...
# 1     {'viewCount': '35260', 'likeCount': '247', 'fa...
# 2     {'viewCount': '703645', 'likeCount': '31338', ...
# 3     {'viewCount': '19015', 'likeCount': '710', 'fa...
# 4     {'viewCount': '1985707', 'likeCount': '122736'...
# ...                                                 ...
# 7315  {'viewCount': '8903', 'likeCount': '304', 'fav...
# 7316  {'viewCount': '774', 'likeCount': '5', 'favori...
# 7317  {'viewCount': '1292540', 'likeCount': '42376',...
# 7318  {'viewCount': '32', 'likeCount': '0', 'favorit...
# 7319  {'viewCount': '1382297', 'likeCount': '13442',...
#
# [7320 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7320 entries, 0 to 7319
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   kind            7320 non-null   object
#  1   etag            7320 non-null   object
#  2   id              7320 non-null   object
#  3   snippet         7320 non-null   object
#  4   contentDetails  7320 non-null   object
#  5   statistics      7320 non-null   object
# dtypes: object(6)
# memory usage: 343.3+ KB

# %%
df.head()
# Out:
#             kind                         etag           id  \
# 0  youtube#video  XdTw0tvl3tzaOg9uxWTuOvR556Q  0MQEf_7qk4s
# 1  youtube#video  3mvpUDM9S69VWLeHiMtbQQaPKoU  RZdYlS6zvhY
# 2  youtube#video  Wu3tX7S65HWUyw28UBs71xJmOQM  GRlarIhf1Rw
# 3  youtube#video  y6IlQx3b9ATzJ0voyIEPMAq64XA  MOCPCwGm3Dw
# 4  youtube#video  ArKKKY639fShjmCAi5nbgaGUY5A  ObMnw8woAog
#
#                                              snippet  \
# 0  {'publishedAt': '2024-12-03T17:01:38Z', 'chann...
# 1  {'publishedAt': '2024-12-26T04:53:04Z', 'chann...
# 2  {'publishedAt': '2024-08-17T12:24:50Z', 'chann...
# 3  {'publishedAt': '2025-03-20T13:00:25Z', 'chann...
# 4  {'publishedAt': '2023-05-18T16:08:40Z', 'chann...
#
#                                       contentDetails  \
# 0  {'duration': 'PT8S', 'dimension': '2d', 'defin...
# 1  {'duration': 'PT12S', 'dimension': '2d', 'defi...
# 2  {'duration': 'PT18S', 'dimension': '2d', 'defi...
# 3  {'duration': 'PT34S', 'dimension': '2d', 'defi...
# 4  {'duration': 'PT36S', 'dimension': '2d', 'defi...
#
#                                           statistics
# 0  {'viewCount': '253586', 'likeCount': '14833', ...
# 1  {'viewCount': '35260', 'likeCount': '247', 'fa...
# 2  {'viewCount': '703645', 'likeCount': '31338', ...
# 3  {'viewCount': '19015', 'likeCount': '710', 'fa...
# 4  {'viewCount': '1985707', 'likeCount': '122736'...

# %%
df['kind'].value_counts()
# Out:
# kind
# youtube#video    7320
# Name: count, dtype: int64

# %%
def split_json_column(df, column):
    # Convert the JSON string to a dictionary
    df[column] = df[column].apply(lambda x: eval(x) if isinstance(x, str) else x)
    
    # Normalize the JSON column into separate columns
    json_df = pd.json_normalize(df[column])
    
    # Concatenate the new columns with the original DataFrame
    df = pd.concat([df.drop(columns=[column]), json_df], axis=1)
    
    return df

# %%
df = split_json_column(df, 'snippet')
df = split_json_column(df, 'contentDetails')
df = split_json_column(df, 'statistics')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7320 entries, 0 to 7319
# Data columns (total 43 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   kind                        7320 non-null   object
#  1   etag                        7320 non-null   object
#  2   id                          7320 non-null   object
#  3   publishedAt                 7320 non-null   object
#  4   channelId                   7320 non-null   object
#  5   title                       7320 non-null   object
#  6   description                 7320 non-null   object
#  7   channelTitle                7320 non-null   object
#  8   categoryId                  7320 non-null   object
#  9   liveBroadcastContent        7320 non-null   object
#  10  thumbnails.default.url      7320 non-null   object
#  11  thumbnails.default.width    7320 non-null   int64
#  12  thumbnails.default.height   7320 non-null   int64
#  13  thumbnails.medium.url       7320 non-null   object
#  14  thumbnails.medium.width     7320 non-null   int64
#  15  thumbnails.medium.height    7320 non-null   int64
#  16  thumbnails.high.url         7320 non-null   object
#  17  thumbnails.high.width       7320 non-null   int64
#  18  thumbnails.high.height      7320 non-null   int64
#  19  thumbnails.standard.url     7294 non-null   object
#  20  thumbnails.standard.width   7294 non-null   float64
#  21  thumbnails.standard.height  7294 non-null   float64
#  22  thumbnails.maxres.url       7049 non-null   object
#  23  thumbnails.maxres.width     7049 non-null   float64
#  24  thumbnails.maxres.height    7049 non-null   float64
#  25  localized.title             7320 non-null   object
#  26  localized.description       7320 non-null   object
#  27  tags                        4855 non-null   object
#  28  defaultLanguage             2547 non-null   object
#  29  defaultAudioLanguage        5465 non-null   object
#  30  duration                    7314 non-null   object
#  31  dimension                   7320 non-null   object
#  32  definition                  7320 non-null   object
#  33  caption                     7320 non-null   object
#  34  licensedContent             7320 non-null   bool
#  35  projection                  7320 non-null   object
#  36  regionRestriction.blocked   80 non-null     object
#  37  regionRestriction.allowed   6 non-null      object
#  38  contentRating.ytRating      2 non-null      object
#  39  viewCount                   7317 non-null   object
#  40  likeCount                   7066 non-null   object
#  41  favoriteCount               7320 non-null   object
#  42  commentCount                7214 non-null   object
# dtypes: bool(1), float64(4), int64(6), object(32)
# memory usage: 2.4+ MB

# %%
df.head(5)
# Out:
#             kind                         etag           id  \
# 0  youtube#video  XdTw0tvl3tzaOg9uxWTuOvR556Q  0MQEf_7qk4s
# 1  youtube#video  3mvpUDM9S69VWLeHiMtbQQaPKoU  RZdYlS6zvhY
# 2  youtube#video  Wu3tX7S65HWUyw28UBs71xJmOQM  GRlarIhf1Rw
# 3  youtube#video  y6IlQx3b9ATzJ0voyIEPMAq64XA  MOCPCwGm3Dw
# 4  youtube#video  ArKKKY639fShjmCAi5nbgaGUY5A  ObMnw8woAog
#
#             publishedAt                 channelId  \
# 0  2024-12-03T17:01:38Z  UC0xHrJNbxHmFnUP-49WYM-Q
# 1  2024-12-26T04:53:04Z  UC8w4I8t2OpqoOpzzNT1c2dg
# 2  2024-08-17T12:24:50Z  UC0xHrJNbxHmFnUP-49WYM-Q
# 3  2025-03-20T13:00:25Z  UC7geKfz2-IH0rsgRBtHTm0g
# 4  2023-05-18T16:08:40Z  UCPkctgt1mTeJWTGj4tq4dPQ
#
#                                                title  \
# 0  120 mind blowing AI tools #productivity #aitoo...
# 1         PAID vs FREE AI Tools - Best Free AI Tools
# 2  Top 10 designer AI tools #ai #productivity #de...
# 3                3 Best AI tools for market research
# 4                           Best 12 AI Tools in 2023
#
#                                          description        channelTitle  \
# 0                                                               SetupsAI
# 1  PAID vs FREE AI Tools - Best Free AI Tools\nAr...            WebbyFan
# 2                                                               SetupsAI
# 3  Top 3 AI Market Research Tools: Automate Your ...  Learn With Shopify
# 4                                                                LKLogic
#
#   categoryId liveBroadcastContent  \
# 0         22                 none
# 1         26                 none
# 2         22                 none
# 3         27                 none
# 4         27                 none
#
#                            thumbnails.default.url  thumbnails.default.width  \
# 0  https://i.ytimg.com/vi/0MQEf_7qk4s/default.jpg                       120
# 1  https://i.ytimg.com/vi/RZdYlS6zvhY/default.jpg                       120
# 2  https://i.ytimg.com/vi/GRlarIhf1Rw/default.jpg                       120
# 3  https://i.ytimg.com/vi/MOCPCwGm3Dw/default.jpg                       120
# 4  https://i.ytimg.com/vi/ObMnw8woAog/default.jpg                       120
#
#    thumbnails.default.height  \
# 0                         90
# 1                         90
# 2                         90
# 3                         90
# 4                         90
#
#                               thumbnails.medium.url  thumbnails.medium.width  \
# 0  https://i.ytimg.com/vi/0MQEf_7qk4s/mqdefault.jpg                      320
# 1  https://i.ytimg.com/vi/RZdYlS6zvhY/mqdefault.jpg                      320
# 2  https://i.ytimg.com/vi/GRlarIhf1Rw/mqdefault.jpg                      320
# 3  https://i.ytimg.com/vi/MOCPCwGm3Dw/mqdefault.jpg                      320
# 4  https://i.ytimg.com/vi/ObMnw8woAog/mqdefault.jpg                      320
#
#    thumbnails.medium.height                               thumbnails.high.url  \
# 0                       180  https://i.ytimg.com/vi/0MQEf_7qk4s/hqdefault.jpg
# 1                       180  https://i.ytimg.com/vi/RZdYlS6zvhY/hqdefault.jpg
# 2                       180  https://i.ytimg.com/vi/GRlarIhf1Rw/hqdefault.jpg
# 3                       180  https://i.ytimg.com/vi/MOCPCwGm3Dw/hqdefault.jpg
# 4                       180  https://i.ytimg.com/vi/ObMnw8woAog/hqdefault.jpg
#
#    thumbnails.high.width  thumbnails.high.height  \
# 0                    480                     360
# 1                    480                     360
# 2                    480                     360
# 3                    480                     360
# 4                    480                     360
#
#                             thumbnails.standard.url  \
# 0  https://i.ytimg.com/vi/0MQEf_7qk4s/sddefault.jpg
# 1  https://i.ytimg.com/vi/RZdYlS6zvhY/sddefault.jpg
# 2  https://i.ytimg.com/vi/GRlarIhf1Rw/sddefault.jpg
# 3  https://i.ytimg.com/vi/MOCPCwGm3Dw/sddefault.jpg
# 4  https://i.ytimg.com/vi/ObMnw8woAog/sddefault.jpg
#
#    thumbnails.standard.width  thumbnails.standard.height  \
# 0                      640.0                       480.0
# 1                      640.0                       480.0
# 2                      640.0                       480.0
# 3                      640.0                       480.0
# 4                      640.0                       480.0
#
#                                thumbnails.maxres.url  thumbnails.maxres.width  \
# 0  https://i.ytimg.com/vi/0MQEf_7qk4s/maxresdefau...                   1280.0
# 1  https://i.ytimg.com/vi/RZdYlS6zvhY/maxresdefau...                   1280.0
# 2  https://i.ytimg.com/vi/GRlarIhf1Rw/maxresdefau...                   1280.0
# 3  https://i.ytimg.com/vi/MOCPCwGm3Dw/maxresdefau...                   1280.0
# 4  https://i.ytimg.com/vi/ObMnw8woAog/maxresdefau...                   1280.0
#
#    thumbnails.maxres.height  \
# 0                     720.0
# 1                     720.0
# 2                     720.0
# 3                     720.0
# 4                     720.0
#
#                                      localized.title  \
# 0  120 mind blowing AI tools #productivity #aitoo...
# 1         PAID vs FREE AI Tools - Best Free AI Tools
# 2  Top 10 designer AI tools #ai #productivity #de...
# 3                3 Best AI tools for market research
# 4                           Best 12 AI Tools in 2023
#
#                                localized.description  \
# 0
# 1  PAID vs FREE AI Tools - Best Free AI Tools\nAr...
# 2
# 3  Top 3 AI Market Research Tools: Automate Your ...
# 4
#
#                                                 tags defaultLanguage  \
# 0                                                NaN             NaN
# 1  [ai, ai tools, best ai tools, new ai tools, be...           en-IN
# 2                                                NaN             NaN
# 3  [AI tools, market research tools, artificial i...           en-US
# 4                                                NaN             NaN
#
#   defaultAudioLanguage duration dimension definition caption  licensedContent  \
# 0                  NaN     PT8S        2d         hd   false             True
# 1                   en    PT12S        2d         hd   false             True
# 2                  NaN    PT18S        2d         hd   false             True
# 3                en-US    PT34S        2d         hd   false            False
# 4                  NaN    PT36S        2d         hd   false             True
#
#     projection regionRestriction.blocked regionRestriction.allowed  \
# 0  rectangular                       NaN                       NaN
# 1  rectangular                       NaN                       NaN
# 2  rectangular                       NaN                       NaN
# 3  rectangular                       NaN                       NaN
# 4  rectangular                       NaN                       NaN
#
#   contentRating.ytRating viewCount likeCount favoriteCount commentCount
# 0                    NaN    253586     14833             0           81
# 1                    NaN     35260       247             0            6
# 2                    NaN    703645     31338             0           85
# 3                    NaN     19015       710             0            5
# 4                    NaN   1985707    122736             0          440

# %% [markdown]
# ## Kiểm tra trùng lặp

# %%
#Kiểm tra duplicate
df['id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Ý nghĩa các dòng, các cột

# %% [markdown]
# | Column Name                      | Description |
# |----------------------------------|-------------|
# | `kind`                           | Resource type; e.g., "youtube#video". |
# | `etag`                           | Unique identifier for resource versioning, helps in caching. |
# | `id`                             | Video ID (or other resource ID if not only videos). |
# | `publishedAt`                    | Date and time when the video was published (ISO 8601 format). |
# | `channelId`                      | ID of the channel that uploaded the video. |
# | `title`                          | Title of the video. |
# | `description`                    | Full description of the video. |
# | `channelTitle`                   | Name of the channel. |
# | `categoryId`                     | ID representing the video’s category (e.g., Music, Education). |
# | `liveBroadcastContent`          | Whether the video is `live`, `none`, or `upcoming`. |
# | `thumbnails.default.url`        | URL of the default (smallest) thumbnail. |
# | `thumbnails.default.width`      | Width of the default thumbnail. |
# | `thumbnails.default.height`     | Height of the default thumbnail. |
# | `thumbnails.medium.url`         | URL of the medium-quality thumbnail. |
# | `thumbnails.medium.width`       | Width of the medium thumbnail. |
# | `thumbnails.medium.height`      | Height of the medium thumbnail. |
# | `thumbnails.high.url`           | URL of the high-quality thumbnail. |
# | `thumbnails.high.width`         | Width of the high thumbnail. |
# | `thumbnails.high.height`        | Height of the high thumbnail. |
# | `thumbnails.standard.url`       | URL of the standard-quality thumbnail (may be null). |
# | `thumbnails.standard.width`     | Width of the standard thumbnail. |
# | `thumbnails.standard.height`    | Height of the standard thumbnail. |
# | `thumbnails.maxres.url`         | URL of the max resolution thumbnail. |
# | `thumbnails.maxres.width`       | Width of the max resolution thumbnail. |
# | `thumbnails.maxres.height`      | Height of the max resolution thumbnail. |
# | `localized.title`               | Title localized based on the viewer's language setting. |
# | `localized.description`         | Description localized based on the viewer's language setting. |
# | `tags`                           | List of tags (keywords) associated with the video. |
# | `defaultLanguage`               | Language used in the video metadata (ISO 639-1). |
# | `defaultAudioLanguage`          | Language of the audio track in the video. |
# | `duration`                      | Length of the video in ISO 8601 duration format (e.g., PT5M33S = 5m 33s). |
# | `dimension`                     | Video dimension, e.g., `2d` or `3d`. |
# | `definition`                    | Quality definition: `hd` (High) or `sd` (Standard). |
# | `caption`                       | Whether the video has captions (`true`/`false`). |
# | `licensedContent`              | Whether the video contains licensed third-party content. |
# | `projection`                    | Projection type (e.g., `rectangular` or `360`). |
# | `regionRestriction.blocked`     | List of country codes where the video is **blocked**. |
# | `regionRestriction.allowed`     | List of country codes where the video is **allowed**. |
# | `contentRating.ytRating`        | YouTube’s content rating (e.g., `ytAgeRestricted`). |
# | `viewCount`                     | Number of times the video has been viewed. |
# | `likeCount`                     | Number of likes the video has received. |
# | `favoriteCount`                 | Number of times the video has been favorited (always 0 for YouTube). |
# | `commentCount`                  | Number of comments on the video. |

# %% [markdown]
# ## Loại bỏ cột dư thừa

# %%
drop_columns = [
    'etag', 'kind',
    'thumbnails.medium.url', 'thumbnails.medium.width', 'thumbnails.medium.height',
    'thumbnails.high.url', 'thumbnails.high.width', 'thumbnails.high.height',
    'thumbnails.standard.url', 'thumbnails.standard.width', 'thumbnails.standard.height', 'thumbnails.maxres.url',
    'thumbnails.maxres.width', 'thumbnails.maxres.height', 'thumbnails.default.width', 'thumbnails.default.height',
    'localized.title', 'localized.description','thumbnails.default.url' ,
    'projection', 'liveBroadcastContent',
    'favoriteCount', 
]
df.drop(columns=drop_columns, inplace=True, errors='ignore')

# %% [markdown]
# ## Kiểm tra kiểu dữ liệu và fix

# %%
df.head(5)
# Out:
#             id           publishedAt                 channelId  \
# 0  0MQEf_7qk4s  2024-12-03T17:01:38Z  UC0xHrJNbxHmFnUP-49WYM-Q
# 1  RZdYlS6zvhY  2024-12-26T04:53:04Z  UC8w4I8t2OpqoOpzzNT1c2dg
# 2  GRlarIhf1Rw  2024-08-17T12:24:50Z  UC0xHrJNbxHmFnUP-49WYM-Q
# 3  MOCPCwGm3Dw  2025-03-20T13:00:25Z  UC7geKfz2-IH0rsgRBtHTm0g
# 4  ObMnw8woAog  2023-05-18T16:08:40Z  UCPkctgt1mTeJWTGj4tq4dPQ
#
#                                                title  \
# 0  120 mind blowing AI tools #productivity #aitoo...
# 1         PAID vs FREE AI Tools - Best Free AI Tools
# 2  Top 10 designer AI tools #ai #productivity #de...
# 3                3 Best AI tools for market research
# 4                           Best 12 AI Tools in 2023
#
#                                          description        channelTitle  \
# 0                                                               SetupsAI
# 1  PAID vs FREE AI Tools - Best Free AI Tools\nAr...            WebbyFan
# 2                                                               SetupsAI
# 3  Top 3 AI Market Research Tools: Automate Your ...  Learn With Shopify
# 4                                                                LKLogic
#
#   categoryId                                               tags  \
# 0         22                                                NaN
# 1         26  [ai, ai tools, best ai tools, new ai tools, be...
# 2         22                                                NaN
# 3         27  [AI tools, market research tools, artificial i...
# 4         27                                                NaN
#
#   defaultLanguage defaultAudioLanguage duration dimension definition caption  \
# 0             NaN                  NaN     PT8S        2d         hd   false
# 1           en-IN                   en    PT12S        2d         hd   false
# 2             NaN                  NaN    PT18S        2d         hd   false
# 3           en-US                en-US    PT34S        2d         hd   false
# 4             NaN                  NaN    PT36S        2d         hd   false
#
#    licensedContent regionRestriction.blocked regionRestriction.allowed  \
# 0             True                       NaN                       NaN
# 1             True                       NaN                       NaN
# 2             True                       NaN                       NaN
# 3            False                       NaN                       NaN
# 4             True                       NaN                       NaN
#
#   contentRating.ytRating viewCount likeCount commentCount
# 0                    NaN    253586     14833           81
# 1                    NaN     35260       247            6
# 2                    NaN    703645     31338           85
# 3                    NaN     19015       710            5
# 4                    NaN   1985707    122736          440

# %%
df['caption'].value_counts()
# Out:
# caption
# false    6349
# true      971
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7320 entries, 0 to 7319
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         7320 non-null   object
#  1   publishedAt                7320 non-null   object
#  2   channelId                  7320 non-null   object
#  3   title                      7320 non-null   object
#  4   description                7320 non-null   object
#  5   channelTitle               7320 non-null   object
#  6   categoryId                 7320 non-null   object
#  7   tags                       4855 non-null   object
#  8   defaultLanguage            2547 non-null   object
#  9   defaultAudioLanguage       5465 non-null   object
#  10  duration                   7314 non-null   object
#  11  dimension                  7320 non-null   object
#  12  definition                 7320 non-null   object
#  13  caption                    7320 non-null   object
#  14  licensedContent            7320 non-null   bool
#  15  regionRestriction.blocked  80 non-null     object
#  16  regionRestriction.allowed  6 non-null      object
#  17  contentRating.ytRating     2 non-null      object
#  18  viewCount                  7317 non-null   object
#  19  likeCount                  7066 non-null   object
#  20  commentCount               7214 non-null   object
# dtypes: bool(1), object(20)
# memory usage: 1.1+ MB

# %% [markdown]
# After reviewing the data, I noticed several issues that need to be addressed:
#
# **1. Incorrect Data Types:**
#
# * `publishedAt` should be converted from `object` to `datetime`.
# * `duration` should be converted into a time format for easier processing and analysis.
# * `caption` should be a boolean (`True`/`False`) instead of a string.
# * `viewCount`, `likeCount`, and `commentCount` should all be stored as integers, not strings.
#
# **2. Missing Values:**
#
# * Some columns contain null values and will need to be handled accordingly. <br><br>
#
#
#
# As a first step, I will correct the data types to ensure the dataset is consistent and ready for further analysis:
#
# * Convert `publishedAt` to `datetime`.
# * Convert `duration` into a proper time format. (1h = 60 minutes, 30s = 0.5 minutes,...)
# * Transform `caption` into a boolean value.
# * Cast `viewCount`, `likeCount`, and `commentCount` as integers.

# %%
#change publishedAt to datetime
df['publishedAt'] = pd.to_datetime(df['publishedAt'], errors='coerce')

#change caption to boolean
df['caption'] = df['caption'].apply(lambda x: True if x == 'true' else False)

#cast viewCount, likeCount, commentCount to int
df['viewCount'] = pd.to_numeric(df['viewCount'], errors='coerce')
df['likeCount'] = pd.to_numeric(df['likeCount'], errors='coerce')
df['commentCount'] = pd.to_numeric(df['commentCount'], errors='coerce')

# %%
#change duration to minutes
import isodate as i
df['duration_minutes'] = df['duration'].apply(lambda x: round(i.parse_duration(x).total_seconds() / 60 if pd.notnull(x) else 0, 3))
df.drop(columns=['duration'], inplace=True)

# %%
df.head(10)
# Out:
#             id               publishedAt                 channelId  \
# 0  0MQEf_7qk4s 2024-12-03 17:01:38+00:00  UC0xHrJNbxHmFnUP-49WYM-Q
# 1  RZdYlS6zvhY 2024-12-26 04:53:04+00:00  UC8w4I8t2OpqoOpzzNT1c2dg
# 2  GRlarIhf1Rw 2024-08-17 12:24:50+00:00  UC0xHrJNbxHmFnUP-49WYM-Q
# 3  MOCPCwGm3Dw 2025-03-20 13:00:25+00:00  UC7geKfz2-IH0rsgRBtHTm0g
# 4  ObMnw8woAog 2023-05-18 16:08:40+00:00  UCPkctgt1mTeJWTGj4tq4dPQ
# 5  fvxyj34edJU 2024-12-04 23:51:24+00:00  UCyVbhVGzfL9tW9Xc1FkYsbg
# 6  3-UzoSScXyE 2025-03-06 04:40:48+00:00  UCHNWKXRh_O3oX5ew47lW44Q
# 7  TZe5UqlUg0c 2025-03-05 08:00:32+00:00  UCfJT_eYDTmDE-ovKaxVE1ig
# 8  NQjYMvkDkrE 2025-05-12 12:52:12+00:00  UCXGT7mz2PeIOsMyMpwe5nhQ
# 9  eFy8tepEByw 2025-03-14 11:30:45+00:00  UCY6N8zZhs2V7gNTUxPuKWoQ
#
#                                                title  \
# 0  120 mind blowing AI tools #productivity #aitoo...
# 1         PAID vs FREE AI Tools - Best Free AI Tools
# 2  Top 10 designer AI tools #ai #productivity #de...
# 3                3 Best AI tools for market research
# 4                           Best 12 AI Tools in 2023
# 5  Best PAID AI Tools Free Alternatives 2025 | #A...
# 6  Best Free AI Tools for Research Papers & Essay...
# 7  7 Best AI Tools You NEED to Try in 2025 (Free ...
# 8  how to restore damaged photos using the ChatGP...
# 9                     BEST AI TOOLS TO USE IN 2025!🔥
#
#                                          description          channelTitle  \
# 0                                                                 SetupsAI
# 1  PAID vs FREE AI Tools - Best Free AI Tools\nAr...              WebbyFan
# 2                                                                 SetupsAI
# 3  Top 3 AI Market Research Tools: Automate Your ...    Learn With Shopify
# 4                                                                  LKLogic
# 5  Title:\nBest PAID AI Tools Free Alternatives 2...         PC Skills Pro
# 6  📝 Struggling with writing research papers or e...                Alamin
# 7  Looking for the best AI tools to boost product...       Kevin Stratvert
# 8  Want to get back your photo from the damaged p...  Tech tips and tricks
# 9  📸 Instagram: https://bit.ly/ishansharma7390ig\...          Ishan Sharma
#
#   categoryId                                               tags  \
# 0         22                                                NaN
# 1         26  [ai, ai tools, best ai tools, new ai tools, be...
# 2         22                                                NaN
# 3         27  [AI tools, market research tools, artificial i...
# 4         27                                                NaN
# 5         27  [Free AI for increasing work efficiency 2025, ...
# 6         27                                                NaN
# 7         28  [kevin stratvert, tools, best ai tools, free a...
# 8         28  [shorts, aishorts, aitoolsdemo, aitools2025, a...
# 9         24  [ai tools, ai tools to save time, ai tools for...
#
#   defaultLanguage defaultAudioLanguage dimension definition  caption  \
# 0             NaN                  NaN        2d         hd    False
# 1           en-IN                   en        2d         hd    False
# 2             NaN                  NaN        2d         hd    False
# 3           en-US                en-US        2d         hd    False
# 4             NaN                  NaN        2d         hd    False
# 5             NaN                  NaN        2d         hd    False
# 6             NaN                  NaN        2d         hd    False
# 7              en                   en        2d         hd     True
# 8              en                   en        2d         hd    False
# 9             NaN                en-IN        2d         hd    False
#
#    licensedContent regionRestriction.blocked regionRestriction.allowed  \
# 0             True                       NaN                       NaN
# 1             True                       NaN                       NaN
# 2             True                       NaN                       NaN
# 3            False                       NaN                       NaN
# 4             True                       NaN                       NaN
# 5            False                       NaN                       NaN
# 6            False                       NaN                       NaN
# 7             True                       NaN                       NaN
# 8            False                       NaN                       NaN
# 9             True                       NaN                       NaN
#
#   contentRating.ytRating  viewCount  likeCount  commentCount  duration_minutes
# 0                    NaN   253586.0    14833.0          81.0             0.133
# 1                    NaN    35260.0      247.0           6.0             0.200
# 2                    NaN   703645.0    31338.0          85.0             0.300
# 3                    NaN    19015.0      710.0           5.0             0.567
# 4                    NaN  1985707.0   122736.0         440.0             0.600
# 5                    NaN   334280.0     7493.0          61.0             0.117
# 6                    NaN    60165.0     1455.0          33.0             0.600
# 7                    NaN   213090.0     4678.0         106.0             7.817
# 8                    NaN      613.0        6.0           0.0             0.433
# 9                    NaN  4802595.0   205401.0         203.0             1.133

# %% [markdown]
# With the data types corrected, we will now adressing missing values. We Will start with the categorical columns (bool, object,...)

# %%
categorical_columns = []
for col in df.select_dtypes(include=['object','bool']).columns:
    categorical_columns.append(col)
categorical_columns
# Out:
# ['id',
#  'channelId',
#  'title',
#  'description',
#  'channelTitle',
#  'categoryId',
#  'tags',
#  'defaultLanguage',
#  'defaultAudioLanguage',
#  'dimension',
#  'definition',
#  'caption',
#  'licensedContent',
#  'regionRestriction.blocked',
#  'regionRestriction.allowed',
#  'contentRating.ytRating']

# %%
#Tính và vẽ chart plotly % null của các cột, sắp xêp theo tỷ lệ null giảm dần
import plotly.express as px

null_counts = df[categorical_columns].isnull().mean().sort_values(ascending=False)
fig = px.bar(null_counts*100, 
             title='Tỷ lệ Null của các cột trong DataFrame', 
             labels={'index': 'Cột', 'value': 'Tỷ lệ Null'},
             text=round(null_counts * 100, 2))
fig.update_layout(xaxis_title='Cột', yaxis_title='Tỷ lệ Null (%)')
fig.show()

# %%
#Drop các cột có tỷ lệ null > 75%
threshold = 0.75
columns_to_drop = null_counts[null_counts > threshold].index.tolist()
df.drop(columns=columns_to_drop, inplace=True, errors='ignore')

# %%
def detect_language_safe(title):
    try:
        return detect(str(title))
    except:
        return "unknown"

df['defaultLanguage'] = df['defaultLanguage'].fillna(df['description'].apply(detect_language_safe))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7320 entries, 0 to 7319
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    7320 non-null   object
#  1   publishedAt           7320 non-null   datetime64[ns, UTC]
#  2   channelId             7320 non-null   object
#  3   title                 7320 non-null   object
#  4   description           7320 non-null   object
#  5   channelTitle          7320 non-null   object
#  6   categoryId            7320 non-null   object
#  7   tags                  4855 non-null   object
#  8   defaultLanguage       7320 non-null   object
#  9   defaultAudioLanguage  5465 non-null   object
#  10  dimension             7320 non-null   object
#  11  definition            7320 non-null   object
#  12  caption               7320 non-null   bool
#  13  licensedContent       7320 non-null   bool
#  14  viewCount             7317 non-null   float64
#  15  likeCount             7066 non-null   float64
#  16  commentCount          7214 non-null   float64
#  17  duration_minutes      7320 non-null   float64
# dtypes: bool(2), datetime64[ns, UTC](1), float64(4), object(11)
# memory usage: 929.4+ KB

# %%
df.fillna({'defaultAudioLanguage': 'None',  'tags': 'None'}, inplace=True)

# %%
#drop rows where duration is null
df.dropna(subset=['duration_minutes'], inplace=True)

# %%
numberic_columns = df.select_dtypes(exclude=['bool','object']).columns.tolist()

#Calculate NA percent and draw plotly bar chart
na_percent = df[numberic_columns].isnull().mean().sort_values(ascending=False)
fig = px.bar(na_percent * 100,
                title='Tỷ lệ Null của các cột số trong DataFrame', 
                labels={'index': 'Cột', 'value': 'Tỷ lệ Null'},
                text=round(na_percent * 100, 2))
fig.update_layout(xaxis_title='Cột', yaxis_title='Tỷ lệ Null (%)')
fig.show()

# %%
df[df['duration_minutes'] == 0]
# Out:
#                id               publishedAt                 channelId  \
# 1973  zce9XNAdaNY 2025-05-11 21:05:29+00:00  UChELZ_JMGNYuxObfrXoER6A
# 1979  PR0tQ_NstH4 2025-05-11 21:05:13+00:00  UChELZ_JMGNYuxObfrXoER6A
# 2005  Zzu3qDY-Tog 2025-05-11 21:06:16+00:00  UChELZ_JMGNYuxObfrXoER6A
# 2007  lTMeZVzKvsc 2025-05-11 21:04:17+00:00  UChELZ_JMGNYuxObfrXoER6A
# 2049  1LHPrXRT07k 2025-05-01 09:36:12+00:00  UCEcRPnqQeCLyAxpr_R8bygw
# 3447  1oDrJba2PSs 2025-01-09 11:48:26+00:00  UCSJ4gkVC6NrvII8umztf0Ow
# 3449  Na0w3Mz46GA 2024-06-02 16:19:22+00:00  UCSJ4gkVC6NrvII8umztf0Ow
# 4701  qd-_03GEjCE 2025-05-12 11:24:35+00:00  UCY-edAci2pVBEsFHSyl_lRg
# 5694  8EyMUl-zvVE 2025-04-14 02:51:14+00:00  UCbfENehrv6SRfQLRNZrypcg
#
#                                                   title  \
# 1973     Foundation Principles of Generative AI, Part 5
# 1979     Foundation Principles of Generative AI, Part 6
# 2005     Foundation Principles of Generative AI, Part 4
# 2007     Foundation Principles of Generative AI, Part 9
# 2049  كل طرق تعلم الذكاء الاصطناعي: من ML لـ Generat...
# 3447                           Study With Me 📚 Pomodoro
# 3449        asian lofi radio ⛩️ beats to relax/study to
# 4701  AI Tools for Everyday Work | Boost Productivit...
# 5694  Claude AI Explained | The Anthropic Chatbot Ri...
#
#                                             description          channelTitle  \
# 1973  In this episode, you will explore a foundation...      Christopher Penn
# 1979  In this episode, Christopher Penn reveals a fu...      Christopher Penn
# 2005  In this episode, Christopher Penn discusses th...      Christopher Penn
# 2007  In this episode, discover the tenth foundation...      Christopher Penn
# 2049  هل تعلم إنو الذكاء الاصطناعي بلّش رسميًا سنة 1...            Lara Wehbe
# 3447  🎼 | Listen on Spotify, Apple music and more\n→...             Lofi Girl
# 3449  🎼 | Listen on Spotify, Apple music and more\n→...             Lofi Girl
# 4701  @educationnestofficial \nAI Tools for Everyday...        Education Nest
# 5694  Welcome to our channel! In this video, we take...  Professor Rahul Jain
#
#      categoryId                                               tags  \
# 1973         27  [Generative AI, AI Principles, How AI Works, C...
# 1979         27  [generative AI, AI prompting, prompting, deleg...
# 2005         27  [generative AI, AI prompts, prompt length, pro...
# 2007         27  [AI, Generative AI, AI Models, Artificial Inte...
# 2049         28  [machine learning, deep learning, reinforcemen...
# 3447         10  [pomodoro, pomodoro technique, study with me, ...
# 3449         10  [chilledcow, chilled cow, lofi, lofi hiphop, l...
# 4701         27                                               None
# 5694         27  [Claude AI, Anthropic Claude, AI chatbot, Chat...
#
#      defaultLanguage defaultAudioLanguage dimension definition  caption  \
# 1973              en                   en        2d         hd    False
# 1979              en                   en        2d         hd    False
# 2005              en                   en        2d         hd    False
# 2007              en                   en        2d         hd    False
# 2049              ar                   ar        2d         hd    False
# 3447              en                 None        2d         sd    False
# 3449              en                 None        2d         sd    False
# 4701              en                 None        2d         sd    False
# 5694              en                 None        2d         hd    False
#
#       licensedContent   viewCount  likeCount  commentCount  duration_minutes
# 1973            False         0.0        0.0           0.0               0.0
# 1979            False         0.0        0.0           1.0               0.0
# 2005            False         0.0        0.0           1.0               0.0
# 2007            False         0.0        0.0           0.0               0.0
# 2049            False         0.0        1.0           0.0               0.0
# 3447             True   2729017.0    23848.0           0.0               0.0
# 3449             True  11561564.0    97048.0           0.0               0.0
# 4701             True         0.0        0.0           0.0               0.0
# 5694            False         0.0        0.0           0.0               0.0

# %%
#drop rows where duration_minutes is 0
df = df[df['duration_minutes'] > 0]

# %%
df['likeCount'] = df['likeCount'].fillna(0).astype(int)
df['commentCount'] = df['commentCount'].fillna(0).astype(int)
df['viewCount'] = df['viewCount'].fillna(0).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7311 entries, 0 to 7319
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    7311 non-null   object
#  1   publishedAt           7311 non-null   datetime64[ns, UTC]
#  2   channelId             7311 non-null   object
#  3   title                 7311 non-null   object
#  4   description           7311 non-null   object
#  5   channelTitle          7311 non-null   object
#  6   categoryId            7311 non-null   object
#  7   tags                  7311 non-null   object
#  8   defaultLanguage       7311 non-null   object
#  9   defaultAudioLanguage  7311 non-null   object
#  10  dimension             7311 non-null   object
#  11  definition            7311 non-null   object
#  12  caption               7311 non-null   bool
#  13  licensedContent       7311 non-null   bool
#  14  viewCount             7311 non-null   int32
#  15  likeCount             7311 non-null   int32
#  16  commentCount          7311 non-null   int32
#  17  duration_minutes      7311 non-null   float64
# dtypes: bool(2), datetime64[ns, UTC](1), float64(1), int32(3), object(11)
# memory usage: 899.6+ KB

# %% [markdown]
# ## Kiểm tra phân bố
# ### Kiểm tra phân vị, histogram với dữ liệu số

# %%
# Hiển thị toàn bộ số thập phân (ví dụ: 657015.900 instead of 6.570159e+05)
pd.set_option('display.float_format', '{:.6f}'.format)
df.describe()
# Out:
#              viewCount      likeCount  commentCount  duration_minutes
# count      7311.000000    7311.000000   7311.000000       7311.000000
# mean     655870.033511   16938.565996    385.260703         17.148914
# std     3665125.179642   97576.375987   1802.174724         82.733213
# min           0.000000       0.000000      0.000000          0.033000
# 25%        3411.000000      49.000000      2.000000          0.700000
# 50%       29085.000000     630.000000     26.000000          2.667000
# 75%      183132.000000    4196.500000    149.000000         12.908500
# max   104343035.000000 2795506.000000  45002.000000       3948.783000

# %%
df[df['duration_minutes'] < 1]
# Out:
#                id               publishedAt                 channelId  \
# 0     0MQEf_7qk4s 2024-12-03 17:01:38+00:00  UC0xHrJNbxHmFnUP-49WYM-Q
# 1     RZdYlS6zvhY 2024-12-26 04:53:04+00:00  UC8w4I8t2OpqoOpzzNT1c2dg
# 2     GRlarIhf1Rw 2024-08-17 12:24:50+00:00  UC0xHrJNbxHmFnUP-49WYM-Q
# 3     MOCPCwGm3Dw 2025-03-20 13:00:25+00:00  UC7geKfz2-IH0rsgRBtHTm0g
# 4     ObMnw8woAog 2023-05-18 16:08:40+00:00  UCPkctgt1mTeJWTGj4tq4dPQ
# ...           ...                       ...                       ...
# 7312  IXhmwcMIDCE 2023-05-20 04:48:53+00:00  UCg2Pq_61OYOUjbq8fTA1t3A
# 7313  DxEQ80o_oew 2024-10-20 05:55:58+00:00  UCCrDVNw6IGhs7Av77W4O7Cg
# 7314  61UfcPIlzZs 2023-10-25 13:54:30+00:00  UCnN0pW_aaM3uaRTv5Y2iDpw
# 7317  CkNjj5nJbr8 2024-10-16 12:00:01+00:00  UCCrDVNw6IGhs7Av77W4O7Cg
# 7319  si971R_ghg8 2025-04-02 06:13:59+00:00  UCSY3VSZaEzdjoLKoEXKafWQ
#
#                                                   title  \
# 0     120 mind blowing AI tools #productivity #aitoo...
# 1            PAID vs FREE AI Tools - Best Free AI Tools
# 2     Top 10 designer AI tools #ai #productivity #de...
# 3                   3 Best AI tools for market research
# 4                              Best 12 AI Tools in 2023
# ...                                                 ...
# 7312  Trend mới chỉ dành cho ai có bồ 🤣 #shorts  #ti...
# 7313  AI LÀ NGƯỜI GÂY ẤN TƯỢNG NHẤT VỚI BẠN #xuhuong...
# 7314  Engineering branch which have better scope or ...
# 7317  AI LÀ NGƯỜI GÂY ẤN TƯỢNG MẠNH VỚI BẠN? #xuhuon...
# 7319  Ghibili trend gone wrong 🤣🤣 #ghibli #ghibliart...
#
#                                             description  \
# 0
# 1     PAID vs FREE AI Tools - Best Free AI Tools\nAr...
# 2
# 3     Top 3 AI Market Research Tools: Automate Your ...
# 4
# ...                                                 ...
# 7312  ✔ xin chào, Việt Phương Thoa đâyyyyyy  \n\n⨳ T...
# 7313  WHO IMPRESSES YOU #xuhuong #dance #nhảytrend #...
# 7314
# 7317  WHICH CHARACTER IMPRESSES YOU? #xuhuong #dance...
# 7319
#
#                   channelTitle categoryId  \
# 0                     SetupsAI         22
# 1                     WebbyFan         26
# 2                     SetupsAI         22
# 3           Learn With Shopify         27
# 4                      LKLogic         27
# ...                        ...        ...
# 7312          Việt Phương Thoa         22
# 7313  TikTok Việt Nam Official         24
# 7314                  PG Clips         22
# 7317  TikTok Việt Nam Official         24
# 7319              Aswinvlogs93         22
#
#                                                    tags defaultLanguage  \
# 0                                                  None         unknown
# 1     [ai, ai tools, best ai tools, new ai tools, be...           en-IN
# 2                                                  None         unknown
# 3     [AI tools, market research tools, artificial i...           en-US
# 4                                                  None         unknown
# ...                                                 ...             ...
# 7312  [việt phương thoa, viet phuong thoa, tik tok, ...              vi
# 7313  [tiktok, tiktok gái xinh, tiktok việt nam, trà...              vi
# 7314                                               None         unknown
# 7317  [tiktok, tiktok gái xinh, tiktok việt nam, trà...              vi
# 7319                                               None         unknown
#
#      defaultAudioLanguage dimension definition  caption  licensedContent  \
# 0                    None        2d         hd    False             True
# 1                      en        2d         hd    False             True
# 2                    None        2d         hd    False             True
# 3                   en-US        2d         hd    False            False
# 4                    None        2d         hd    False             True
# ...                   ...       ...        ...      ...              ...
# 7312                   vi        2d         hd    False             True
# 7313                 None        2d         hd    False            False
# 7314                 None        2d         hd    False            False
# 7317                 None        2d         hd    False            False
# 7319                 None        2d         hd    False            False
#
#       viewCount  likeCount  commentCount  duration_minutes
# 0        253586      14833            81          0.133000
# 1         35260        247             6          0.200000
# 2        703645      31338            85          0.300000
# 3         19015        710             5          0.567000
# 4       1985707     122736           440          0.600000
# ...         ...        ...           ...               ...
# 7312    2771323      50432           916          0.200000
# 7313   12287866     278649           601          0.217000
# 7314     146184       4287            60          0.967000
# 7317    1292540      42376           424          0.283000
# 7319    1382297      13442           145          0.183000
#
# [2927 rows x 18 columns]

# %%
len(df[df['duration_minutes'] < 1])
# Out:
# 2927

# %%
categorical_columns = df.select_dtypes(include=['object', 'bool']).columns.tolist()
string_columns = ['title', 'description', 'tags','id', 'channelId']
# Loại bỏ các cột không phải là categorical
categorical_columns = [col for col in categorical_columns if col not in string_columns]

#Vẽ histogram cho các cột categorical
for col in categorical_columns:
        fig = px.histogram(df, x=col, title=f'Histogram of {col}')
        fig.show()

# %% [markdown]
# Since 'dimensions', 'definition' does not contains a lot of information, and we dont focus on analyze the image quality of video, we can drop it

# %%
#drop 'dimensions', 'definition'
df.drop(columns=['dimension', 'definition'], inplace=True)

# %%
# Bước 1: Tạo dictionary ánh xạ từ ID sang tên thể loại
category_mapping = {
    '1': "Film & Animation",
    '2': "Autos & Vehicles",
    '10': "Music",
    '15': "Pets & Animals",
    '17': "Sports",
    '19': "Travel & Events",
    '20': "Gaming",
    '22': "People & Blogs",
    '23': "Comedy",
    '24': "Entertainment",
    '25': "News & Politics",
    '26': "Howto & Style",
    '27': "Education",
    '28': "Science & Technology",
    '29': "Nonprofits & Activism"
}

# Bước 2: Thêm cột mới 'categoryName' dựa trên 'categoryId'
df['categoryName'] = df['categoryId'].map(category_mapping)

# %%
#add new column 'crawl_date' with '2025-05-14', date time
df['crawl_date'] = pd.to_datetime('2025-05-14')

# %%
df.head(5)
# Out:
#             id               publishedAt                 channelId  \
# 0  0MQEf_7qk4s 2024-12-03 17:01:38+00:00  UC0xHrJNbxHmFnUP-49WYM-Q
# 1  RZdYlS6zvhY 2024-12-26 04:53:04+00:00  UC8w4I8t2OpqoOpzzNT1c2dg
# 2  GRlarIhf1Rw 2024-08-17 12:24:50+00:00  UC0xHrJNbxHmFnUP-49WYM-Q
# 3  MOCPCwGm3Dw 2025-03-20 13:00:25+00:00  UC7geKfz2-IH0rsgRBtHTm0g
# 4  ObMnw8woAog 2023-05-18 16:08:40+00:00  UCPkctgt1mTeJWTGj4tq4dPQ
#
#                                                title  \
# 0  120 mind blowing AI tools #productivity #aitoo...
# 1         PAID vs FREE AI Tools - Best Free AI Tools
# 2  Top 10 designer AI tools #ai #productivity #de...
# 3                3 Best AI tools for market research
# 4                           Best 12 AI Tools in 2023
#
#                                          description        channelTitle  \
# 0                                                               SetupsAI
# 1  PAID vs FREE AI Tools - Best Free AI Tools\nAr...            WebbyFan
# 2                                                               SetupsAI
# 3  Top 3 AI Market Research Tools: Automate Your ...  Learn With Shopify
# 4                                                                LKLogic
#
#   categoryId                                               tags  \
# 0         22                                               None
# 1         26  [ai, ai tools, best ai tools, new ai tools, be...
# 2         22                                               None
# 3         27  [AI tools, market research tools, artificial i...
# 4         27                                               None
#
#   defaultLanguage defaultAudioLanguage  caption  licensedContent  viewCount  \
# 0         unknown                 None    False             True     253586
# 1           en-IN                   en    False             True      35260
# 2         unknown                 None    False             True     703645
# 3           en-US                en-US    False            False      19015
# 4         unknown                 None    False             True    1985707
#
#    likeCount  commentCount  duration_minutes    categoryName crawl_date
# 0      14833            81          0.133000  People & Blogs 2025-05-14
# 1        247             6          0.200000   Howto & Style 2025-05-14
# 2      31338            85          0.300000  People & Blogs 2025-05-14
# 3        710             5          0.567000       Education 2025-05-14
# 4     122736           440          0.600000       Education 2025-05-14

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7311 entries, 0 to 7319
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    7311 non-null   object
#  1   publishedAt           7311 non-null   datetime64[ns, UTC]
#  2   channelId             7311 non-null   object
#  3   title                 7311 non-null   object
#  4   description           7311 non-null   object
#  5   channelTitle          7311 non-null   object
#  6   categoryId            7311 non-null   object
#  7   tags                  7311 non-null   object
#  8   defaultLanguage       7311 non-null   object
#  9   defaultAudioLanguage  7311 non-null   object
#  10  caption               7311 non-null   bool
#  11  licensedContent       7311 non-null   bool
#  12  viewCount             7311 non-null   int32
#  13  likeCount             7311 non-null   int32
#  14  commentCount          7311 non-null   int32
#  15  duration_minutes      7311 non-null   float64
#  16  categoryName          7311 non-null   object
#  17  crawl_date            7311 non-null   datetime64[ns]
# dtypes: bool(2), datetime64[ns, UTC](1), datetime64[ns](1), float64(1), int32(3), object(10)
# memory usage: 899.6+ KB

# %%
for col in df.columns:
    if df[col].apply(lambda x: isinstance(x, list)).any():
        df[col] = df[col].apply(lambda x: '; '.join(x) if isinstance(x, list) else x)

# %%
#create dataset '2_cleaned_data' and add ad as table 'video_basic_info'
today = pd.Timestamp.now().strftime('%Y%m%d')
dataset_id = "2_cleaned_data"
table_id = f"video_basic_info"

# Create dataset
full_dataset_id = f"{project_id}.{dataset_id}"
client = bigquery.Client(project=project_id)
dataset = bigquery.Dataset(full_dataset_id)
dataset.location = "asia-southeast1"

try:
    client.create_dataset(dataset, timeout=30)
    print(f"✅ Dataset '{full_dataset_id}' created.")
except Exception as e:
    print(f"⚠️ Failed to create dataset: {e}")
# Out:
# c:\Users\kt061\anaconda3\envs\min_ds\Lib\site-packages\google\auth\_default.py:76: UserWarning:
#
# Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
# ⚠️ Failed to create dataset: 409 POST https://bigquery.googleapis.com/bigquery/v2/projects/ytbdataanalyst/datasets?prettyPrint=false: Already Exists: Dataset ytbdataanalyst:2_cleaned_data

# %%
# Load config
table_ref = f"{project_id}.{dataset_id}.{table_id}"

job_config = bigquery.LoadJobConfig(
    write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE,  # Use WRITE_TRUNCATE to overwrite
    autodetect=True  # Let BigQuery detect schema from DataFrame
)

# Upload the DataFrame
job = client.load_table_from_dataframe(df, table_ref, job_config=job_config)
job.result()  # Wait for the job to complete

print(f"✅ Data uploaded to BigQuery table: {table_id}")
# Out:
# c:\Users\kt061\anaconda3\envs\min_ds\Lib\site-packages\google\cloud\bigquery\_pandas_helpers.py:489: FutureWarning:
#
# Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
# ✅ Data uploaded to BigQuery table: video_basic_info
