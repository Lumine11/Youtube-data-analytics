# %%
#connect to BigQuery
from google.cloud import bigquery
from google.cloud import storage
from googleapiclient.discovery import build
import json
from datetime import datetime
import time
import io

# %%
import os
from dotenv import load_dotenv
from pathlib import Path

parent_env_path = Path.cwd().parent / ".env"
load_dotenv(dotenv_path=parent_env_path)
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = os.getenv("GOOGLE_APPLICATION_CREDENTIALS")
API_KEY = os.getenv("API_KEY_1")
project_id = os.getenv("PROJECT_ID")

# %%
#connect to prj_id, dataset_id = 2_cleaned_data, table_id: video_basic_info
client = bigquery.Client(project=project_id)
dataset_id = "2_cleaned_data"
table_id = "video_basic_info"
table_ref = client.dataset(dataset_id).table(table_id)
# Out:
# c:\Users\kt061\anaconda3\envs\min_ds\Lib\site-packages\google\auth\_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
#querry and get the channel_id
query = f"""
SELECT distinct(channelId)
FROM `{project_id}.{dataset_id}.{table_id}`
"""

# %%
# Thực thi truy vấn
query_job = client.query(query)
results = query_job.result()

# Lưu kết quả vào danh sách
channel_list = [row.channelId for row in results]
len(channel_list)
# Out:
# 4245

# %%
channel_list
# Out:
# ['UCJ-lUkI7HFBXUG16RYQYWxw',
#  'UCyj5OG4nbnQMnueBOvryi9g',
#  'UCGODnMAAEhZeO0ROmB2EFBg',
#  'UCcOIZzJgLCyMPILY7-1Vsdg',
#  'UCDl5YK8CD2fY267VdDHLgfg',
#  'UC_RovKmk0OCbuZjA8f08opw',
#  'UCYjnt7fIBOjxCKF4m_DW3Ag',
#  'UCOJp1lsu9vCF-TllwMzcCLg',
#  'UCOXHwUny8BePng1gXxIe-PA',
#  'UCdvVtDgpEXI8e2UzBJR-NSQ',
#  'UCDkRmtg6Wt2jUsER5-xLRkQ',
#  'UCo0wMFwDhVqmdI2BVnE4Qeg',
#  'UCFGBxznLew-4-j0LESic87A',
#  'UChYs-_zjKRYhdMddjx-NPLw',
#  'UC5WjFrtBdufl6CZojX3D8dQ',
#  'UCsBqUzFfHvNHEmUj-NUC26w',
#  'UCYb4LjLNw3-K2B90ZTw7G7w',
#  'UC907TPs-L1d-hgE_pH1HVmg',
#  'UCR_gwC__rtlFBdNXdYXKy0A',
#  'UCENw8EpouX_IGd8a_p-Px2g',
#  'UCYhkv2Xbuj_FssJS74Eyn1w',
#  'UCWajepQsMCmNBUHVIPirk8g',
#  'UCUetYLN8ZnErkC0NmF0wfcA',
#  'UCRVtlcqayOmyuLIDrT3ng1w',
#  'UCE7spuKzxP1k8A-XucxxUAQ',
#  'UCLuYADJ6hESLHX87JnsGbjA',
#  'UC-B3lKAktiHyLwFv7TRq2xg',
#  'UC9gXEfDwAt9x8DzV8Pz2Caw',
#  'UCvViwWz0_m_lcHJEUFbIOlQ',
#  'UCCK6b9W7w4dJ6ZtclFZdpsA',
#  'UCaC3GsUi4NuY_IGVzhMA11A',
#  'UCi8C7TNs2ohrc6hnRQ5Sn2w',
#  'UCLF7ITqhCLwb9ZkZpyvyoUQ',
#  'UC58znoFTA2_8qnXIkOC75JQ',
#  'UC0IcuSzkill_2QyBH1MnMOQ',
#  'UCg9pTBF5vu86eGkO4aKi3NQ',
#  'UC7jf7M34XLreNJUnxyyYtEQ',
#  'UC8-Th83bH_thdKZDJCrn88g',
#  'UCW7AGm8JSBEEew61dJIgl_A',
#  'UCEDfPzFX7OuUVXawUH2GrnA',
#  'UCFm2potpkGnclQPMeYxN2ow',
#  'UCY25D8Rak0XwGRRir57K6qg',
#  'UCpJU5mN3mv6VJCDb-1k7PAA',
#  'UC8XA1eOZigBeY2Dj78WR9ew',
#  'UCoch_d78Aosmp14ey1HgGSQ',
#  'UCpV_X0VrL8-jg3t6wYGS-1g',
#  'UCf0PBRjhf0rF8fWBIxTuoWA',
#  'UCNGIDQ466bNY87eEeKeQuzA',
#  'UCYO_jab_esuFRV4b17AJtAw',
#  'UCvccwjObHiDH_3IWnM3f5KA',
#  'UCyHta2dyCTkf29AB67AYn7A',
#  'UCauCavIRk9Jy4-D1iy_y1GA',
#  'UCtFrc_PtglNBYkh7NynAgmA',
#  'UCp8lLM2JP_1pv6E0NQ38pqw',
#  'UCjrYRLo3EdDHJfimSAihjNA',
#  'UC3fiLpTgEE9PHeGgFAmDS0w',
#  'UC1eqXrdXse7mE5R1lrRd5Bw',
#  'UCTYPaVlcA3N46GfiOVD739Q',
#  'UCz5VmR33E2dstcQ0AqeLt8w',
#  'UCn2RJFAA1ndipnVJsYAwWOw',
#  'UCDnaXAXa0STJ6cYC9m7LF9A',
#  'UCOrNYuqNFV2-TUAUZu5qSaA',
#  'UCBWe-V31YaEa-tlqBiXqltA',
#  'UCmCAY_mStg1POKUWgMg-aGQ',
#  'UCyU8cI9U09-ufNVYNeoVO8A',
#  'UCmRaku8uYTNJ8VMA-w1X39g',
#  'UCCayKhPEGA82e9DbnkxPnOg',
#  'UCWFZzWfxOTRRhpddbtZC0ZQ',
#  'UCo8Twk8WbbDeEF5FNgdX4Og',
#  'UCbRAuB7ikqXt3i2BEL_bP4Q',
#  'UCfZX28-cKWKWhpqOjWrobaA',
#  'UC8DbVvuSiqg6mmp-K8yXRFQ',
#  'UCugDMta-1YUMPOSl9W4DBgw',
#  'UCjECA8ZHP52yFjKyRW4-8Hw',
#  'UCp6zcssPqSnE9LlfOYmXZEg',
#  'UCDZfn935vwaahDabsfylfIQ',
#  'UCj6Sdo4tRaczDt30FNbMztg',
#  'UCJvhLTkyfX0H3juT7D9H12A',
#  'UC1fDcw1Wqw1OG5PcauNeo3Q',
#  'UCJ-KJeHzrnZkGX7qAM2V74Q',
#  'UC8kFF39hsRrFfHM6-7A6APQ',
#  'UCHMy1tguHPmcQsxALlyf18g',
#  'UCjcXVqa43SspS2Q5Ikb5CYQ',
#  'UCFtlcbvNOjFb_akhP9Ly7ZA',
#  'UCev2mm-MzuhnNvAXZ3Z7jVg',
#  'UC4A4DZLrgTrw6lVi-VP8RIg',
#  'UCeUkC2uxnDJnvI29Kp_Kp9g',
#  'UCRLEADhMcb8WUdnQ5_Alk7g',
#  'UC8vjf5_1lXrXYJfD4dICGRg',
#  'UCBE-pYkO3G1cyu4z-TacxQA',
#  'UCsDTy8jvHcwMvSZf_JGi-FA',
#  'UC9M7dZqrA_inICuq3dSwoQg',
#  'UC_j6RqDBHE-G53Qjs8riHeg',
#  'UChKdxjtlyaS21ZuCdpL9ahA',
#  'UCc38bRwr1NXR6ndJwU6PODQ',
#  'UCdDtsDwI7U9k78w6PAyGfSA',
#  'UCmZBzIg2vpnBY6gagXJ42nQ',
#  'UCWqKcFb7h9cNEdCxB5A5BgQ',
#  'UCKU0u3VbuYn0wD3CUr-Yn6A',
#  'UCrFzy-Fc9OpU0dsi8mwk7jw',
#  'UCMv4linFpfZgRCiWgenhHuw',
#  'UCdq65x-0_G8sMhwWNgtmXaQ',
#  'UCn5CtwAo7oeHULdlVl-HMKw',
#  'UClH-KpveOLJszChWRfFmPfQ',
#  'UC7NyBKOKI6vdFDHYzDHlteg',
#  'UCzgPg1KhiJTzkxy0IUciRaQ',
#  'UCIBJXulalYQ0dYY5fB7LsfA',
#  'UCml4VmPF7KmD49bQ-XhR-JA',
#  'UCA295QVkf9O1RQ8_-s3FVXg',
#  'UCu1gvy0qwcHJ6Ot5iiiQyTQ',
#  'UC-D_JWjvR55BxcHad4fvAoQ',
#  'UClg1YG2uxaBd4X-0rCgwuLw',
#  'UCaO0cXm2BZ0vxUOAxrlah1A',
#  'UCd0FeVnxd8z9jkVV3wOr9Fw',
#  'UCVKSf8jO6Jq9jlpDMaMX2xw',
#  'UC8-A8NP7Dr5cd02QO1voj1g',
#  'UC1tulPk8iW7b3LM-0lWNLFA',
#  'UCEAbqW0HFB_UxZoUDO0kJBw',
#  'UCRa1gO7Br7s-9_S0b-WM6Hg',
#  'UCHNWKXRh_O3oX5ew47lW44Q',
#  'UCS8o8k_cwOFKg7Qn-j218IA',
#  'UCKxwEXrlXQYnXLw-L5ojmmw',
#  'UCPEZnYBqewx-h43B5tLymYw',
#  'UCUyDOdBWhC1MCxEjC46d-zw',
#  'UC7kIy8fZavEni8Gzl8NLjOQ',
#  'UC3sH8ShnMyB5MxavG1DaklA',
#  'UCS-_nVJBVHKLGqTTfY9D-aQ',
#  'UCoOae5nYA7VqaXzerajD0lg',
#  'UCCMSoNxUmvZqptMRWYUehvA',
#  'UC8WLJYJx18iRpOyX82zZudw',
#  'UCh9VaIz98zYq6Jw2ojbwLGw',
#  'UCiXFozWYaJ8shjtXJz47Yrw',
#  'UCh0b668zDtV1XLcZuIwEbag',
#  'UCv6eC6SWlm6p_fPbCwSYTjQ',
#  'UCoYavJuol0W3aPe1uAUNNvQ',
#  'UCnwWq9TE9Yd60jIs0yp1EDQ',
#  'UCH6gDteHtH4hg3o2343iObA',
#  'UCdRlXVgTzjPsZdf4tex__hg',
#  'UCMTDWG_-W5MPJXQkpZsTxVg',
#  'UCPn5YyTGKsVDnDULA5aq8IA',
#  'UCzHijPeaF1SqbJpOkdnrb6A',
#  'UCxFvHi1W58pQqCciT08hGUA',
#  'UCnHwry_kfr6oJ3W3nMpV6Nw',
#  'UCugfZrsRFwE32HcHcLbUTAQ',
#  'UCKEssKg-uvelYlm5s90x0ew',
#  'UCkHNVO_aPDSqjfIG_XHlYIg',
#  'UCIGamkvDYGEuLRfqNMLn29A',
#  'UCBwmMxybNva6P_5VmxjzwqA',
#  'UCJINtWke3-FMz2WuEltWDVQ',
#  'UCqnyK53tR3JqztHdDdM0E_g',
#  'UCRkBGr12q-rhzSHCTA0w0mQ',
#  'UCLoGADNKOleoeZF4U6MiE1Q',
#  'UCFOyeKxBqMhGTE8VDSUe8bg',
#  'UCJqx8MM4gDPDy8TqVVlPyLw',
#  'UCR2uRTQ53V_egXKFflMMaaw',
#  'UCcLAmSbFRiP4g32I6PqNyzg',
#  'UCxows96qiGDbCuMgsRp7mQQ',
#  'UCu43etOtxZD4gJw4k94N5ZQ',
#  'UC0VU1uXWEYCpVGFSZ0OQD5g',
#  'UCBx7WvvKwiXTv-yCFI018Rg',
#  'UC3QAJ63ROdbmQFAsubmyaig',
#  'UCjXfbV2_TcWpdVSGWHfOoSA',
#  'UC0ORQn1Fa_EleBJLDBglqFg',
#  'UCbCq5Y0WPGimG2jNXhoQxGw',
#  'UC3Qhl_FNeCtsOC46DVdYDsw',
#  'UCTs3VX60I6EKrrwdkgrwCGQ',
#  'UCdwKRgpXOHvVxlYnqYxXNzw',
#  'UCTvgSAxisCh58hjzlMdED0A',
#  'UCAbcoKROFsRA_uA9aSprCwg',
#  'UCi0Og_kmPT_sM1Q_3nDj6XQ',
#  'UCxHtGlzYPT6vhsMRvP0J8rg',
#  'UCkRFwipiIqBTakN-mkZ-GcQ',
#  'UCyWN-BnWSKeHEnNOYvvpNnA',
#  'UCS9BcPpwy1W5Xorp0KU23aQ',
#  'UClnGQG5Ib9GEBzJAV5mmixQ',
#  'UCHaHD477h-FeBbVh9Sh7syA',
#  'UCK3WJRWvVSu85usUbdm8qUA',
#  'UCn1USB9-5UqKJTSHd1JGcVw',
#  'UCDf_8gL0KLte4lS7IKd3xpA',
#  'UCY3K5KpHpALhyLml3RhF65A',
#  'UC8F7X90NDmMr1mGx8897r_A',
#  'UCqvuLvdIkUjAtSFrKw5LhXg',
#  'UCimY3LX34zbb6OO9i8MM4DA',
#  'UC9l7tHD7VC4orBaP26Ad2JQ',
#  'UCDTSUkdlbcgEU-IGH_mHgmw',
#  'UCFEHCvUfFakdJyTl4Xuq92w',
#  'UCwvM6d_NWEcgxjkCP5Q-ZZg',
#  'UC3KK7ENB_ierAXvrxVNnbZQ',
#  'UCnvB3xCvPSyrBAMHgBe3dVw',
#  'UCzWd8lsefYoh42OCrg6FzuQ',
#  'UCoXfB4FJGFGYopD4IPQ-UCQ',
#  'UCLCmRDJmLtH9ixrWVwGCZjA',
#  'UC8ofcOdHNINiPrBA9D59Vaw',
#  'UCrg3m_-ydPRcHDenTuIw5bA',
#  'UCvQECJukTDE2i6aCoMnS-Vg',
#  'UCotg1XiSmuJnFA6RXHKLW4w',
#  'UC7JqmPfPHcfHKN7ZOZCflKQ',
#  'UCQ9qzwIRsiaxGur9i7YFRcw',
#  'UCKFkTEYYlQa0Xm9mwPSegyA',
#  'UC_hG9fglfmShkwex1KVydHA',
#  'UCMT5Ui9vr5tHYXuXrhU3K2w',
#  'UCzXDfm1sfblA6xuA-2ixGeQ',
#  'UCcvt-UGh_BOCjhdpwz1Vm5w',
#  'UCfFUEwlIwPbYYA7RQ7Zfx3A',
#  'UCJ2U9Dq9NckqHMbcUupgF0A',
#  'UCmZqTB34wHK3KdDoZAlNr0g',
#  'UCcqCFcO-_p7T6PFHLmm8HGg',
#  'UCYbK_tjZ2OrIZFBvU6CCMiA',
#  'UCyFyjSC9b_xBHSwIdUrJhvw',
#  'UCtFCcrvupjyaq2lax_7OQQg',
#  'UCYr_ag3pt2GVPSD9O22cDtA',
#  'UCzIsviqoJc-VcWqF5Pp8iLw',
#  'UCsg20ERGZt9eHVZRXROJSqg',
#  'UCBVlDVnDO0o-dLkVlAYf8Dw',
#  'UCoGHeFY7jE2OB_TJS_87MOA',
#  'UCsh6L6zyRdtqW1QEEDDrNsQ',
#  'UCLTAVHeuoOyc4aFIA1o6Xyg',
#  'UCBlphb6_k7X1P28OCYXMsWg',
#  'UCYq9VOkrH3uv7IiWcDKm5zw',
#  'UCcWO3AqiaRqL8XoKUuLVO8Q',
#  'UCyfuXve0-iSw1Pbd1HRbDAA',
#  'UCNZGCCw-VV46OvUmXFqgvVw',
#  'UCOrS4ObeJ08FmsVG9Fwhmsg',
#  'UCf6AGqO98eGk11nfazociVQ',
#  'UCG8HkD_BXy6BL1mi19BIpHA',
#  'UCPgfM-dk3XAb4T3DtT6Nwsw',
#  'UC42dYnRlAA4r56cyoRctuTA',
#  'UC5UNV-eYBiiOs9QvYilDfyA',
#  'UCB-KUvceivlnd9H4NlbMRiA',
#  'UCbiAPS_7fbdY8X_mSeWO5QA',
#  'UC2C_jShtL725hvbm1arSV9w',
#  'UCTOoRgpHTjAQPk6Ak70u-pA',
#  'UCxX9wt5FWQUAAz4UrysqK9A',
#  'UCdTg9-VDy4GACVDZg-tdWuA',
#  'UCcabW7890RKJzL968QWEykA',
#  'UCM0--k8uumfySc926W-ydlg',
#  'UCbwthJmjmX5ZhuhyBp0otqw',
#  'UCCWi3hpnq_Pe03nGxuS7isg',
#  'UCeQFANvuwl3LAu_5HixB3Ww',
#  'UCr2TgqpOrU3kUTkVy5XoLow',
#  'UChknL2ihNgn_9d_i12cuzKQ',
#  'UCF3hdOpKtB-5eKyWe8spKuA',
#  'UCEp6S28ctSr4C_pBkP9ONTw',
#  'UCONVcfduH4lQAUdywsbHpqQ',
#  'UCQbUlYFhjEkt8CnbwDhpcow',
#  'UCHyu2gwfAkOXWroIjvxVUCg',
#  'UCzAF54cHk1ZO82af-8E3qOQ',
#  'UCjDHKp8AGNucJmEBMCk0NGg',
#  'UCrtPXCqjm9c7nqgJL-vBSZg',
#  'UCJCweGNQ-YNMt5HXY-TmoYQ',
#  'UCfao-LwRY1gf61_PdJ_RWQg',
#  'UCjGRWOVSpb7jGrhUh5XgRBw',
#  'UC5ASIl3Js_XSsb95sedH5kQ',
#  'UCTQuKo8v0PaPCvk5aRxc_Yg',
#  'UCIGEBB32IQdzLOhEtlSP06g',
#  'UCx7mvQguzz34ljqecZ-WVkg',
#  'UC6X3FnXCkALmhtmx_wkfQkw',
#  'UCFxKQX0tfkGSMtqHHD4IlKw',
#  'UCos_WjZSSpb2YH9M3YLoVug',
#  'UCrJrY9gMcbRL2APnFCXiuBQ',
#  'UChELZ_JMGNYuxObfrXoER6A',
#  'UC14Awgh6H83EzYGP-0uZkPQ',
#  'UCkVD_UAkZ0x_U_GbNP98JGQ',
#  'UCqrILQNl5Ed9Dz6CGMyvMTQ',
#  'UCl9StMQ79LtEvlrskzjoYbQ',
#  'UCbg9O0JF3rVKev6wpI5_u5g',
#  'UCmNXJXWONLNF6bdftGY0Otw',
#  'UCTXiHVtLmYCRr_xGoWeefqg',
#  'UC0e3QhIYukixgh5VVpKHH9Q',
#  'UCUwREhIG7cNAELA4kgLYPaQ',
#  'UCFK6NCbuCIVzA6Yj1G_ZqCg',
#  'UCJuhCGFakg0M7O804pzQaoA',
#  'UC0Soz-h9mxh-QzAs5_rJ4dA',
#  'UCJyEBMU1xVP2be1-AoGS1BA',
#  'UCc8M--6NmH2x3jrNX16hYuw',
#  'UCkq7wuK1UIqFLVAk-dfuGeQ',
#  'UC2D6eRvCeMtcF5OGHf1-trw',
#  'UCeVMnSShP_Iviwkknt83cww',
#  'UC5CMtpogD_P3mOoeiDHD5eQ',
#  'UCflFbG9kh5ZRcVl1TvzDCPw',
#  'UCZ-qVFZubQ-pVHc9SQ9HjzQ',
#  'UCT7YaGWYmKtcu53NkuB59PQ',
#  'UCPcSrnFKQQNAO5DvYZkoL9g',
#  'UC80PWRj_ZU8Zu0HSMNVwKWw',
#  'UCaj6HRoG3Vlr0YaAF_4Lwig',
#  'UC9tkvx7rS_pg9opmI2O3SYw',
#  'UC9EM16FgJ0yxKW8j9NBpOyQ',
#  'UC0-kUBU0jMYCr65s2PLygbg',
#  'UCqK_GSMbpiV8spgD3ZGloSw',
#  'UCPej7zo9oC14YDDy0gZX6ww',
#  'UCAeJheOWuUrs00ZPnUaOA0A',
#  'UCDrf0V4fcBr5FlCtKwvpfwA',
#  'UCQgY7qMRfckOZDKHuHlvOQw',
#  'UC9-y-6csu5WGm29I7JiwpnA',
#  'UCn9YQVWevSjx3kjBRjt6yrw',
#  'UCqsWHG7cl8ra7aaaAYcq4Mw',
#  'UCUlONbjGcI8fh6OfYNHKGzA',
#  'UCHb00yEZ_yY_inLGdSBa7GQ',
#  'UCJFMlSxcvlZg5yZUYJT0Pug',
#  'UC0AtH8WBx4bf1S73wXV1N-g',
#  'UCGtbVv_ACgV7difdVZ92NMw',
#  'UCZ50rYSkYQG31YDEJm9Di_g',
#  'UCX6b17PVsYBQ0ip5gyeme-Q',
#  'UCSTTf8qG_t3ax8eIARcGw8A',
#  'UCE1_bZxswCCARhhVeSQLuew',
#  'UCSxjMb2OIobraWIljViiW8w',
#  'UCI7M65p3A-D3P4v5qW8POxQ',
#  'UCrWvhVmt0Qac3HgsjQK62FQ',
#  'UCRXqBacOG5b_2boz7T-HVzw',
#  'UCSO5KA_gEVAGtLA5Ym4Oocw',
#  'UCr1e4Ny8YHVA8TiRZK-ppXA',
#  'UCKjagJKCdDwiHAtbtCv8AoA',
#  'UCxzNPaToGSLpTKBYxOscZqQ',
#  'UCN759gKK9xewnTkSG7fVs7Q',
#  'UCpLKqC4BVf57nLX6ew7Omxw',
#  'UCJDWj0B_-Rzi9tdemSzl-bw',
#  'UCW39zufHfsuGgpLviKh297Q',
#  'UChZKqB_5RTTgCbKDpQkyk2w',
#  'UCUfWianbIoAb9ji-XrMtTcw',
#  'UCdNj_PP__5kKtjZabuEjbqA',
#  'UCWXYDYv5STLk-zoxMP2I1Lw',
#  'UCjSOwkYUtTDjDoPczoTv_Hw',
#  'UCA-mWX9CvCTVFWRMb9bKc9w',
#  'UCIgdMadtFZtXER3tcNcuQkQ',
#  'UC3iyLcDyYxk2nN7M5DsYaYQ',
#  'UCAg98wtgZm1nEVTXGx3XShw',
#  'UCncI1vqW0PHWUulTh7fD8_A',
#  'UCzL_0nIe8B4-7ShhVPfJkgw',
#  'UCpbMQO3wyA-vfYiCiIGB8Iw',
#  'UCPGrgwfbkjTIgPoOh2q1BAg',
#  'UCUlCfM_fqQedxqGPqLVPuGw',
#  'UCCB6USgNTyGiMn2tChTqpUQ',
#  'UCTS6MKBP4KA7V4FQI-j9_nQ',
#  'UCGVXtXuHVDBM8WIyLEX4sWw',
#  'UCEJ3Bv-zDYMmtACIyFo4nGQ',
#  'UCjnzUpn_3T7h9OC_YyV00Yg',
#  'UCTIhfOopxukTIRkbXJ3kN-g',
#  'UCxrT9QLqHx5fWeSaL8MoJLQ',
#  'UC1XLb_DoX2eNWGKjkh2epwA',
#  'UCTUvDLTW9meuDXWcbmISPdA',
#  'UC6cfHCY3fZv_msqKSvuNjSA',
#  'UCWq_JZB3uWvdhegKuNbFJrQ',
#  'UCldcv2KztSXrU9Hfl6S7s6A',
#  'UC-CSyyi47VX1lD9zyeABW3w',
#  'UCezp1ocO-_139HyS9S9GGig',
#  'UCIIhOkk0vC3ZIGg3CPBzvsQ',
#  'UCeNZ75tFE5I8o1yi35KAq0g',
#  'UCU44weIqNyzdwvLVR6Aaveg',
#  'UCv90NdTyTp7ZPPRvvSZaS5w',
#  'UCUvchJEJp5gfft0eSoa8k4w',
#  'UCye3MwiwYaTo8baXfwxZ5ng',
#  'UCDVcypCpv96s4aVbZBm4ABA',
#  'UCEgQyQPkQIhoXf12FFKSYgQ',
#  'UCUOMtzQmEmhIAF8G_cha_Xw',
#  'UC00DrQVoCf9Liv4D0KV0rGw',
#  'UCzrLk2LUAdJAnF04Nb_6B_w',
#  'UC_GFrBVMkHRqL1_W0uu40Fg',
#  'UCiPW7OlzTfQjR_vLlkYPZCg',
#  'UCPHve6SlWdX2ZTuxX4uiZdg',
#  'UCbojg-FJgI1L6iLWUzgcsww',
#  'UCR-foyF-C6VuAlwy3KZMkgA',
#  'UCfvIqreCk628yB9mp3e_ABQ',
#  'UC-UongAkpO6ZtDOPdbMq09w',
#  'UCHMiVk1X8dT1f_YCLFY5gdA',
#  'UCtXRIIGnq4rU8REt1vAuttw',
#  'UCbjozK_PYCTLEluFlrJ8UZg',
#  'UCCAW1leDXKWsjMhrMCW4JRw',
#  'UC2LdhwAnowNWor0KUZ7OH-g',
#  'UClWTCPVi-AU9TeCN6FkGARg',
#  'UCH9qJIJuI-MY9nHhFyjfbaA',
#  'UC4EX8zLiBUalk704IX_zu1Q',
#  'UCAbIzdnrncJi_aEchwltNYA',
#  'UCZM8XQjNOyG2ElPpEUtNasA',
#  'UCmcxOHjLnA8O80QViI982Mw',
#  'UCc8q4B1bj-668LMHyNXnTxQ',
#  'UCij4PbZVBmFbUYieXQmt6lQ',
#  'UCKS34cSMNaXaySe2xgXH-3A',
#  'UClPVvbHAFrQAezYF3uzSGsw',
#  'UC8A4Rd-bBfX2Etc0Aoa8JLw',
#  'UCAQjmY2DJqwU3Eqz0oN83aw',
#  'UC6PGl0rdTbOf3UfQ9PfTiHQ',
#  'UCmw4mRoGmTAvcZnYJsq2bJw',
#  'UCerWGX7_E2fR2spWSxAPwog',
#  'UC8NQS4iripeTvsbaPa1ctKQ',
#  'UC98kynF2a0WYUKZ4_Wa9TdQ',
#  'UCHPF63oIn3xHzJ2GCB4uG0Q',
#  'UCZj4IZIbT3irBiS9xICCBuA',
#  'UCgGKaobxMvgkWs-KGoSZhmQ',
#  'UCK0gwZDfvx-5jXfhi2cTCdA',
#  'UCU3PwUp0RENg1dLlldjjx3w',
#  'UCOqpyBqmT-eJsMinC3ggmbw',
#  'UCYD4oFRKB8rRQp_LVMYJYog',
#  'UCm1KEjDfLyH43Lv4PCCS0ew',
#  'UCmruzXXUBMADovuNtsDBYXQ',
#  'UC8lxnUR_CzruT2KA6cb7p0Q',
#  'UCuLyyxpAOqEsOYiNMapZNKg',
#  'UC6E0xxW6o3QacO-rx71x26Q',
#  'UCwr-evhuzGZgDFrq_1pLt_A',
#  'UCRE30aq2K2cviVhO7PTuxTQ',
#  'UCfVm3KgECdX5wXlNlHNpGQA',
#  'UCjFoVg7TXcs2UD_fd_hh-mA',
#  'UCZBfu59WmdZ5P7__xAEN4Xw',
#  'UCEBVWimd2E-2YaWxzxZICpQ',
#  'UClJPdT106jaiV1TrZ1zfQtA',
#  'UCsU1JlQCw9_6fhzu7q1xXFw',
#  'UCFU9Go20p01kC64w-tmFORw',
#  'UCelp2mfpa0fors7HePAodoA',
#  'UCenEYndxAXRzZoWAhhq_7xg',
#  'UCXhiOv9VT_0XSnVXyEh4pWw',
#  'UCHehtPkTMXl7XB6rd573sWg',
#  'UCO1aucBAJgFR8odzfXOZ5uw',
#  'UCgoyBmLOMNWmsiVkj-MezyQ',
#  'UCwVBLXAj0pfOb3df21bBtyQ',
#  'UCjm_qVkCPjOVDz9BWjNqO9A',
#  'UCOWFKaCN-rzmYk502JFWnqg',
#  'UC9kKt-14c3tjGJSO_jwPHnA',
#  'UCYN4GkclPID4hXTs80-6y3A',
#  'UCIbVc86kI5Jnq4Ez_8_hhIg',
#  'UC9fDmdRmgzu5jQjV8yEsDIQ',
#  'UCTfqCtzIVBx1avoUQIZWFOA',
#  'UCGdPm5Aq081vVD7ih9jZf6Q',
#  'UCMwvrr69fBH9bjAHHtpTxBg',
#  'UCzV128kBrInLAYzBxVINyXw',
#  'UCsW7wxIr1vVKrDy82Gtir1g',
#  'UCxfZhob3IPZjo0ZJyJR_DRg',
#  'UCn55ORF262PHJqV8sXApcCQ',
#  'UCO8mdBdlvR6QCClPgv1NvUQ',
#  'UCVN7crOz9pUcZec9BYbZFaA',
#  'UCN7dywl5wDxTu1RM3eJ_h9Q',
#  'UC2WHjPDvbE6O328n17ZGcfg',
#  'UC9PpCs2M4dLw1DVojXZVl2A',
#  'UCd5q3wSDbJ0mIm5lJN3F9ag',
#  'UCZonap26CSIMtVKesNQN4dw',
#  'UC36qgdaYNkwCgjKjgiCqxeA',
#  'UCYJhto4Of0p8eKKxmB2un9g',
#  'UC9PC0y4EO7NxqXIE8xH0YIA',
#  'UCo39EOedHxiMBRoPwshkf2w',
#  'UCxboW7x0jZqFdvMdCFKTMsQ',
#  'UCUJGE6eXB1OXPXbx4CXzTPA',
#  'UCPpRfYLhUU2gi3B2P8cdt0Q',
#  'UCurYxozQbvKn-oNUxNJh45Q',
#  'UCDLEyi7ibFBh9TPvwEHI5Kg',
#  'UC0JB7TSe49lg56u6qH8y_MQ',
#  'UCOEMEjL1GBJ41uCWur5VXWQ',
#  'UCJihyK0A38SZ6SdJirEdIOw',
#  'UCRPMAqdtSgd0Ipeef7iFsKw',
#  'UC0RhatS1pyxInC00YKjjBqQ',
#  'UCNeF1FuCGYsBEUnOxCk9Jnw',
#  'UCphOzyQUeVHsmUOGy1f3-cA',
#  'UCCLwN8tru67vMTVP-FayOwQ',
#  'UC-ZZjHr4nl5t32pFl3Sqf0A',
#  'UC2YywsQt3Tq4Tc2it-kAgQQ',
#  'UCWOM-v9Nl2mGem5PlktFLqg',
#  'UCvM2ieGvifxNqCo-af6eqHg',
#  'UCoPJeYPmYF_5CX9gbPHAG3Q',
#  'UCur5RceRuh24CGQdTRtcFwQ',
#  'UC2ldcEtbR7cFYadgrnW3B6Q',
#  'UCRcHDNWSvYi9aL9OQ5FSoNg',
#  'UCKuEZ20jRcPMyI3jAWRuzpw',
#  'UCy4IMW5TUi3oeK9xWZHspPA',
#  'UCgMYvTNW4dRf04vm4iDANdQ',
#  'UCrB7UFnkosBjAhOg3a9NdWw',
#  'UC6Av2xW5pfCmFtseY4uWzzg',
#  'UCfmqLyr1PI3_zbwppHNEzuQ',
#  'UCrZOiJyMbXpZ8T5snCIJaLA',
#  'UC6-4Xy3oKB0z2Z95HtIiIbw',
#  'UCIfO5AQxT9a0yzOVaPSx-VA',
#  'UCObs0kLIrDjX2LLSybqNaEA',
#  'UCiv_dpEdqEJKPAdc0wpFAkA',
#  'UCJublDh2UsiIKsAE1553miw',
#  'UCnGPmAcR-LCVm_TPxQ633Xw',
#  'UCqqRJQATiPt9Pzy0h1ZqDRg',
#  'UCik2f2SHJX9y8yKv-WoO93g',
#  'UC4Gb9HiXn4peb06WzOKaBGg',
#  'UCpd0xtuhhWwUug1bk84usiA',
#  'UC_4gWKPs8amHyq2ccnv-Mcg',
#  'UCj6owuAZrJNsjQzc2ZtILIw',
#  'UChUsovhBBfoCyYEeYLdOuCQ',
#  'UC4ay94l73_FLJ_WJkIqLnSw',
#  'UCC_ycdL5_Rw9b6UEmtmUE3g',
#  'UCT10tszdK_A9faHe0qGnuqA',
#  'UCUPH9adyxLAoEPqCUA1v9Yw',
#  'UC3abfTxNmYKy0U5HfOSL9Zw',
#  'UCTlSASzpspvFbRl0RhaJNpw',
#  'UCWX0cUR2rZcqKei1Vstww-A',
#  'UCKq9E-ge4jMbeX462kI3LKw',
#  'UCUaPVV_tQDVKK5fbvh0aNuA',
#  'UCtSgvR0074NWsMEk64VxTzA',
#  'UCk8n46m74K5XWfdeBzOXDfA',
#  'UC1Up4TuDvGZraQUj9vxUaxQ',
#  'UCl4nXWTkPOqmKlEmIN5_TJQ',
#  'UCwYk9fLWPGWBkm-NxqtS9qA',
#  'UCIepU6JSIqlO4uPvHP-5v7g',
#  'UCpM_g95uzZ_OyhgukvrbbiQ',
#  'UCw3jwyEmeiRdkS22sOjMsSA',
#  'UCDT1VphGzcihpW362i57yPQ',
#  'UC-hisIZlnsImYe7Y5M4qVFA',
#  'UCA0kKOoNN6zDP0xxw3d5y-w',
#  'UCbNIC-svDbtUOH2qsLnPQPg',
#  'UCxXvigD355ALunI2mg8VU0Q',
#  'UCVeuau7DLrg7zlAjxxDbdww',
#  'UCXhAGLH8n9IZiqpC6kecEmg',
#  'UCdCWCSEuDCiblkAsdQ2rqZQ',
#  'UCTdISCnEQ0YNKaoB4kxpANg',
#  'UC1no2qq4VcJMWN7fpd8Bc5w',
#  'UCKWaEZ-_VweaEx1j62do_vQ',
#  'UCtzK1Q-jw4aOgzLXqQpmybg',
#  'UCV1gEIO7A8XQYuLt3-8HO5g',
#  'UCT3Bo4EURi2Q2dTWQlcHTdQ',
#  'UC1aCj0rC0LwnpNHAvLVHRYA',
#  'UC7Afb8i522ErAUMk4RwPx4w',
#  'UCmdFOQhLHsnY-JFwEMC7nRQ',
#  'UCUqNROqVf2yfIuHQPvPQVqQ',
#  'UC0yhMlbuY4GdG8rDhFH1KnQ',
#  'UCQ4FNww3XoNgqIlkBqEAVCg',
#  'UCgxMiiBKk-xYskc2KNLiBTg',
#  'UCTjjAn3hNXUhIxPmJ8iAZdw',
#  'UCNzs7V6xG5GO0i_i6Grojyw',
#  'UCktMIWomeuj4pwvBb-OBwMw',
#  'UCvGKLK8Qhrwdv2npwUdHntQ',
#  'UCk9P9FH37GNzqIcP_4WcUEg',
#  'UCCktnahuRFYIBtNnKT5IYyg',
#  'UCMkzUiUrvYp_BZEvlmShc4g',
#  'UC97qxGRmPsyfV0Miz7AxU2A',
#  'UCP2jbHVWC5QLY-_1IJacp5g',
#  'UCKc0J2A7znmiFwIjXUvmdvw',
#  'UCobgOt3poNKlml3Y5TnVU8Q',
#  'UCMNDGkruvZQtOqHIoPDC8GA',
#  'UCXNCcqhVkygHfwCSkpSZVHg',
#  'UC4b83HZ82cB8HpyWNJXaA7w',
#  'UCXfywPIGeHlataAi1hsB1wg',
#  'UCxVxcTULO9cFU6SB9qVaisQ',
#  'UCkv9W4kwjpqbHbh51d9nzhQ',
#  'UC0QTNpNFbVTkI9AwvsXA6IQ',
#  'UCLW5hBjqTfZtGwaN1MRcTvg',
#  'UCHpMmk47IxdZc2tnc3TbuaQ',
#  'UCCDu1S_OmR5XtM-AzL-_U1Q',
#  'UCBgPxTfodXMa_zavgl0DX7A',
#  'UCmXmlB4-HJytD7wek0Uo97A',
#  'UC9-QG4g0f1VxbdZztyt7vCg',
#  'UCtle5XVir6ahnsYcgwXeh_w',
#  'UCwAnu01qlnVg1Ai2AbtTMaA',
#  'UCfLLa4mTtaOMQ3GMmOOXOXw',
#  'UCM-yUTYGmrNvKOCcAl21g3w',
#  'UCIm6PH37h6wUs_q7GR0LNtw',
#  'UCfXUCESXq0p0PmEFfHeGU9g',
#  'UC2TUZnaGIN5F_1mE6HWDHnQ',
#  'UCYdEAbC7JrC8fBt8OoDwoJQ',
#  'UCVeW9qkBjo3zosnqUbG7CFw',
#  'UCpIn7ox7j7bH_OFj7tYouOQ',
#  'UCQM_HxoKmza1simMUchYfVA',
#  'UCx-RHGMb4Khxzx0wp83PMhA',
#  'UCnzxPyNnn8jk4bHFk3JUBhA',
#  'UCsQiYDzi0UtpdDIe7_DpcLw',
#  'UCg_Jd7CKe5D5AFeHmwXhmNw',
#  'UCmKaoNn0OvxVAe7f_8sXYNQ',
#  'UCD7xzypHmCAj3I_kwHHobOg',
#  'UCqzK60-oUOEq36uU9B1MMUg',
#  'UCGpsgNbzdF7BECCVbB1COHw',
#  'UCB50SSUsJ-gqHoPsVfFJgQw',
#  'UCLS-WEG1Tukw18E95_Gtkew',
#  'UCRgn-SAQZa4I41zLH03LoOQ',
#  'UCjhdBsNZvpbgPlnwNMHEc1w',
#  'UCtimfZyjzmkpOeLI1s88hcQ',
#  'UCHRZP1s9cGDCotwZ4gzeTDQ',
#  'UCn0SshozrPjtsEWCzWtS78Q',
#  'UC2MYZHG8a56u4REI2RedtRA',
#  'UCIn_XzWVxOsQAyx5rNaLWbg',
#  'UC1OGsU7cCOlzqGUufsxmr5w',
#  'UC6uTM-tW9QNSmBisHYl5zqQ',
#  'UC4d4sdHCXktRTVtkRWW8tYA',
#  'UCBF5i6PogoMwnoAP0LFiCmQ',
#  'UC5AN-yLpjexjnj-rgvPsMMw',
#  'UCYH1yre7R1k2dYPaz3Zye7A',
#  'UCfXzRcRPMHw_AF7EdRtyiJQ',
#  'UCpTLKPsVLtxz30S7rVt5F1g',
#  'UCqPw78XvJUKtGiq3TzAcwJQ',
#  'UCp6Feo9X6OxxnVxGnqgd-Kw',
#  'UCJZv4d5rbIKd4QHMPkcABCw',
#  'UCSQxOdeYx-jnCs2fdrgRz2w',
#  'UCgjfLFbkFt1ksAMu0xZtDmw',
#  'UC1XbXsp48-VkYbNBJQ1YvOQ',
#  'UCKeeYaPkdEAzNed4Ql2UkOA',
#  'UC51g2r_bWOQq-7Y-VwU9sYA',
#  'UCwb2Hyxn7C-qS42iEqs-RXA',
#  'UCrUc3p2rJblDZCderP1k5pA',
#  'UCIf6t3gpKr_D46xuWlj9UAQ',
#  'UCA6yfpYhy5sWMjRGOT-OAIQ',
#  'UChTx7DYF0j2mhoIPK0FgErQ',
#  'UCSWj8mqQCcrcBlXPi4ThRDQ',
#  'UCBX_-ls-dXuhFNSWSXcHrTA',
#  'UCVoVneLJ0pJZ5O1irMkzwyw',
#  'UCXZvhCBxTSvPf38GN0NtKiw',
#  'UCtCH96LBdX7u1UNZA68vUuA',
#  'UCNU_lfiiWBdtULKOw6X0Dig',
#  'UCjWY5hREA6FFYrthD0rZNIw',
#  'UCCDDZ73SMXb3xp-hjMHngXg',
#  'UC329xxxQBQGX-Gp7EVBWUkg',
#  'UCsXVk37bltHxD1rDPwtNM8Q',
#  'UC9TIoIaBbsSQiTyNY8WqYGQ',
#  'UCPkctgt1mTeJWTGj4tq4dPQ',
#  'UCGC8xwPqAAso4wRXkq1wPGA',
#  'UCwVRLP3k8WBM6zSIspcbdbw',
#  'UCVOTBwF0vnSxMRIbfSE_K_g',
#  'UCGFNZxMqKLsqWERX_N2f08Q',
#  'UCwvaQ_T2IyOvNeMBchvhFlw',
#  'UCMfRfVxPrb0mMRzzfi6r2Cg',
#  'UC5TQ0_ORokxOHLcybp1QlNA',
#  'UCRU2FboU3kpwP4QqKPSmnYw',
#  'UCz3dFKn8ne4HfcHMtiRShHw',
#  'UC4zyMdFPl2uOPQLfY2p3xrQ',
#  'UCKCsVSA5THlkHbnkZTPm6-g',
#  'UCNzPBf0DNhmwzpEaPHcVDUQ',
#  'UCU9ny7XPs7f2EEqZb1jHicg',
#  'UC3b-OgZLEXmcV6iaqJIIBbQ',
#  'UCZaTlaJq7K3sywTuGntvbVg',
#  'UC7geKfz2-IH0rsgRBtHTm0g',
#  'UCttZMJCI9L9PbfJkQw7o-0Q',
#  'UCKVdr_Lro6WDKigrKQxhNlg',
#  'UCF-uUxo43IPpnEwnR62WGlA',
#  'UC6EiWxE3xKKCrheTCZ0tCwA',
#  'UCfFDKOfEegSy4-YwGba4Taw',
#  'UCXPq0t4cR6tbq05zGSJ9Xmw',
#  'UCeoXXZ2u_cUQ6CJ-oXpss9w',
#  'UCxF6vlGt1cSVhl0bfzhx_Cg',
#  'UC-ntE_GnjjiUuKYqih9ENYA',
#  'UCv7B4-tF5Cvvk270mcBNclQ',
#  'UCdbUlVh3w8JwltHaYlLGGSw',
#  'UCtbzP6TBHpsFwP7VSy8VvXw',
#  'UChJecTwxnuK7mrD9sCdOiiQ',
#  'UCQ-j0OZwjuKR0VQHJVH-tVg',
#  'UCjS0rHVOt4YjlijDaiE-iaw',
#  'UC_hv2IPy6vSLAJkJnOSsOrw',
#  'UCJtUOos_MwJa_Ewii-R3cJA',
#  'UCxCcu9pet4dljrBLf8R5nwA',
#  'UCnywImTXDH16OwNiINV4gOg',
#  'UC3owDdLk7HL1dyQnkoBuRew',
#  'UCui4jxDaMb53Gdh-AZUTPAg',
#  'UCoaAe6ighxrzJuHeFPAlCeA',
#  'UCprZwzk_Ju0MEhQnbC-VZnA',
#  'UCODuWzVyACyCHSWgxOyVBMA',
#  'UCSrLdrCGaVWDSUyrTgqgmOw',
#  'UCW2XViiENiDImgyWigOH34w',
#  'UCaTV8HRt51_H-LHHoiInHEg',
#  'UCBHSt-tJgmAhcPJRTQ-AdXQ',
#  'UCHDWAGztZO9SqdeBz7Y0EJg',
#  'UCz7f7uZ9HWVYQRvxYxoha8w',
#  'UCN0QBfKk0ZSytyX_16M11fA',
#  'UCEBb1b_L6zDS3xTUrIALZOw',
#  'UC0wOrSaO_sBGGU9Jderpk7g',
#  'UCyLbObwJPbv5ZfAWAZDdGlQ',
#  'UCCYOVWKfD_sltew1MyFFe7Q',
#  'UCMTlgnK24X_a_UQwYQBNchA',
#  'UCOeCHYu0CAN_3FrWYd5w3Hw',
#  'UCY6KjrDBN_tIRFT_QNqQbRQ',
#  'UCtudk0sp6ivpR8unwuOR9HA',
#  'UCPi23Ql765_5smMj2-r0X4g',
#  'UCndJsCumRxIZJ2W_i8y9dxw',
#  'UCVzgTh8i9W-UtengLs-xytA',
#  'UCAm_DFOoK0uXb4CF6xIcNdw',
#  'UCQYO2p7JMcCp-9xIZxGP2Sg',
#  'UCAvfQvxU5Ff6iGKLJaS_Ayw',
#  'UCnkEhPBMZcEO0QGu51fDFDg',
#  'UCHkzp52CldSPZqU5T49mOnA',
#  'UCZbdK5v2VIj7qG6s7y3nDdw',
#  'UCDZPlN6Mfj1eDBD7LY9GcrA',
#  'UCBZtviXtzxiOopXmDz5NZPg',
#  'UChXeB7ef39aG9JgW_R3mv0g',
#  'UCiGyN_nCYTS32QxxS51PE-A',
#  'UCpY8Ct4p-ThbDU67uP_942A',
#  'UCAA9z8nJQOq197l7nCbxTmw',
#  'UCFqInmJykuVFKzi6uQl_ySg',
#  'UCkqcFoRpgSYn_TVZlqq3qIg',
#  'UCisy6taOAeLfyaCqcMQDfig',
#  'UCB_IfFmew4M6kgeo6yp18Nw',
#  'UCNxUdsuH8-kEGIwSD0r8RhQ',
#  'UCK841qw075u5p2Y2Biy0WLg',
#  'UCkr-unKyg_SiEzUwUY_uluQ',
#  'UCV_WMc6wSrrYvCio1J7VwIg',
#  'UCv4Cq5W1d5-aIEupKYjZTTw',
#  'UCUvvj5lwue7PspotMDjk5UA',
#  'UCYYIY0kLm0yEUJhzQV7-h5g',
#  'UCJUmE61LxhbhudzUugHL2wQ',
#  'UC9KGtR8cAAx_XEVQaYeAX8w',
#  'UC5Ho4uTyWaKzi5H2Lwl5yHw',
#  'UCT5lhnIOkq6GhoilSAo-XZA',
#  'UC3-CvNO8pZJYITGApuW83pA',
#  'UC3xlS5T2M6we94bCsYneNXA',
#  'UCHoBKQDRkJcOY2BO47q5Ruw',
#  'UCon-pJX2rzbu8gXvEHcCaZQ',
#  'UCde0vB0fTwC8AT3sJofFV0w',
#  'UCPg1nvqDKLj38SPyeFWVxwQ',
#  'UCpAhT0u-Hq6qj3H3h6BYR8Q',
#  'UCkKemMaRnFPlNLHZ0zOYfpA',
#  'UC2XjBkW16jGLGSEF9vo4PDA',
#  'UCiuK-QMCYaENSJ50leNTiog',
#  'UCoKvdSR1Xhol5eGl1Wn1VgA',
#  'UCCQEK0dldcvHx-DPsBw_trw',
#  'UCoWt4xP3KVx65Qrb_HaGyDg',
#  'UCoOHTipX1_cNiC9seIPfUXA',
#  'UCbzVRTkX3bzNZuBd9In4XyA',
#  'UCboc79_6B4Ydge3lkulCwYA',
#  'UCcM6uK1CJk9dRJyTCfMWDvg',
#  'UC-MQclc03gjp0d8rTjma1ng',
#  'UCWoO921LC7bp-H3Cpb65z4g',
#  'UCmFeOdJI3IXgTBDzqBLD8qg',
#  'UCS-2gkmy9ae-fBgsj-ml9oQ',
#  'UC7AyUr6ra_E_IJQuaQoI8kw',
#  'UC_seWBB7USKanhHB4KbWXKw',
#  'UCxPD7bsocoAMq8Dj18kmGyQ',
#  'UCwrC3EiyloNb7GQW7KXVcHw',
#  'UCSqUkHcyd1Syv_dkviuKteA',
#  'UCZ1lcpLlWDVeBvXcDi0b_lA',
#  'UCrrStJLqfMdS9yUoC7qzaXQ',
#  'UCYUjYU5FveRAscQ8V21w81A',
#  'UCCcrR0XBH0aWbdffktUBEdw',
#  'UCdIAr2sxtaKgah1UGC4dFJA',
#  'UC_0xBUVs9v0xVul5IyvxHjg',
#  'UCkGS_3D0HEzfflFnG0bD24A',
#  'UC_CdyYnOzkWwr13C6YIfDEA',
#  'UCu6dZ7Tvlhw1BkUUDWJngqw',
#  'UCJsUvAqDzczYv2UpFmu4PcA',
#  'UCXJqQBTenQuLYFEpi6ag9lQ',
#  'UCxO1b7z0lTbZFahm-7L3BGw',
#  'UCJ3J6JsgRIq0S0tQ_uE1Xnw',
#  'UC9pSwOKio1gWGccObXsyu4A',
#  'UC2y8LIDRAfpgHoIUlggj-Ew',
#  'UCrmsp2voP5agAXWHvEPvxsg',
#  'UCzaYfiBHJgmx6WbA7UXoy7g',
#  'UCnnBpJ_fjSfS2BdNJce8UBw',
#  'UCl-Zrl0QhF66lu1aGXaTbfw',
#  'UCnCrCxn9TvB2ZLJwIeeKKbQ',
#  'UCywhh5mhHMqsf5deT1nJ1uA',
#  'UCdQWgFsJaVSreMxJIS-9oBg',
#  'UCrsRPKM9rUtTHVJ85VUjTPQ',
#  'UCa9FBCj_ZcKU6OBtLsQJXpg',
#  'UC4FK5DEcMLB3CyJcbJfZEJA',
#  'UChlRjY6jnr3X2qBBRUYShTw',
#  'UCG54vwVpmt6U-yj-RaGlxdA',
#  'UCXihi0rkG9rMRWTFVTjdLlw',
#  'UCs45sHlKtDMxhPKt1Pjdevg',
#  'UCVe8CMJF4caRzuckVYV8CaQ',
#  'UCan6AI1ASU12XvVTom1WglQ',
#  'UCU0RB5iVFW3LbmshiC_Kf-Q',
#  'UCDe0VhDSxfozY5MRnDjIInQ',
#  'UCVhLjuXs5z5ZYJBxpeRbI1g',
#  'UC16Hy0D3KBn9xeMyL7jQAjw',
#  'UCLxuRo-9qQjd8Lbq_CXqtZA',
#  'UCDbobv7_LYSJzUVwmMR-fRA',
#  'UCO67XybFBWeMSw4SLCu2mSQ',
#  'UCjuxbyEZytRdXptCYJzeXgQ',
#  'UCFsfJyLwNP00MZ8kp7jVnAg',
#  'UCA1DPRW3KGTx7PrvrowqgyA',
#  'UCbmOgzvvDg60mXGm9t9Ad5Q',
#  'UC3xNuN9OROXbS_XjEiXzQyw',
#  'UCRVzEriB1B2JKGpsLpL-uNg',
#  'UCcyogDO_BD5HS7YlySkTELQ',
#  'UCMZfp1_wquyegVY9SoER0Nw',
#  'UCSVfXe2ubP_Ld1GDygTvT5g',
#  'UCFBYHxWeomOYh2Y_0BX0GAw',
#  'UCSTvN8DMiKDH21oEwIQNYKA',
#  'UC88yq_cznQoE_vsIo7NJVGQ',
#  'UC4K9hTI2xhhWdNrFt8h1CVw',
#  'UCDxq8zhHpdyMzcDOCC1ErLQ',
#  'UCyVbhVGzfL9tW9Xc1FkYsbg',
#  'UCLi0F7n6_PO5PvCCrTDUFHw',
#  'UCO9Q3cPY4dKabwGrZ9rJx5Q',
#  'UCsk2Pj2BnDhILR85qoV2Vhg',
#  'UChCAb299FjSisWATg0IM1sA',
#  'UCEciEJ2j2wcUa2QUtWpZbXA',
#  'UCIxi6j0TECM_yhfCPYaJ6Eg',
#  'UC1CnRvokdIDsQMJS3p3Mrjw',
#  'UC15TAExjKx5YUFiQXUgy_1A',
#  'UCa0mvXpcwOGCBOdUBaIFe7A',
#  'UCvmqI5F-hOdYV9tj81mPlzA',
#  'UCcuaQecz84wTuxKzr1Yxi4Q',
#  'UCg_3adUY1s2d_eZQhu77smA',
#  'UCGJAcveK9o1xObmuR_bFhrA',
#  'UC5fs7PookxGfDPTo-RU0ReQ',
#  'UCxlJ45KjG4XVcQ_hd8j227A',
#  'UCfGkxkJDQG7fBbX9mBtYz0A',
#  'UCDcrzjRkgrhKocTgLwBZpMA',
#  'UCwCtLnoEf85oyoKx70IptsA',
#  'UCm_vlZ4rLGzSJ3JuDejHdQw',
#  'UCPP-feIQ3HPGvngcSmtqE1A',
#  'UCd2J-PizcFDxWHBBfRkp38Q',
#  'UCKNTZMRHPLXfqlbdOI7mCkg',
#  'UCMrvLMUITAImCHMOhX88PYQ',
#  'UCXasJkcS9vY8X4HgzReo10A',
#  'UC_-Z0YYZN9dAw2xySgHwI0A',
#  'UCf9T51_FmMlfhiGpoes0yFA',
#  'UC55-mxUj5Nj3niXFReG44OQ',
#  'UCMEbih2k3WBsODB68WqwT6g',
#  'UCUFbQPEX8jzvvhUq1WnG_EA',
#  'UC3-uyUX8s536lUkrWwYvfDg',
#  'UCzNONYnPyGlqhuht8P4Kn_Q',
#  'UCVgOWXEyCmRPEVEerK_49Fw',
#  'UCHJCoTUB2-y7aElI_Xrnk-w',
#  'UC0MBD7ZJO2OhQ_D6bgsAoEw',
#  'UCrj6ws9M7PVCcBqKDz3Bucg',
#  'UCmHni5tWH0k3EyquYPFDzpQ',
#  'UC3LCokV1C_1HGI4W5rftmvQ',
#  'UCHSfoKXyDYgK_Ox9WDsKPXg',
#  'UCbfENehrv6SRfQLRNZrypcg',
#  'UC02mna0_opR3Htu0OM4x7Sw',
#  'UCWv7vMbMWH4-V0ZXdmDpPBA',
#  'UCs6nmQViDpUw0nuIx9c_WvA',
#  'UCZtfeqRvCHPadnqmmDf1IQw',
#  'UCtYC7AmigYX16SuR3jAGPuA',
#  'UC5g5xT_sZ0YO_tPZXTQhYKA',
#  'UCGsmwdySx-Zyipro53lpBwA',
#  'UCEq0oQsS-voRnSWbcviIDGA',
#  'UCB77GKNWbJKX8LxJxzMNk-w',
#  'UCodIRuNfsp09zPs1bFxNSRw',
#  'UCzDNsDnN55mXW65zSGAnHeQ',
#  'UCEAAzv2OBqxsSczKJ2QZyGQ',
#  'UC0lVlRRbmWcw9M-CHUqpRwA',
#  'UCLdrXqGujPV1ZJawyYRR5xA',
#  'UC9ocsRoOwj9tkAQNfUt8ZJg',
#  'UC68KSmHePPePCjW4v57VPQg',
#  'UC3Qe9c8dZqnjwcDD2vCZBKQ',
#  'UCJhn8ucrKssVSQmcDHlFHtQ',
#  'UCRbBlR65mBJ04CM41ZyIp4w',
#  'UCJgv6grOurQt7VerrWh9eEg',
#  'UCVNli1WMMljwc83Lqn-L9yg',
#  'UCWE8GMv0qRy3MuzZvx9fYxg',
#  'UC8hduN7MEQkFRbPafcY-Gaw',
#  'UCSJ0F94cWCv9mkm1rQ2-NwQ',
#  'UCrebGs3b-Z7JLKQM2YOpUKA',
#  'UCeJlRRXNtdx6HqXBFm7qfOg',
#  'UCgx5SDcUQWCQ_1CNneQzCRw',
#  'UCjNjebiJPAsVqGlG0Fh8SrA',
#  'UChxbzaVeQnEmSZtuZODfYQA',
#  'UCQPGMaiZ05U4DSs7VZIqnVw',
#  'UCm4eA46c6boHmPrD0Lp2iEg',
#  'UC6qg6j2gREJ7HjhNMwOS-yg',
#  'UC1nBZreWJArdFgiIu3BTeGw',
#  'UCnL8HkOfdjwceyT3x7h_-iw',
#  'UC29JcHD3XXEV4rxx3-TWHng',
#  'UC0HIbEF8N0mcUT7_u7sSp2A',
#  'UCmNAkARqTFvNoyxmFhKTS9Q',
#  'UC3rY5HOgbBvGmq7RnDfwF7A',
#  'UC0Uh1eHJLniH3yRiYJgtARg',
#  'UC5LPsrt_LivE-0SWmJfg-hw',
#  'UCIPZVAwDGa-A4ZJxCBvXRuQ',
#  'UCxladMszXan-jfgzyeIMyvw',
#  'UC0FBv8ckxw1hrZxbUm3G7hA',
#  'UCGMGlkdnRaYJ18SFspK9fOQ',
#  'UCuR8L5fK6ZXyApcL7vMcv0g',
#  'UCA5hJSW-X51Cz3u2fUWsjLA',
#  'UCy2rq3VkNMr1_iRhSxhQpag',
#  'UCgscS8mBsQZ5sFRkJIFWD7Q',
#  'UCZ3KGRwOA_uONNE_6VGG2bA',
#  'UC6GV9kv4vDs20lY3UI47Zsw',
#  'UCE7rqQvcrMTpMU3NF_66nig',
#  'UCkUCBUhFQEW43f22BERpIWQ',
#  'UCqMb_VI8SKLMyujXe5vUpsA',
#  'UCCl7cSGaMFkxoQqdPbbbauQ',
#  'UChd9BBD7NWmkbwhsmV2-XoA',
#  'UCAkyj2N9kd0HtKhCrejsYWQ',
#  'UC9JWnvl5ZjZv09F5RqiLptw',
#  'UC46vj6mN-6kZm5RYWWqebsg',
#  'UCB-KGGtblMXnJr0QPzPFegg',
#  'UC96UGbXH7n_ZVq6MnwP9Kbg',
#  'UCpkziHOjqDLOwOWkYgDourA',
#  'UCgfKoZmOuWjApDwnwuWFbJw',
#  'UC-VS4yxf5t8tu-SGvhl3EOw',
#  'UCvCJAkuh-x3iF8jX8X5yUpw',
#  'UCH6wiF1uC7PhuV_UIR_28AA',
#  'UCMKbFe_WqCf7z0HuthmjAag',
#  'UCzTpVpOAXUXmU5qlY8wDWxQ',
#  'UC2NAec2evVOH3vDPyxtqbZQ',
#  'UCDU1Yn_Qcdu58rM7Z3ynwAg',
#  'UC_O00RqZr7aTQ7w2jx3Ul-g',
#  'UCarjHZkz5S4fqC1E4dXzAYw',
#  'UC_s0g4QdprLkyyN2MDpef7Q',
#  'UCcD1a90gZr2e0JOb_VOS6Kw',
#  'UCorFOsy96xeWE68KfywaR_Q',
#  'UC7zZ2-Q_oxbUaoMVL0z51wg',
#  'UCjDc3MSEXncXkt8fPJwgJzw',
#  'UCV5ghQaO_W1uTFYag_cGqLA',
#  'UCJvE661CWYDfByTAlm8r7fw',
#  'UCLMB3EPQVT-d9oQ5JigcabA',
#  'UCIQne9yW4TvCCNYQLszfXCQ',
#  'UC4EacBmPcZXvr02g78hddUA',
#  'UCrUHyTeumr4EYGZdaISPvAQ',
#  'UCkrZ8WeSMe0G6vow3KsNpsg',
#  'UC93KwU9APdyfS5-GEAjGS7g',
#  'UCtAoItAnNOJYf8XqnERy50w',
#  'UCFeel7cL_QE98b9oRaTomLg',
#  'UCk2qkTSFIwMwbBaF5ZkDEFA',
#  'UC-_VWzLy91jVYDqPEXxa96g',
#  'UC-HLXw5cFC-7zqaXqTIlj-g',
#  'UCPpecwq3qib6yHtbllnkemw',
#  'UCuJZat-meqObfMo21lQ5b2A',
#  'UCFmHrI6SoMlqcqsVVJ4VCVQ',
#  'UCi2Ur7IAiOGLaIvUNr-WkKg',
#  'UCZYTClx2T1of7BRZ86-8fow',
#  'UCkryQ5vRrHHceEGa0dcZuXw',
#  'UCsCru_-pmZYURBiKFF_VJSA',
#  'UCui1g2kzY4vZ8PDNok_Yz5g',
#  'UCrJlKsfZLj6ZLYlPwo1uZCw',
#  'UCaeZnstUEcmk5Lyzh_xRzAw',
#  'UClPOFnXoAe1duK-HI84gA9A',
#  'UCLKZ20yD2tNMBOkSDZo4FeQ',
#  'UCoHVvn1aZXyg6n0sM5QitAQ',
#  'UCSnhAS-Tcjw45OgpOtS5sUw',
#  'UC6_-L6gvR1X0_6_TXeKKriQ',
#  'UCLlGxVFdpYEhNbhsr13Z-Cg',
#  'UCa9gErQ9AE5jT2DZLjXBIdA',
#  'UCURUV9lkptpRz0U76nmK7iQ',
#  'UC7brC61h0WUHV7V2wfSUGLA',
#  'UCc7gpqMnnOSbU_F2-5MVVZw',
#  'UCXaOCH5VB0s-fZAzFFFE5nA',
#  'UC525q2RIufHjnaHOuIUFY9A',
#  'UCFKNX8tHlluVLBFBsePDirg',
#  'UCLKx4-_XO5sR0AO0j8ye7zQ',
#  'UCHetsKn3hHUg4J48onIKQZQ',
#  'UCG04dVOTmbRYPY1wvshBVDQ',
#  'UCz4EZ4sjW1eXIahYr7S1rfA',
#  'UCW2QaaCszJ04uVQbRyY7O7g',
#  'UC4z6xtAqbk6oFwg5qhq4ODw',
#  'UCPvM2XTz_ejiwNllG-Apfqw',
#  'UC6sQgW0qiRh0uzVrWOKjZzA',
#  'UCsvqVGtbbyHaMoevxPAq9Fg',
#  'UCWN3xxRkmTPmbKwht9FuE5A',
#  'UCZ5emGtBQWQ3rHIrsBZpEUQ',
#  'UCwSozl89jl2zUDzQ4jGJD3g',
#  'UC8f_tyaLOG2-22SaxgEA07w',
#  'UCRRBkLlPhEAtniq6qpkDc9g',
#  'UCqKRlX8Pi6xg-lAAzkt3wfA',
#  'UCsQ6_w5iUOUOMAUPclg2kcg',
#  'UC2SeYiYj9PCWNMPBR5J8r-Q',
#  'UCLhC6m5-YiAtVUlvmU6vWoA',
#  'UCIXwj6GM5xonFrulxyP5n5A',
#  'UCEeqSP81Aav5Zvbdc1RvnAQ',
#  'UCxoDMG0tvaYO5Xobvtqw5nw',
#  'UCs03Xqn7iGA4UqjYPZx_6Gg',
#  'UCS3lFRhXKfCZ8FvRqPjy9NA',
#  'UCkg0u3bmqgG9SsZwuMW_qsg',
#  'UCyI4QLEBjWNRb8nW5DPnhHA',
#  'UCXB6zy4Pu9bPVQHvS8XKLUw',
#  'UC8w8_H_1uDfi2ftQx7a64uQ',
#  'UCagiBBx1prefrlsDzDxuA9A',
#  'UC56Nlgc6h43QNmaZGP1uQ0g',
#  'UCOzEQqC_EE6R-KhhIED-Qvg',
#  'UC_mkC8ChfzCJcuSqSMwvUWw',
#  'UC_FbRs9OJRXyUFjEa7ug3gw',
#  'UCGwuxdEeCf0TIA2RbPOj-8g',
#  'UChugFTK0KyrES9terTid8vA',
#  'UCBa5G_ESCn8Yd4vw5U-gIcg',
#  'UCGXXW2LIxTXtPI1aoRguGrA',
#  'UCtYLUTtgS3k1Fg4y5tAhLbw',
#  'UCyUBW72KU30dfAYWLVNZO8Q',
#  'UCPwgsn54MIoBQN9HsJ35Pbg',
#  'UCIg2taLnC9X6LRP1k3kukOA',
#  'UC8syZt8NH9Vdqzwe5sjzkeA',
#  'UCx5kDBBn1gupAAwaoQwaqrg',
#  'UC2xOn0xQj1HIpHJpOy5tvpA',
#  'UCCSZqgcsCtbokmz2xAniUKw',
#  'UCmpoibtP3u02auqMiGulhig',
#  'UC-Dpg1ZjCAXoK8OZaQNsC7Q',
#  'UCrC8mOqJQpoB7NuIMKIS6rQ',
#  'UCI4A0dSGeVAEbEYQ4jkcmBg',
#  'UCLI_f0zfE2Q9EWoJe_cAwRw',
#  'UCOSoTRBZAD7VDlP5OHBHy2g',
#  'UCO9yfXErzQFELbDBUgTDqxw',
#  'UC-Tcw6cOY7GS3Y_u9i8dbEw',
#  'UCeLAfuQgnmCy1mJHEwv9Qew',
#  'UC1XJa1jxEPETUs7WNIv6eKA',
#  'UCp5Nhw2YMCMUemXC1oWTkkA',
#  'UCF8U-fXYj4MucR2jmGPH0Bw',
#  'UCRdfhTdKpGtJg-QIuAIND8g',
#  'UClUA0PA7bXRe-1nbV5w-M7g',
#  'UC9P5va2ei53ypHDN_dHRuUg',
#  'UC8DfAsbr00uQ_0Fdm0iI5Jw',
#  'UC0EUXypdFcn3puNSV1hcL_g',
#  'UCoDxdfbqZ7tkpaDJv1rmCag',
#  'UCsooa4yRKGN_zEE8iknghZA',
#  'UCRKtlwm0WZIA1tDyhyV6Q_w',
#  'UC-_x8eTFQo-ws7zVvdILkEQ',
#  'UC7HYxRWmaNlJux-X7rNLZyw',
#  'UCo-qyGCqEWkHudTpcN-RbYA',
#  'UChJ6OvOQPC-58OBHcdzELxA',
#  'UCE2q3AJQWnnsPLvwiVdU8xA',
#  'UCSDclSDfDZLCTfxbt64IotQ',
#  'UCk3gSmmVE0vedMkICkhWpcQ',
#  'UC2r05YffIyAru43GMoxZBzw',
#  'UC8-_tmVldoye6BMatC8n_mg',
#  'UCO66zvpQorlNfs_7hFCfmaw',
#  'UCgQ3R0mnmsuvrhzUXd_qdYg',
#  'UCZlIaL4DOEFig1b2jgx25zA',
#  'UCsSUJsckEsDBOf79Ap4flmQ',
#  'UCQuu7K8SuAqqP879QB5CqXg',
#  'UC09ZrHAz3BfssHslbgxVqkw',
#  'UCPvDKIsrjA_h3g5yZJwCIHA',
#  'UC3jiygXxwsS15xIodsU3XVA',
#  'UCPLTXEqO_SibQoOQbUdtNYw',
#  'UCD6yLKy9enO-rLPhP0iY18w',
#  'UC91rKAoOe5G4SW6hrFi6riw',
#  ...]

# %%
#crawl snippet, statistics, contentDetails, topicDetails of each channel in channel_list, lưu crawl vào ytbdata/1_crawl/channel_raw_info/channel_raw_info{date}.json
youtube = build('youtube', 'v3', developerKey=API_KEY)

bucket_name = "ytbdata"
gcs_folder = "1_crawl"
date_str = datetime.today().strftime("%Y%m%d")
filename = f"channel_raw_info_{date_str}.json"
blob_path = f"{gcs_folder}/channel_raw_info/{filename}"

# %%
# ─── CRAWL CHANNEL INFO ────────────────────────────────────
raw_data = []

batch_size = 50
for i in range(0, len(channel_list), batch_size):
    batch = channel_list[i:i + batch_size]
    id_string = ",".join(batch)

    try:
        response = youtube.channels().list(
            part="snippet,statistics,contentDetails,topicDetails",
            id=id_string
        ).execute()

        raw_data.extend(response["items"])

        print(f"✅ Crawled batch {i} → {i + len(batch) - 1}")

        time.sleep(0.1)  # hạn chế bị quota exceeded

    except Exception as e:
        print(f"❌ Error with batch {i}-{i + len(batch) - 1}: {e}")
        continue
# Out:
# ✅ Crawled batch 0 → 49
# ✅ Crawled batch 50 → 99
# ✅ Crawled batch 100 → 149
# ✅ Crawled batch 150 → 199
# ✅ Crawled batch 200 → 249
# ✅ Crawled batch 250 → 299
# ✅ Crawled batch 300 → 349
# ✅ Crawled batch 350 → 399
# ✅ Crawled batch 400 → 449
# ✅ Crawled batch 450 → 499
# ✅ Crawled batch 500 → 549
# ✅ Crawled batch 550 → 599
# ✅ Crawled batch 600 → 649
# ✅ Crawled batch 650 → 699
# ✅ Crawled batch 700 → 749
# ✅ Crawled batch 750 → 799
# ✅ Crawled batch 800 → 849
# ✅ Crawled batch 850 → 899
# ✅ Crawled batch 900 → 949
# ✅ Crawled batch 950 → 999
# ✅ Crawled batch 1000 → 1049
# ✅ Crawled batch 1050 → 1099
# ✅ Crawled batch 1100 → 1149
# ✅ Crawled batch 1150 → 1199
# ✅ Crawled batch 1200 → 1249
# ✅ Crawled batch 1250 → 1299
# ✅ Crawled batch 1300 → 1349
# ✅ Crawled batch 1350 → 1399
# ✅ Crawled batch 1400 → 1449
# ✅ Crawled batch 1450 → 1499
# ✅ Crawled batch 1500 → 1549
# ✅ Crawled batch 1550 → 1599
# ✅ Crawled batch 1600 → 1649
# ✅ Crawled batch 1650 → 1699
# ✅ Crawled batch 1700 → 1749
# ✅ Crawled batch 1750 → 1799
# ✅ Crawled batch 1800 → 1849
# ✅ Crawled batch 1850 → 1899
# ✅ Crawled batch 1900 → 1949
# ✅ Crawled batch 1950 → 1999
# ✅ Crawled batch 2000 → 2049
# ✅ Crawled batch 2050 → 2099
# ✅ Crawled batch 2100 → 2149
# ✅ Crawled batch 2150 → 2199
# ✅ Crawled batch 2200 → 2249
# ✅ Crawled batch 2250 → 2299
# ✅ Crawled batch 2300 → 2349
# ✅ Crawled batch 2350 → 2399
# ✅ Crawled batch 2400 → 2449
# ✅ Crawled batch 2450 → 2499
# ✅ Crawled batch 2500 → 2549
# ✅ Crawled batch 2550 → 2599
# ✅ Crawled batch 2600 → 2649
# ✅ Crawled batch 2650 → 2699
# ✅ Crawled batch 2700 → 2749
# ✅ Crawled batch 2750 → 2799
# ✅ Crawled batch 2800 → 2849
# ✅ Crawled batch 2850 → 2899
# ✅ Crawled batch 2900 → 2949
# ✅ Crawled batch 2950 → 2999
# ✅ Crawled batch 3000 → 3049
# ✅ Crawled batch 3050 → 3099
# ✅ Crawled batch 3100 → 3149
# ✅ Crawled batch 3150 → 3199
# ✅ Crawled batch 3200 → 3249
# ✅ Crawled batch 3250 → 3299
# ✅ Crawled batch 3300 → 3349
# ✅ Crawled batch 3350 → 3399
# ✅ Crawled batch 3400 → 3449
# ✅ Crawled batch 3450 → 3499
# ✅ Crawled batch 3500 → 3549
# ✅ Crawled batch 3550 → 3599
# ✅ Crawled batch 3600 → 3649
# ✅ Crawled batch 3650 → 3699
# ✅ Crawled batch 3700 → 3749
# ✅ Crawled batch 3750 → 3799
# ✅ Crawled batch 3800 → 3849
# ✅ Crawled batch 3850 → 3899
# ✅ Crawled batch 3900 → 3949
# ✅ Crawled batch 3950 → 3999
# ✅ Crawled batch 4000 → 4049
# ✅ Crawled batch 4050 → 4099
# ✅ Crawled batch 4100 → 4149
# ✅ Crawled batch 4150 → 4199
# ✅ Crawled batch 4200 → 4244

# %%
json_str = json.dumps(raw_data, indent=2, ensure_ascii=False)

# Upload to GCS
storage_client = storage.Client(project=project_id)
bucket = storage_client.bucket(bucket_name)
blob = bucket.blob(blob_path)

# Upload from string as file-like object
json_bytes = json_str.encode("utf-8")
blob.upload_from_file(io.BytesIO(json_bytes), content_type='application/json')

print(f"✅ Đã lưu {len(raw_data)} kênh vào GCS: gs://{bucket_name}/{blob_path}")
# Out:
# c:\Users\kt061\anaconda3\envs\min_ds\Lib\site-packages\google\auth\_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# ✅ Đã lưu 4230 kênh vào GCS: gs://ytbdata/1_crawl/channel_raw_info/channel_raw_info_20250614.json
