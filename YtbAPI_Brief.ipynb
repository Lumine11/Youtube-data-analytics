# %% [markdown]
# Ref: https://developers.google.com/youtube/v3/docs
#
# Youtube Data API allow developers to et data from many subject (Resource), such as search, video, channel, playlist, comment, commentThread, captiopn,...   <br> <br/>
# In the early stage of the project, we need general information of videos and channel, so we will consider search, video, channel first.

# %%
import os
from dotenv import load_dotenv
from pathlib import Path
import requests

# %%
#get the API KEY
parent_env_path = Path.cwd().parent / ".env"
load_dotenv(dotenv_path=parent_env_path)
API_KEY = os.getenv("API_KEY_1")

# %% [markdown]
# ## Information related to search api
# The query parameter of search api only have 1 option: snippet.

# %%
SEARCH_URL = "https://www.googleapis.com/youtube/v3/search"

params = {
    "part": "snippet",
    "q": "AI",
    "type": "video",
    "publishedAfter": "2023-10-01T00:00:00Z",
    "publishedBefore": "2023-10-31T23:59:59Z",
    "order": "relevance",
    "maxResults": 50,
    "key": API_KEY
}

response = requests.get(SEARCH_URL, params=params)
results = response.json()

for item in results['items']:
    print(item)
# Out:
# {'kind': 'youtube#searchResult', 'etag': '2JivQViHLy49ut04wzxuc-20BDU', 'id': {'kind': 'youtube#video', 'videoId': '_6R7Ym6Vy_I'}, 'snippet': {'publishedAt': '2023-10-12T16:29:50Z', 'channelId': 'UCYeF244yNGuFefuFKqxIAXw', 'title': 'What is generative AI and how does it work? – The Turing Lectures with Mirella Lapata', 'description': 'How are technologies like ChatGPT created? And what does the future hold for AI language models? This talk was filmed at the ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_6R7Ym6Vy_I/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/_6R7Ym6Vy_I/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/_6R7Ym6Vy_I/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'The Royal Institution', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-12T16:29:50Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'dNq5Lk9kFf06yhqyTMrXKFdQ_js', 'id': {'kind': 'youtube#video', 'videoId': 'ObIijyxb9ZE'}, 'snippet': {'publishedAt': '2023-10-05T21:15:22Z', 'channelId': 'UCvW8DDqe1mGMWyW5X-PUuUg', 'title': 'Ultra-Realistic AI Influencer dancing Bounce When She Walk #AIAvatar', 'description': 'Step into the frontier of AI avatars, where we effortlessly merge authentic video footage with AI-crafted visages, granting ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ObIijyxb9ZE/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/ObIijyxb9ZE/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/ObIijyxb9ZE/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Everуpixel Workroom', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-05T21:15:22Z'}}
# {'kind': 'youtube#searchResult', 'etag': '-BDYBjrlY3n5hiyhKiAEwiCVLW8', 'id': {'kind': 'youtube#video', 'videoId': 'x2skvbHZG-g'}, 'snippet': {'publishedAt': '2023-10-15T03:05:49Z', 'channelId': 'UC34VWSnNs8q8HfqYPXX5TeA', 'title': 'Canva Magic AI thực sự tuyệt vời | Dũng kiến thức AI', 'description': 'ai #dungkienthucai #artificialintelligence #canva.', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/x2skvbHZG-g/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/x2skvbHZG-g/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/x2skvbHZG-g/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Dũng Kiến thức AI', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-15T03:05:49Z'}}
# {'kind': 'youtube#searchResult', 'etag': '6jFSQONr18y9I3BxhHwvYZAZEpk', 'id': {'kind': 'youtube#video', 'videoId': 'OK0YhF3NMpQ'}, 'snippet': {'publishedAt': '2023-10-22T13:00:16Z', 'channelId': 'UCUMZ7gohGI9HcU9VNsr2FJQ', 'title': 'OpenAI&#39;s CEO on What Kids Should Be Studying', 'description': 'What should kids be learning these days to prepare for an AI future? OpenAI CEO Sam Altman tells Emily Chang on The Circuit.', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/OK0YhF3NMpQ/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/OK0YhF3NMpQ/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/OK0YhF3NMpQ/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Bloomberg Originals', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-22T13:00:16Z'}}
# {'kind': 'youtube#searchResult', 'etag': '-qqdMI2dHVI84TvSvmMXY9fjDeY', 'id': {'kind': 'youtube#video', 'videoId': '6HkL487I7yg'}, 'snippet': {'publishedAt': '2023-10-21T05:28:41Z', 'channelId': 'UC34VWSnNs8q8HfqYPXX5TeA', 'title': 'Tạo logo trong 1 phút với AI  | Dũng kiến thức AI', 'description': 'dungkienthucai #ai #artificialintelligence #logo #logodesign.', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6HkL487I7yg/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/6HkL487I7yg/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/6HkL487I7yg/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Dũng Kiến thức AI', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-21T05:28:41Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'YMC14GU_cNB31fLIGWhaE675wn8', 'id': {'kind': 'youtube#video', 'videoId': '0ewcCxa5-yY'}, 'snippet': {'publishedAt': '2023-10-09T00:29:22Z', 'channelId': 'UCE7spuKzxP1k8A-XucxxUAQ', 'title': 'AI thumbnails are a problem', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0ewcCxa5-yY/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/0ewcCxa5-yY/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/0ewcCxa5-yY/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'John Casterline', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-09T00:29:22Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'QSXUiIDJKlDQmMuDcNvn2fniTB0', 'id': {'kind': 'youtube#video', 'videoId': 'z9iQiR3Rl4k'}, 'snippet': {'publishedAt': '2023-10-16T15:12:54Z', 'channelId': 'UCUFMgUDsqQnWFDBxUbBHR3g', 'title': 'Create a FREE LOGO with AI within seconds 🤯 #ai #freelogo #artificialintelligence', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/z9iQiR3Rl4k/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/z9iQiR3Rl4k/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/z9iQiR3Rl4k/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Simply Digital', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-16T15:12:54Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'fx8cOM-_WvXkSmDkjuZwazMpEIg', 'id': {'kind': 'youtube#video', 'videoId': 't-gBmFABbWM'}, 'snippet': {'publishedAt': '2023-10-27T23:16:25Z', 'channelId': 'UCghJTNTO9kcDeUFXMuSDGLQ', 'title': 'How To Poison AI Art #artificialintelligence #aitools #ainews', 'description': 'Nightshade is a new anti-AI tool that allows artists to inject “poison” into their digital images to really mess with image scraping ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/t-gBmFABbWM/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/t-gBmFABbWM/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/t-gBmFABbWM/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'AI For Humans', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-27T23:16:25Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'aYPFmxibfX4pcpEUp8xWet4KL7c', 'id': {'kind': 'youtube#video', 'videoId': 'GbeWrzoqKeE'}, 'snippet': {'publishedAt': '2023-10-12T17:21:53Z', 'channelId': 'UCMwJJL5FJFuTRT55ksbQ4GQ', 'title': '&quot;Asking AI what women from every country look like&quot;', 'description': 'Asmongold Clips / Asmongold Reacts To: Getting cancelled for sure 100% this time Reddit post by SixxRabbit: ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GbeWrzoqKeE/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/GbeWrzoqKeE/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/GbeWrzoqKeE/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Asmongold Clips', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-12T17:21:53Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'SbPjGyDB7mGESnrwoqhUyVE1CB8', 'id': {'kind': 'youtube#video', 'videoId': 'Y9-UL8PPHzE'}, 'snippet': {'publishedAt': '2023-10-03T18:30:26Z', 'channelId': 'UCE7spuKzxP1k8A-XucxxUAQ', 'title': 'the AI mrbeast scam is bad', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Y9-UL8PPHzE/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/Y9-UL8PPHzE/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/Y9-UL8PPHzE/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'John Casterline', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-03T18:30:26Z'}}
# {'kind': 'youtube#searchResult', 'etag': '86YVEtPD609_k-oNBOsKZ1zRoic', 'id': {'kind': 'youtube#video', 'videoId': 'W0N4W3C2oYQ'}, 'snippet': {'publishedAt': '2023-10-31T17:03:29Z', 'channelId': 'UC34VWSnNs8q8HfqYPXX5TeA', 'title': 'Tạo video triệu view với AI miễn phí | Dũng kiến thức AI', 'description': 'http://discord.com/invite/rrayYqZ4tf #dungkienthucai #ai #artificialintelligence.', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/W0N4W3C2oYQ/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/W0N4W3C2oYQ/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/W0N4W3C2oYQ/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Dũng Kiến thức AI', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-31T17:03:29Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'zVbxjEn1UdK9pZp2x0awPuTOcrY', 'id': {'kind': 'youtube#video', 'videoId': 'Bjpxya-XGPM'}, 'snippet': {'publishedAt': '2023-10-30T15:01:29Z', 'channelId': 'UCGwZVWP1KHeZGitiOeFxjjw', 'title': '&quot;Will AI Replace Jobs ?&quot; -Jack Ma🤖✨', 'description': 'With the growing advancement of Technology and Artificial Intelligence, people were afraid that the technology and AI will take ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Bjpxya-XGPM/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/Bjpxya-XGPM/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/Bjpxya-XGPM/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Wealth Grit', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-30T15:01:29Z'}}
# {'kind': 'youtube#searchResult', 'etag': '2zPrCyVuSZhwAQ1wYQaQRsDFmHQ', 'id': {'kind': 'youtube#video', 'videoId': 'XnOQ7MtALjE'}, 'snippet': {'publishedAt': '2023-10-07T11:25:04Z', 'channelId': 'UCXyPYxAMlsMx9XyXSzVCmrA', 'title': 'How to Use Ai Feature in Excel _ Save 4 Hours Daily on Excel #ai #aitools #aitools2023 #chatgpt4', 'description': "HEY HELLO EVERYONE I'M MANISH KUMAR THIS IS MY CHANNEL @MK-COMPUTERS-143 THIS CHANNEL IS USED FOR ...", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XnOQ7MtALjE/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/XnOQ7MtALjE/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/XnOQ7MtALjE/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'MK COMPUTERS ', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-07T11:25:04Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'SoII2ln1JFlsNmmI0-LqAfgBbxA', 'id': {'kind': 'youtube#video', 'videoId': 'mrT6UlnwIXA'}, 'snippet': {'publishedAt': '2023-10-27T12:16:15Z', 'channelId': 'UC6R_sPpOZmi5R5XoSdwIo7A', 'title': 'Create entire websites in seconds with this AI tool', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mrT6UlnwIXA/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/mrT6UlnwIXA/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/mrT6UlnwIXA/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Avinash Mada', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-27T12:16:15Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'bEgqKWlszVIv5rTeQ76llqJ8IS8', 'id': {'kind': 'youtube#video', 'videoId': 'WPROID9MJdc'}, 'snippet': {'publishedAt': '2023-10-03T23:10:33Z', 'channelId': 'UC7rsYYvQbqQrJDGhqWmtAgQ', 'title': 'World&#39;s First AI-Created Drink... Is It Good?', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/WPROID9MJdc/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/WPROID9MJdc/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/WPROID9MJdc/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Kyle Krueger', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-03T23:10:33Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'tsFfY5D8GmERT0gRzmqVCX7UveY', 'id': {'kind': 'youtube#video', 'videoId': 'nQXtbD5qzDc'}, 'snippet': {'publishedAt': '2023-10-04T22:41:09Z', 'channelId': 'UCyRhor7QjUyAQUr38db8PyA', 'title': 'This plug-n can recreate ANY sound using AI 🤯  #ai #musicproduction #producer #vstplugins', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nQXtbD5qzDc/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/nQXtbD5qzDc/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/nQXtbD5qzDc/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Jay Eskar', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-04T22:41:09Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'GxWa5mwmf4QYxYzMJ7hzk-SAmyg', 'id': {'kind': 'youtube#video', 'videoId': 'LuNN32Tmc9c'}, 'snippet': {'publishedAt': '2023-10-10T20:05:14Z', 'channelId': 'UCsN32BtMd0IoByjJRNF12cw', 'title': 'Geoffrey Hinton: In time, AI will have self-awareness, consciousness #shorts', 'description': 'news #artificialintelligence #ai.', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LuNN32Tmc9c/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/LuNN32Tmc9c/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/LuNN32Tmc9c/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': '60 Minutes', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-10T20:05:14Z'}}
# {'kind': 'youtube#searchResult', 'etag': 's0_G0qBv380I_o2B63CVTKxHa8Q', 'id': {'kind': 'youtube#video', 'videoId': 'tFx_UNW9I1U'}, 'snippet': {'publishedAt': '2023-10-28T10:00:46Z', 'channelId': 'UCGBO6EahCqQSyXIws1MQdDg', 'title': 'The 10 Stages of Artificial Intelligence', 'description': 'This video explores the 10 hypothetical stages of AI, including God-Like AI. ___ SOURCES: ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/tFx_UNW9I1U/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/tFx_UNW9I1U/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/tFx_UNW9I1U/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Future Business Tech', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-28T10:00:46Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'yDakd-MQXi7XI5lhiNja0AJsCOU', 'id': {'kind': 'youtube#video', 'videoId': '7F17aaiR0RA'}, 'snippet': {'publishedAt': '2023-10-06T23:07:49Z', 'channelId': 'UCoDmVglbUYN8AeX06YweY5g', 'title': 'Kai Cenat &amp; Duke Dennis React to Ai Love Song #shorts #kaicenat #dukedennis #funny #zesty #trending', 'description': 'Kai Cenat & Duke Dennis React to Ai Love Song Sounds Crazy, the michael jackson x weekend x bruno mars Ai #shorts ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7F17aaiR0RA/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/7F17aaiR0RA/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/7F17aaiR0RA/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Charpy', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-06T23:07:49Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'koxCmeMxhboFfhUBmTNZFUrC0FU', 'id': {'kind': 'youtube#video', 'videoId': 'oo90XYB_BWw'}, 'snippet': {'publishedAt': '2023-10-23T12:04:33Z', 'channelId': 'UCUFMgUDsqQnWFDBxUbBHR3g', 'title': 'You can create your own online course FOR FREE with AI #ai #onlinecourses', 'description': 'You can try for FREE to create your own online course with AI here: ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/oo90XYB_BWw/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/oo90XYB_BWw/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/oo90XYB_BWw/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Simply Digital', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-23T12:04:33Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'T43qtIclTTeWGS8o98VNGTGLmhA', 'id': {'kind': 'youtube#video', 'videoId': 'qrvK_KuIeJk'}, 'snippet': {'publishedAt': '2023-10-09T12:03:13Z', 'channelId': 'UCsN32BtMd0IoByjJRNF12cw', 'title': '&quot;Godfather of AI&quot; Geoffrey Hinton: The 60 Minutes Interview', 'description': "There's no guaranteed path to safety as artificial intelligence advances, Geoffrey Hinton, AI pioneer, warns. He shares his ...", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/qrvK_KuIeJk/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/qrvK_KuIeJk/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/qrvK_KuIeJk/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': '60 Minutes', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-09T12:03:13Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'dMIx9tcyXw0_vxwc_hoxbyjtUUI', 'id': {'kind': 'youtube#video', 'videoId': 'IP9SWZe7AS8'}, 'snippet': {'publishedAt': '2023-10-23T17:17:20Z', 'channelId': 'UC2TUZnaGIN5F_1mE6HWDHnQ', 'title': 'This AI tool can translate your video into any languages, with lip syncing! (Realistic results)', 'description': 'Try it out: https://app.heygen.com/guest?sid=rewardful&via=joanna.', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/IP9SWZe7AS8/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/IP9SWZe7AS8/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/IP9SWZe7AS8/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Joanna Yung', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-23T17:17:20Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'uRqmr8KSUPCtc6G1gZFPTwGtIC4', 'id': {'kind': 'youtube#video', 'videoId': 'DzCWyUCr9LQ'}, 'snippet': {'publishedAt': '2023-10-02T15:30:03Z', 'channelId': 'UCM0--k8uumfySc926W-ydlg', 'title': 'FREE AI Courses worth ₹50 Lakhs 🤩💰#shorts', 'description': "shorts Unlock Your Future with AI: A Courses Even Recommended by Modi Ji! Save this Video Now! I'm about to share ...", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DzCWyUCr9LQ/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/DzCWyUCr9LQ/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/DzCWyUCr9LQ/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'CUET by Gokul Chhabra', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-02T15:30:03Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'cbf_eZ_TQWvc3QymHtypxkWp7IQ', 'id': {'kind': 'youtube#video', 'videoId': 'F0xFwWMclGw'}, 'snippet': {'publishedAt': '2023-10-20T22:20:24Z', 'channelId': 'UCE7spuKzxP1k8A-XucxxUAQ', 'title': 'school “hires” ai principal', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/F0xFwWMclGw/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/F0xFwWMclGw/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/F0xFwWMclGw/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'John Casterline', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-20T22:20:24Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'FKiSDiOHjrKAWYX1geeFr60HxFY', 'id': {'kind': 'youtube#video', 'videoId': 'wSCC8ve0xUU'}, 'snippet': {'publishedAt': '2023-10-09T11:00:44Z', 'channelId': 'UCOEchw_lQpWeXwudnJMJkZQ', 'title': 'ដោនឡូតកម្មវិធី AI នេះ នៅលើទូរស័ព្ទ!', 'description': 'ចុចទីនេះដើម្បី Subscribe: https://bit.ly/3a7vflv --------------------------------------------------------------------------- Like my ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wSCC8ve0xUU/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/wSCC8ve0xUU/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/wSCC8ve0xUU/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Siha Sao សៅ សីហា', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-09T11:00:44Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'tV4uehJWtVUshpQheuVIcDZiVeY', 'id': {'kind': 'youtube#video', 'videoId': 'PVLn5IbNbbE'}, 'snippet': {'publishedAt': '2023-10-02T17:47:22Z', 'channelId': 'UC34VWSnNs8q8HfqYPXX5TeA', 'title': 'AI làm bài thuyết trình | Dũng kiến thức AI', 'description': 'ai #artificialintelligence #dungkienthucai #powerpoint #tinhocvanphong.', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PVLn5IbNbbE/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/PVLn5IbNbbE/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/PVLn5IbNbbE/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Dũng Kiến thức AI', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-02T17:47:22Z'}}
# {'kind': 'youtube#searchResult', 'etag': '1YknqrFbUjVm4a4lAp6V45V-r68', 'id': {'kind': 'youtube#video', 'videoId': 'yn1QKuCQXO8'}, 'snippet': {'publishedAt': '2023-10-28T12:00:58Z', 'channelId': 'UCKNTZMRHPLXfqlbdOI7mCkg', 'title': 'Why Real Programmers LAUGH About No Code Tools &amp; AI', 'description': 'Follow for more Android & Kotlin tips.', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yn1QKuCQXO8/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/yn1QKuCQXO8/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/yn1QKuCQXO8/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Philipp Lackner', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-28T12:00:58Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'tVnCD5A_I7XkAX2IKJi558wPlJo', 'id': {'kind': 'youtube#video', 'videoId': 'xK0qQ5UL1vE'}, 'snippet': {'publishedAt': '2023-10-14T13:53:45Z', 'channelId': 'UCz0mjmNNqJe5G5e-dBvYhgg', 'title': 'AI Generated Total Drama Island As Humans Pt. 3', 'description': 'AI Generated Total Drama Island Pt. 3 #ai #disney #goat.', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xK0qQ5UL1vE/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/xK0qQ5UL1vE/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/xK0qQ5UL1vE/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'GoatedAI', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-14T13:53:45Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'VeaGojXKYvlKBjId1IA5CrVQ0lo', 'id': {'kind': 'youtube#video', 'videoId': 'EOzD0Khshhc'}, 'snippet': {'publishedAt': '2023-10-28T23:00:09Z', 'channelId': 'UClHVl2N3jPEbkNJVx-ItQIQ', 'title': 'Let&#39;s Talk About AI &amp; Mental Health', 'description': "Check out Dr. K's Guide to Mental Health: https://bit.ly/3ESAerp Full video: Our Healthy Gamer Coaches have transformed over ...", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/EOzD0Khshhc/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/EOzD0Khshhc/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/EOzD0Khshhc/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'HealthyGamerGG', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-28T23:00:09Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'KZclBDsB-UI9N_bg7QeDrqyQM50', 'id': {'kind': 'youtube#video', 'videoId': 'scXcUppw9Kc'}, 'snippet': {'publishedAt': '2023-10-15T08:06:10Z', 'channelId': 'UCknY7JRRHSPZz0SddYiriSg', 'title': 'XNote - Real Pen and Paper, Powered By ChatGPT #tech #chatgpt #ai', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/scXcUppw9Kc/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/scXcUppw9Kc/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/scXcUppw9Kc/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'XNote', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-15T08:06:10Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'fj_Cbn8V8iq3sneXDgCOeYou6MM', 'id': {'kind': 'youtube#video', 'videoId': 'gijkkNyszas'}, 'snippet': {'publishedAt': '2023-10-06T13:00:38Z', 'channelId': 'UCFozqRSzA3K_EcCGHRKspRw', 'title': 'AI Vtuber becomes EVIL and COPIES human emotions', 'description': 'AI Vtuber becomes EVIL and COPIES human emotions AI Vtuber GENIUS solves a HARD confusing math QUIZ AI Vtuber ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gijkkNyszas/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/gijkkNyszas/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/gijkkNyszas/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'MOTHERv3', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-06T13:00:38Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'ZQGnNpAYibDUO50R8KbYETf8wXY', 'id': {'kind': 'youtube#video', 'videoId': 'gmUHEvrpYoU'}, 'snippet': {'publishedAt': '2023-10-06T20:37:05Z', 'channelId': 'UCu378IVA2__mBS_AO5197FQ', 'title': 'What are AI Chatbots?', 'description': 'https://www.commonsense.org/education/collections/ai-literacy-for-grades-6-12-lessons What are AI chatbots? And how are they ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gmUHEvrpYoU/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/gmUHEvrpYoU/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/gmUHEvrpYoU/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Common Sense Education', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-06T20:37:05Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'u7lLpOuCGdjjnHPEeos2YqphOb4', 'id': {'kind': 'youtube#video', 'videoId': '5qaGRDnQvog'}, 'snippet': {'publishedAt': '2023-10-25T10:00:07Z', 'channelId': 'UC9cMvTMJkDhe__2iPIopJzA', 'title': 'AI (feat. Violette Wautier)', 'description': 'Provided to YouTube by TERO Entertainment PCL Music (Thailand) AI (feat. Violette Wautier) · Slot Machine AI - Single ℗ 2023 ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5qaGRDnQvog/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/5qaGRDnQvog/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/5qaGRDnQvog/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Slot Machine - Topic', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-25T10:00:07Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'Ez-w1b7VRhCieg1ZvzQVNj873wU', 'id': {'kind': 'youtube#video', 'videoId': 'Wb-egpA7AFA'}, 'snippet': {'publishedAt': '2023-10-31T04:18:08Z', 'channelId': 'UCxvU6bRtYhNLvZleAIGa-FQ', 'title': '[벙커1특강] 박태웅 AI 강의 1부', 'description': "IT 현자! 한빛미디어 박태웅 의장의 '박태웅의 AI 강의' 출간 기념 벙커1 특강 1부 ▷ AI 특강 2부 이어보기 ...", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Wb-egpA7AFA/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/Wb-egpA7AFA/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/Wb-egpA7AFA/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': '딴지방송국', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-31T04:18:08Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'VE4XBPh1_tD14i2Y8o_e3B8Azr0', 'id': {'kind': 'youtube#video', 'videoId': 'zJ4OVgpU6X0'}, 'snippet': {'publishedAt': '2023-10-11T12:30:28Z', 'channelId': 'UCF6kUfvnB9u9avi8LH3kSxA', 'title': 'Unleash Your Earning Potential with AI Animation Story Videos', 'description': 'chatgpt #Midjourney #ai #makemoneyonline This is a short that shows step-by-step how to create AI amination story videos for ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zJ4OVgpU6X0/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/zJ4OVgpU6X0/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/zJ4OVgpU6X0/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'The Zinny Studio', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-11T12:30:28Z'}}
# {'kind': 'youtube#searchResult', 'etag': 's-WqEtoiQ1AY-JuLPCZpApCgHF4', 'id': {'kind': 'youtube#video', 'videoId': 'Tqo5DCQmXX4'}, 'snippet': {'publishedAt': '2023-10-04T12:16:12Z', 'channelId': 'UC14_kcbqdtM2GB2-jeJYFTg', 'title': 'Syte&#39;s Visual AI Platform for Retail', 'description': "Sell more by instantly connecting shoppers with products they'll love. Learn about Syte's AI-powered solutions for eCommerce ...", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Tqo5DCQmXX4/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/Tqo5DCQmXX4/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/Tqo5DCQmXX4/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Syte Product Discovery Platform', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-04T12:16:12Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'PTbSyvdWWymnGpqFaqALqizueC8', 'id': {'kind': 'youtube#video', 'videoId': '15ItMLM98Do'}, 'snippet': {'publishedAt': '2023-10-12T23:52:20Z', 'channelId': 'UCWcKAxNyR6EEKLBorhRRp9A', 'title': 'AI para hablar con tus archivos PDF', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/15ItMLM98Do/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/15ItMLM98Do/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/15ItMLM98Do/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Alcala Creativo', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-12T23:52:20Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'VMamxFK0HW86ignIXRKz9HlNI38', 'id': {'kind': 'youtube#video', 'videoId': '8RhN0lm2AJI'}, 'snippet': {'publishedAt': '2023-10-06T14:23:39Z', 'channelId': 'UCw6UTjha4OBnjMtzfVrlT2g', 'title': 'A.I. GENERATIVE FILL For Video is NEXT LEVEL! (Premiere Pro + Photoshop)', 'description': 'A.I. GENERATIVE FILL For Video is NEXT LEVEL! (Premiere Pro + Photoshop) #shorts Watch Full tutorial: https://linktw.in/VjZVYw ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8RhN0lm2AJI/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/8RhN0lm2AJI/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/8RhN0lm2AJI/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Justin Serran', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-06T14:23:39Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'vm3-LMlfbWjrYzqSeGbSlAyMGWc', 'id': {'kind': 'youtube#video', 'videoId': '0esqNakCovY'}, 'snippet': {'publishedAt': '2023-10-20T06:00:00Z', 'channelId': 'UCQNE2JmbasNYbjGAcuBiRRg', 'title': 'AI의 미친 영상편집 속도;;;  || Autopod #shorts', 'description': '조코딩과 코딩 배우기 https://jocoding.net/ (무료 이벤트) AI 바디프로필 https://jocasso.codemafia.io/body-profile AI 자막 생성 조카소 ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0esqNakCovY/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/0esqNakCovY/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/0esqNakCovY/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': '조코딩 JoCoding', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-20T06:00:00Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'thhoSAGOmqS1pqLlc7UhzbmO7cM', 'id': {'kind': 'youtube#video', 'videoId': 'ND-kzNuhxSM'}, 'snippet': {'publishedAt': '2023-10-13T23:54:14Z', 'channelId': 'UCWcKAxNyR6EEKLBorhRRp9A', 'title': 'Edita foto de producto con esta AI #hacks #trucos #inteligenciaartificial', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ND-kzNuhxSM/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/ND-kzNuhxSM/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/ND-kzNuhxSM/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Alcala Creativo', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-13T23:54:14Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'SNOZXWLU_OM6RrmKOXvjleUziuU', 'id': {'kind': 'youtube#video', 'videoId': 'g8RasrrcGcQ'}, 'snippet': {'publishedAt': '2023-10-26T11:00:11Z', 'channelId': 'UC8B2ycLfajO3h0_ked1qcXQ', 'title': 'Slot Machine - AI feat. Violette Wautier [Official Music Video]', 'description': 'Slot Machine - AI (feat. Violette Wautier) https://slotmachine.lnk.to/AI_ • Spotify: https://spotify.link/ORMhp3lObEb • Apple Music: ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/g8RasrrcGcQ/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/g8RasrrcGcQ/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/g8RasrrcGcQ/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'TERO MUSIC', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-26T11:00:11Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'QcAVcArXOPHa26EjkBsjgUQqmPo', 'id': {'kind': 'youtube#video', 'videoId': '7elmgXZ9pV0'}, 'snippet': {'publishedAt': '2023-10-18T21:46:47Z', 'channelId': 'UCEB-AUq2QMmYbacOxNeZlEg', 'title': 'YearBook AI Part 2 😱😍 #shorts #yearbookai', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7elmgXZ9pV0/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/7elmgXZ9pV0/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/7elmgXZ9pV0/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'LANI LOVE', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-18T21:46:47Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'VMpqAaCGzlJtZi-tCjQBxHKdJXk', 'id': {'kind': 'youtube#video', 'videoId': 'Xcvkk9O1-Qg'}, 'snippet': {'publishedAt': '2023-10-20T09:00:22Z', 'channelId': 'UCgZgbNM5bKHxBkShHnoLGEQ', 'title': 'AI&#39;s Evolution of Men&#39;s Hair', 'description': 'Journey through a century of style with "AI\'s Evolution of Men\'s Hair (From 1910 to 2019)"! Dive into the past and watch as AI ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Xcvkk9O1-Qg/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/Xcvkk9O1-Qg/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/Xcvkk9O1-Qg/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'NeuralNuggets', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-20T09:00:22Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'omevJVd6t4eR49LyeUik9UHHzuM', 'id': {'kind': 'youtube#video', 'videoId': 'ts8-85k6yPk'}, 'snippet': {'publishedAt': '2023-10-11T01:35:22Z', 'channelId': 'UCpyFWSdYlwuwRoIxJjnZxBQ', 'title': 'Secret Website🕵️\u200d♂️ for FREE AI IMAGES🤩🔥 #shorts #techintelugu', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ts8-85k6yPk/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/ts8-85k6yPk/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/ts8-85k6yPk/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Tech Viner', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-11T01:35:22Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'po1bYq2BbSPOyxNnDf1kKX-IrnI', 'id': {'kind': 'youtube#video', 'videoId': 'At5IiC1MIG0'}, 'snippet': {'publishedAt': '2023-10-03T18:46:58Z', 'channelId': 'UCGSfE8rA_g6Qz1g0f-omSoQ', 'title': 'how AI made me a GOOD singer', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/At5IiC1MIG0/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/At5IiC1MIG0/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/At5IiC1MIG0/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'covers ai', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-03T18:46:58Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'owepVxzuy4oVAHu5hU2nphIKDnk', 'id': {'kind': 'youtube#video', 'videoId': 'pJPdW8WWAso'}, 'snippet': {'publishedAt': '2023-10-22T17:16:26Z', 'channelId': 'UCMT1Aw4R4nf_sFNDeuJqc6w', 'title': 'AI Olympics (multi-agent reinforcement learning)', 'description': 'AI Competes in a 100m Dash! In this video 5 AI Warehouse agents compete to learn how to run 100m the fastest. The AI were ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pJPdW8WWAso/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/pJPdW8WWAso/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/pJPdW8WWAso/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'AI Warehouse', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-22T17:16:26Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'ohI3LjIZw0ttx-P-NJUEaTsWNek', 'id': {'kind': 'youtube#video', 'videoId': 'oJHvtM1Kt2U'}, 'snippet': {'publishedAt': '2023-10-21T13:10:01Z', 'channelId': 'UCbwthJmjmX5ZhuhyBp0otqw', 'title': 'FREE AI courses by Google #shorts', 'description': 'Free AI Courses by Google Here you will find the link for every Google AI course, that you can access for free ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/oJHvtM1Kt2U/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/oJHvtM1Kt2U/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/oJHvtM1Kt2U/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Campus Core', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-21T13:10:01Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'X7Ob40bzkzCt-w4mKC2WcUj7pkM', 'id': {'kind': 'youtube#video', 'videoId': '4W_ZMm2fTAo'}, 'snippet': {'publishedAt': '2023-10-17T08:52:55Z', 'channelId': 'UCtnGMVmz1UKecTvodTIyFpg', 'title': 'แชท AI ใช้น้ำเท่าไหร่ #chatGPT #ai', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4W_ZMm2fTAo/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/4W_ZMm2fTAo/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/4W_ZMm2fTAo/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'GabFromSpace', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-17T08:52:55Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'Qm30AMqzoU--D7FXclopWD5v7uc', 'id': {'kind': 'youtube#video', 'videoId': 'aVT0G-PZUVU'}, 'snippet': {'publishedAt': '2023-10-13T12:05:37Z', 'channelId': 'UCYoUuK_uXILQmvip-6jDZ-A', 'title': 'The Most Powerful A.I. In The World!  #shortsindia #millionairemindset  #viralvideo', 'description': 'Follow me on Instagram at please: https://www.instagram.com/vaibhavkadnarofficial/?hl=en.', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/aVT0G-PZUVU/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/aVT0G-PZUVU/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/aVT0G-PZUVU/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Vaibhav Kadnar', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-13T12:05:37Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'lRZ7mbucOZ1NeVwnHNxHQFAaVHA', 'id': {'kind': 'youtube#video', 'videoId': 'BNSvxqjTot0'}, 'snippet': {'publishedAt': '2023-10-20T11:30:04Z', 'channelId': 'UCz3dFKn8ne4HfcHMtiRShHw', 'title': 'Free Online Courses- AI Courses | Artificial Intelligence | Machine Learning | Data Science  #shorts', 'description': "The world has adopted Al as the new norm, and it's time you do the same. Being proficient in Artificial Intelligence, Machine ...", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BNSvxqjTot0/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/BNSvxqjTot0/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/BNSvxqjTot0/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'LeapScholar - Study Abroad Expert', 'liveBroadcastContent': 'none', 'publishTime': '2023-10-20T11:30:04Z'}}

# %% [markdown]
# ## Information related to video
#
# Unlike the search api, video.list api have a lot more parameter:
#
# 1. **`snippet`**: This includes basic public information such as title, description, thumbnail, channel, tags, category, etc.
#
# 2. **`contentDetails`**: This includes information like duration, resolution, whether captions are available, whether the video is embeddable, etc.—all of which are public.
#
# 3. **`statistics`**: View count, like count, and comment count (if comments aren’t disabled) are all public data.
#
# 4. **`status`**: You will see `privacyStatus` as `public`. Other public fields include `embeddable`, `publicStatsViewable`, `license`, and `madeForKids`.
#
# 5. **`player`**: Provides the HTML embed code for the video.
#
# 6. **`topicDetails`**: Gives information about topics related to the video (if available).
#
# 7. **`recordingDetails`**: Available *if* the video owner has provided and made this info public (e.g., recording date, location). Otherwise, these fields will be empty.
#
# 8. **`liveStreamingDetails`**: For videos that are livestreams (upcoming, ongoing, or completed). Public data includes scheduled and actual start/end times, concurrent viewers (if live), etc.
#
# 9. **`localizations`**: Returns translated titles and descriptions for the video (if available).
#
# 10. **`id`**: Returns the `videoId` you requested.
#
# Since we need to analyze the popular and brief attitude of each video, which usually representated by viewCount, like, title, description,... we will consider snippet, contentDetails, statistics, topicDetails

# %%
VIDEO_ID = '0-RgntPt1vQ'  # ID của video cần kiểm tra

# === GỌI API ===
def video_info(video_id, params):
    url = 'https://www.googleapis.com/youtube/v3/videos'
    response = requests.get(url, params=params)

    # === KIỂM TRA PHẢN HỒI ===
    if response.status_code == 200:
        data = response.json()
        items = data.get('items', [])
        if items:
            video_info = items[0]
            print(video_info)
        else:
            print("No video found with this ID.")
    else:
        print("Error:", response.status_code, response.text)

# %%
params = {
    'part': 'snippet',
    'id': VIDEO_ID,
    'key': API_KEY
}

video_info(VIDEO_ID, params)
# Out:
# {'kind': 'youtube#video', 'etag': '4-BA3IsnJguE3PJl0StRebVz19g', 'id': '0-RgntPt1vQ', 'snippet': {'publishedAt': '2025-04-21T14:00:00Z', 'channelId': 'UCz2Ea3MSc6kh4xSQlRctC-g', 'title': 'cant let bro read my Dippy AI chats👀 look up: Dippy AI💕 #dippyai  characterai  #roleplay #anime #fyp', 'description': "Can’t let bro read my Dippy AI chats 👀 | This AI is WILD…  \n💬 Meet the no-filter, no-boundaries AI chat you never knew you needed.  \nDippy AI is the uncensored alternative to Character AI — chat with anime characters, AI girlfriends, roleplay bots, or even your dream waifu.  \nUnlike other apps, Dippy doesn’t misgender, forget conversations, or restrict content.  \n👀 Warning: Once you try it, you won't go back.\n\n🔍 Look up: Dippy AI 💕  \n#ai #dippyai #aichat #characterai #roleplay #openai #animeai #techhacks #usa #viralshorts #highrpm #aigirlfriend #futuretech #productivitytools #gpt #foryou", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0-RgntPt1vQ/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/0-RgntPt1vQ/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/0-RgntPt1vQ/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/0-RgntPt1vQ/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/0-RgntPt1vQ/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'The Curious Animal', 'tags': ['#ai', '#dippyai', '#aichat', '#characterai', '#roleplay', '#openai', '#animeai', '#techhacks', '#usa', '#viralshorts', '#highrpm', '#aigirlfriend', '#futuretech', '#productivitytools', '#gpt', '#foryou', '#dippyaichat', '#aigf', '#aibot', '#aibots', '#techshorts', '#canada', '#uk', '#tech', '#robotics', '#uncensoredai', '#anime', '#chatgpt', '#trendingnow', '#roleplayai', '#characteraichat', '#crazyai', '#funnyai', '#waifuai', '#usaviral', '#gadgetai', '#creator', '#TheCuriousAnimal'], 'categoryId': '28', 'liveBroadcastContent': 'none', 'localized': {'title': 'cant let bro read my Dippy AI chats👀 look up: Dippy AI💕 #dippyai  characterai  #roleplay #anime #fyp', 'description': "Can’t let bro read my Dippy AI chats 👀 | This AI is WILD…  \n💬 Meet the no-filter, no-boundaries AI chat you never knew you needed.  \nDippy AI is the uncensored alternative to Character AI — chat with anime characters, AI girlfriends, roleplay bots, or even your dream waifu.  \nUnlike other apps, Dippy doesn’t misgender, forget conversations, or restrict content.  \n👀 Warning: Once you try it, you won't go back.\n\n🔍 Look up: Dippy AI 💕  \n#ai #dippyai #aichat #characterai #roleplay #openai #animeai #techhacks #usa #viralshorts #highrpm #aigirlfriend #futuretech #productivitytools #gpt #foryou"}}}

# %%
params = {
    'part': 'contentDetails',
    'id': VIDEO_ID,
    'key': API_KEY
}

video_info(VIDEO_ID, params)
# Out:
# {'kind': 'youtube#video', 'etag': 'OvwDHLrC5hdFIGUaMSIOxXOgWBw', 'id': '0-RgntPt1vQ', 'contentDetails': {'duration': 'PT8S', 'dimension': '2d', 'definition': 'hd', 'caption': 'false', 'licensedContent': True, 'contentRating': {}, 'projection': 'rectangular'}}

# %%
params = {
    'part': 'statistics',
    'id': VIDEO_ID,
    'key': API_KEY
}

video_info(VIDEO_ID, params)
# Out:
# {'kind': 'youtube#video', 'etag': 'GC2EHLnM1kOFolyV2_UdmG2qIMU', 'id': 'zce9XNAdaNY', 'statistics': {'viewCount': '57', 'likeCount': '4', 'favoriteCount': '0', 'commentCount': '0'}}

# %%
params = {
    'part': 'topicDetails',
    'id': VIDEO_ID,
    'key': API_KEY
}

video_info(VIDEO_ID, params)
# Out:
# {'kind': 'youtube#video', 'etag': 'NKmxH3n_pdNpCYTehSawzycBWF0', 'id': '0-RgntPt1vQ', 'topicDetails': {'topicCategories': ['https://en.wikipedia.org/wiki/Entertainment', 'https://en.wikipedia.org/wiki/Film']}}

# %% [markdown]
# Since topicDetails return the result not different much with categoryID of snippet, so we will not use topicDetails.

# %% [markdown]
# ## Information related to channel
#
# Similarity, we will check what information do the ytb api can get?
# | part                | Description                                                                                                    |
# | ---------------------- | -------------------------------------------------------------------------------------------------------------- |
# | **`snippet`**          | Basic channel information: title, description, profile image (avatar), country, creation date.                 |
# | **`contentDetails`**   | Information about the channel’s content, such as default playlist IDs (uploads, likes, etc.).                  |
# | **`statistics`**       | Channel metrics: subscriber count, total view count, number of videos.                                         |
# | **`status`**           | Channel status such as monetization, verification status, linking status.                                      |
# | **`brandingSettings`** | Channel branding configuration: banner image, title, keywords, contact info, custom URL.                       |
# | **`topicDetails`**     | A list of topics related to the channel, if available. Helps categorize content (e.g., education, science...). |
# | **`localizations`**    | Translations of the channel’s title and description in various languages (if provided).                        |
# | **`auditDetails`**     | Used for internal or auditing purposes. Not commonly used for regular analysis.                                |

# %%
#Dùng channel.list để lấy thông tin về channel, ví dụ @FORESTSTUDIOO
# === THÔNG TIN CƠ BẢN ===
CHANNEL_ID = 'UCTOWyiIkPEqyh_2O-ArJR5w'  # ID của kênh cần kiểm tra

# %%
url = f"https://www.googleapis.com/youtube/v3/channels?part=snippet&id={CHANNEL_ID}&key={API_KEY}"
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    items = data.get('items', [])
    if items:
        channel_info = items[0]
        print(channel_info)
else:
    print("No channel found with this ID.")
# Out:
# {'kind': 'youtube#channel', 'etag': 'k52FXYqtK72U1SkzJ04bRwMwiRI', 'id': 'UCTOWyiIkPEqyh_2O-ArJR5w', 'snippet': {'title': 'FOREST STUDIO', 'description': 'FOREST STUDIO là kênh YouTube chính thức của FOREST STUDIO JSC.\n\n☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn\n☞ Email: info@forest-studio.vn\n©2018 Forest Studio JSC. All rights reserved', 'customUrl': '@foreststudioo', 'publishedAt': '2018-02-08T10:45:22Z', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/GeZf-8Qv5HpOAY28_dOTongEz8igFufpkFLL0YrRjvIuCbPbJCQDTbIaCE-LTkAn3Mqyulpicxk=s88-c-k-c0x00ffffff-no-rj', 'width': 88, 'height': 88}, 'medium': {'url': 'https://yt3.ggpht.com/GeZf-8Qv5HpOAY28_dOTongEz8igFufpkFLL0YrRjvIuCbPbJCQDTbIaCE-LTkAn3Mqyulpicxk=s240-c-k-c0x00ffffff-no-rj', 'width': 240, 'height': 240}, 'high': {'url': 'https://yt3.ggpht.com/GeZf-8Qv5HpOAY28_dOTongEz8igFufpkFLL0YrRjvIuCbPbJCQDTbIaCE-LTkAn3Mqyulpicxk=s800-c-k-c0x00ffffff-no-rj', 'width': 800, 'height': 800}}, 'localized': {'title': 'FOREST STUDIO', 'description': 'FOREST STUDIO là kênh YouTube chính thức của FOREST STUDIO JSC.\n\n☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn\n☞ Email: info@forest-studio.vn\n©2018 Forest Studio JSC. All rights reserved'}, 'country': 'VN'}}

# %%
url = f"https://www.googleapis.com/youtube/v3/channels?part=contentDetails&id={CHANNEL_ID}&key={API_KEY}"
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    items = data.get('items', [])
    if items:
        channel_info = items[0]
        print(channel_info)
else:
    print("No channel found with this ID.")
# Out:
# {'kind': 'youtube#channel', 'etag': 'pEqkv6-hj-LjuIJGtUTbM3WFR7k', 'id': 'UCTOWyiIkPEqyh_2O-ArJR5w', 'contentDetails': {'relatedPlaylists': {'likes': '', 'uploads': 'UUTOWyiIkPEqyh_2O-ArJR5w'}}}

# %%
url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&id={CHANNEL_ID}&key={API_KEY}"
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    items = data.get('items', [])
    if items:
        channel_info = items[0]
        print(channel_info)
else:
    print("No channel found with this ID.")
# Out:
# {'kind': 'youtube#channel', 'etag': 'dJl_nTgou2CnEdce8V7bw8kb-6o', 'id': 'UCTOWyiIkPEqyh_2O-ArJR5w', 'statistics': {'viewCount': '970573382', 'subscriberCount': '946000', 'hiddenSubscriberCount': False, 'videoCount': '1003'}}

# %%
url = f"https://www.googleapis.com/youtube/v3/channels?part=status&id={CHANNEL_ID}&key={API_KEY}"
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    items = data.get('items', [])
    if items:
        channel_info = items[0]
        print(channel_info)
else:
    print("No channel found with this ID.")
# Out:
# {'kind': 'youtube#channel', 'etag': 'NSuXZPVX95-mAeKislarnzLK_Is', 'id': 'UCTOWyiIkPEqyh_2O-ArJR5w', 'status': {'privacyStatus': 'public', 'isLinked': True, 'longUploadsStatus': 'longUploadsUnspecified', 'madeForKids': False}}

# %%
url = f"https://www.googleapis.com/youtube/v3/channels?part=brandingSettings&id={CHANNEL_ID}&key={API_KEY}"
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    items = data.get('items', [])
    if items:
        channel_info = items[0]
        print(channel_info)
else:
    print("No channel found with this ID.")
# Out:
# {'kind': 'youtube#channel', 'etag': 'yYKYMxlGpZ0FBbZBUdWjJ6HmYPQ', 'id': 'UCTOWyiIkPEqyh_2O-ArJR5w', 'brandingSettings': {'channel': {'title': 'FOREST STUDIO', 'description': 'FOREST STUDIO là kênh YouTube chính thức của FOREST STUDIO JSC.\n\n☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn\n☞ Email: info@forest-studio.vn\n©2018 Forest Studio JSC. All rights reserved', 'keywords': 'foreststudio buskingshow creativecontent xhtdrlx musicshow realityshow anhtuthevoice "FOREST STUDIO" "xuân hạ thu đông rồi lại xuân" xuanhathudongroilaixuan realityshow "hoa minzy" "anh tú" "đĩa than hồng" "chương trình thực tế" "eye contact live" "xuan ha thu dong roi lai xuan" ecl "healing music" xhtdrlx "mùi vị những chuyến đi" "mui vi nhung chuyen di" mvncd "anh tú voi bản đôn" "orange ong bây bi" "anh tu voi ban don" xhtdrlx2', 'unsubscribedTrailer': 'gWs3Xg3275w', 'country': 'VN'}, 'image': {'bannerExternalUrl': 'https://yt3.googleusercontent.com/8tpO7rVfiapTcWPi3ETJo1LnruGb6DZqP1s8Txel2Qxp6Qxx3v6ficv32Ha0OnKsuw8R-okVZV8'}}}

# %%
url = f"https://www.googleapis.com/youtube/v3/channels?part=topicDetails&id={CHANNEL_ID}&key={API_KEY}"
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    items = data.get('items', [])
    if items:
        channel_info = items[0]
        print(channel_info)
else:
    print("No channel found with this ID.")
# Out:
# {'kind': 'youtube#channel', 'etag': 'TQVbqvpRhF7uNr8PiZIgTOP07YQ', 'id': 'UCTOWyiIkPEqyh_2O-ArJR5w', 'topicDetails': {'topicIds': ['/m/064t9', '/m/04rlf', '/m/028sqc'], 'topicCategories': ['https://en.wikipedia.org/wiki/Pop_music', 'https://en.wikipedia.org/wiki/Music', 'https://en.wikipedia.org/wiki/Music_of_Asia']}}

# %%
url = f"https://www.googleapis.com/youtube/v3/channels?part=localizations&id={CHANNEL_ID}&key={API_KEY}"
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    items = data.get('items', [])
    if items:
        channel_info = items[0]
        print(channel_info)
else:
    print("No channel found with this ID.")
# Out:
# {'kind': 'youtube#channel', 'etag': '4I64XQnYY6-RYOi31O92jKCQ3BU', 'id': 'UCTOWyiIkPEqyh_2O-ArJR5w'}

# %%
url = f"https://www.googleapis.com/youtube/v3/channels?part=auditDetails&id={CHANNEL_ID}&key={API_KEY}"
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    items = data.get('items', [])
    if items:
        channel_info = items[0]
        print(channel_info)
else:
    print("No channel found with this ID.")
# Out:
# No channel found with this ID.

# %% [markdown]
# => Since I intereted with tiitle, description and statitics of channel, I will use Snippet, Statitics, topicDetails, contentDetails (for list of videos).
#
# ### How to crawl video of a channel?

# %%
from googleapiclient.discovery import build

playlist_id = 'UUTOWyiIkPEqyh_2O-ArJR5w'

youtube = build('youtube', 'v3', developerKey=API_KEY)

videos = []
next_page_token = None

while True:
    res = youtube.playlistItems().list(
        part='snippet',
        playlistId=playlist_id,
        maxResults=50,
        pageToken=next_page_token
    ).execute()

    for item in res['items']:
        video = {
            'title': item['snippet']['title'],
            'videoId': item['snippet']['resourceId']['videoId'],
            'publishedAt': item['snippet']['publishedAt'],
            'description': item['snippet']['description']
        }
        videos.append(video)

    next_page_token = res.get('nextPageToken')
    if not next_page_token:
        break

    break

print(f"Lấy được {len(videos)} video.")
# Out:
# Lấy được 50 video.

# %%
len(videos)
# Out:
# 50

# %%
for v in videos:
    print(f"{v['title']} - {v['videoId']} - {v['publishedAt']}")
    print(v['description'])
    print()
# Out:
# Running Man Vietnam 3: Trước giờ G, LIÊN BỈNH PHÁT nói gì? - 6Q5eNWzsm1A - 2025-06-12T14:30:11Z
# Running Man Vietnam 3: Trước giờ G, LIÊN BỈNH PHÁT nói gì?
# ---
# ⚡️ Góp mặt lần đầu vào năm 2010, RUNNING MAN nhanh chóng trở thành chương trình tạp kỹ hàng đầu Hàn Quốc. Cho đến nay, dù đã trải qua hơn một thập kỷ, chương trình vẫn luôn mang lại nhiều tiếng cười và là "thanh xuân" của hàng triệu khán giả trên toàn thế giới, trong đó có cả Việt Nam.
#
# ⚡️ Quay trở lại mùa 3 sau hơn 6 năm vắng bóng cùng tên gọi mới CHẠY NGAY ĐI - Khẩu lệnh bắt đầu đầy mãnh liệt và khao khát. Một cuộc đua mới đang âm thầm khởi động: Không chỉ hứa hẹn tràn ngập tiếng cười, mà ở đó còn ẩn chứa vô vàn điều bất ngờ đang chực chờ phía trước. Liệu tại nơi mà ai cũng phải hối hả chạy bởi vòng xoáy bất tận của cuộc đời. Bạn có chắc mình mới chính là người đang làm chủ cuộc chơi hay chỉ là những kẻ bị giật dây?
#
# ★ Đừng quên subscribe hệ thống YouTube của Forest Studio - RUNNING MAN VIETNAM 3 để xem NHANH & SỚM NHẤT: https://www.youtube.com/@RunningManVietnam3
#
# 💬 Và cập nhật các thông tin mới nhất của chương trình tại đây:
# ☛ Fanpage: https://www.facebook.com/runningmanvnss3
# ☛ TikTok: https://www.tiktok.com/@runningmanvnss3
# ☛ Instagram: https://www.instagram.com/runningmanvietnamseason3
# ☛ Threads: https://www.threads.com/@runningmanvietnamseason3
#
# #RunningManVietnam #RunningManVietnamSeason3 #ChayNgayDi
# #LienBinhPhat #ForestStudio #SBS #PrismStudio
# _______
# © Bản quyền thuộc về Forest Studio JSC.
# © Copyright by Forest Studio JSC.
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📺 Xem full top các chương trình đang thịnh hành & độc quyền của Forest Studio:
# ☛ Xuân Hạ Thu Đông, rồi lại Xuân: https://www.youtube.com/playlist?list=PLxNMBnO9F8FMtG4_3bKxsshIs4cpaii3F
# ☛ Mùi Vị Những Chuyến Đi: https://www.youtube.com/playlist?list=PLxNMBnO9F8FOkQAiqFyyheikQE7djqJ0P
# ☛ Eye Contact LIVE: https://www.youtube.com/watch?v=MXFvJLmarB8&list=PLxNMBnO9F8FPoR8sC4Yl_JczaeveDRpWa
#
# 📮 Contact us 👇🏻:
# ☛ Email: info@forest-studio.vn
# ☛ Website: https://forest-studio.vn
# ☛ Fanpage: https://www.facebook.com/forestudiovn
# ☛ Instagram: https://www.instagram.com/foreststudiovn
#
# Running Man Vietnam 3: Trước giờ G, TRẤN THÀNH nói gì? - 1tHSY5IguLU - 2025-06-12T13:30:02Z
# Running Man Vietnam 3: Trước giờ G, TRẤN THÀNH nói gì?
# ---
# ⚡️ Góp mặt lần đầu vào năm 2010, RUNNING MAN nhanh chóng trở thành chương trình tạp kỹ hàng đầu Hàn Quốc. Cho đến nay, dù đã trải qua hơn một thập kỷ, chương trình vẫn luôn mang lại nhiều tiếng cười và là "thanh xuân" của hàng triệu khán giả trên toàn thế giới, trong đó có cả Việt Nam.
#
# ⚡️ Quay trở lại mùa 3 sau hơn 6 năm vắng bóng cùng tên gọi mới CHẠY NGAY ĐI - Khẩu lệnh bắt đầu đầy mãnh liệt và khao khát. Một cuộc đua mới đang âm thầm khởi động: Không chỉ hứa hẹn tràn ngập tiếng cười, mà ở đó còn ẩn chứa vô vàn điều bất ngờ đang chực chờ phía trước. Liệu tại nơi mà ai cũng phải hối hả chạy bởi vòng xoáy bất tận của cuộc đời. Bạn có chắc mình mới chính là người đang làm chủ cuộc chơi hay chỉ là những kẻ bị giật dây?
#
# ★ Đừng quên subscribe hệ thống YouTube của Forest Studio - RUNNING MAN VIETNAM 3 để xem NHANH & SỚM NHẤT: https://www.youtube.com/@RunningManVietnam3
#
# 💬 Và cập nhật các thông tin mới nhất của chương trình tại đây:
# ☛ Fanpage: https://www.facebook.com/runningmanvnss3
# ☛ TikTok: https://www.tiktok.com/@runningmanvnss3
# ☛ Instagram: https://www.instagram.com/runningmanvietnamseason3
# ☛ Threads: https://www.threads.com/@runningmanvietnamseason3
#
# #RunningManVietnam #RunningManVietnamSeason3 #ChayNgayDi
# #TranThanh #ForestStudio #SBS #PrismStudio
# _______
# © Bản quyền thuộc về Forest Studio JSC.
# © Copyright by Forest Studio JSC.
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📺 Xem full top các chương trình đang thịnh hành & độc quyền của Forest Studio:
# ☛ Xuân Hạ Thu Đông, rồi lại Xuân: https://www.youtube.com/playlist?list=PLxNMBnO9F8FMtG4_3bKxsshIs4cpaii3F
# ☛ Mùi Vị Những Chuyến Đi: https://www.youtube.com/playlist?list=PLxNMBnO9F8FOkQAiqFyyheikQE7djqJ0P
# ☛ Eye Contact LIVE: https://www.youtube.com/watch?v=MXFvJLmarB8&list=PLxNMBnO9F8FPoR8sC4Yl_JczaeveDRpWa
#
# 📮 Contact us 👇🏻:
# ☛ Email: info@forest-studio.vn
# ☛ Website: https://forest-studio.vn
# ☛ Fanpage: https://www.facebook.com/forestudiovn
# ☛ Instagram: https://www.instagram.com/foreststudiovn
#
# ♪ Karaoke ♪ NƠI MÌNH DỪNG CHÂN - MIN | XHTDRLX3 - 5scQk3JZMNo - 2025-04-20T12:00:11Z
# ♪ Karaoke ♪ NƠI MÌNH DỪNG CHÂN - MIN | XHTDRLX3
# ❉ Ca khúc: Nơi Mình Dừng Chân
# ❉ Sáng tác: Khắc Hưng
# ❉ Trình bày: MIN
#
# 💿 Nghe trọn bản LIVE tại đây: https://youtu.be/jFWRBgvEC5c
# 💿 Xem FULL TẬP 5 tại đây: https://youtu.be/3cxHAhm0FJ4
# 💿 Tổng hợp những bản KARAOKE QUỐC DÂN: https://youtube.com/playlist?list=PLxNMBnO9F8FPu5cuvb7R4R4Fo-D9lB8r6&si=Oqc9t4_fcB6WD505
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #MIN #NoiMinhDungChan
# #ForestStudio #xuanhathudongroilaixuan #xhtdrlx #xhtđrlx #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
#
# ♪ Karaoke ♪ LỜI NÓI DỐI CHÂN THẬT - LÂM BẢO NGỌC x HOÀNG DŨNG | XHTDRLX3 - seSoIL6O-HU - 2025-04-19T12:01:35Z
# ♪ Karaoke ♪ LỜI NÓI DỐI CHÂN THẬT - LÂM BẢO NGỌC x HOÀNG DŨNG | XHTDRLX3
# ❉ Ca khúc: Lời Nói Dối Chân Thật.
# ❉ Sáng tác: Touliver.
# ❉ Trình bày: Lâm Bảo Ngọc, Hoàng Dũng.
#
# 💿 Nghe trọn bản LIVE tại đây: https://www.youtube.com/watch?v=cTYrJKRhjgg
# 💿 Xem FULL TẬP 3 tại đây: https://www.youtube.com/watch?v=HoSsSc6zCwA&t=16s
# 💿 Tổng hợp những bản KARAOKE QUỐC DÂN: https://youtube.com/playlist?list=PLxNMBnO9F8FPu5cuvb7R4R4Fo-D9lB8r6&si=Oqc9t4_fcB6WD505
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #LoiNoiDoiChanThat #HoangDung #LamBaoNgoc #Touliver
# #ForestStudio #xuanhathudongroilaixuan #xhtdrlx #xhtđrlx #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
#
# [NHÌN LẠI QUÃNG 2] XUÂN HẠ THU ĐÔNG RỒI LẠI XUÂN 3 | Lưu dấu những chặng đường đã qua - gWs3Xg3275w - 2025-03-29T13:30:07Z
# [NHÌN LẠI QUÃNG 2] XUÂN HẠ THU ĐÔNG RỒI LẠI XUÂN 3 | Lưu dấu những chặng đường đã qua
#
# 💌 Vượt qua hết thảy khó khăn nào phải nhờ phép màu. Vào giây phút chia tay, chúng ta mới cảm thấy trân trọng hành trình này biết bao.
#
# 🌸 Xem TRỌN BỘ TẬP FULL tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FMtG4_3bKxsshIs4cpaii3F&si=T113Wt09erCGo6UK
#
# 🎼 Xuân Hạ Thu Đông, rồi lại Xuân là một chương trình thực tế về âm nhạc lần đầu tiên tổ chức tại Việt Nam vào năm 2021, với mong muốn "lan toả âm nhạc chữa lành tâm hồn đến mọi nẻo đường, trên từng góc phố"
# 🌸 Sau 2 mùa nhận được nhiều sự yêu thương và đón nhận nồng nhiệt từ khán giả, Xuân Hạ Thu Đông, rồi lại Xuân chính thức quay trở lại với mùa mới (2024) với chủ đề Street's Harmony - Thanh âm những con phố. Chương trình hứa hẹn mang tới không chỉ những bản nhạc hay mà còn là lời nhắn nhủ: "Bốn mùa sẽ qua đi, mùa xuân rồi sẽ trở lại. Món quà cho những nỗ lực vượt qua mùa đông khó khăn sẽ là những ngày xuân tươi đẹp rạng rỡ."
#
# 💿 XUÂN HẠ THU ĐÔNG, RỒI LẠI XUÂN 3 được phát sóng định kỳ vào mỗi tối thứ 7 hàng tuần, lúc 20:00 trên kênh HTV7 và 20:30 trên kênh YouTube FOREST STUDIO.
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #BuiCongNam #AnhTu #LamBaoNgoc
# #ForestStudio #xuanhathudongroilaixuan #xhtdrlx #xhtđrlx #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# #Nhavanhoa #bunglenvantiecvui #vanmonngonbungvi
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
#
# [XHTDRLX3] Noo Phước Thịnh "DÍNH BẪY" trước thuyết âm mưu của Anh Tú | HẬU TRƯỜNG - BfWdQUejeY4 - 2025-03-28T15:38:52Z
# [XHTDRLX3] Noo Phước Thịnh "DÍNH BẪY" trước thuyết âm mưu của Anh Tú | HẬU TRƯỜNG
#
# 🌸 NGHE FULL BÀI HÁT tại đây: https://youtu.be/WOZ85j3DqGs?si=Zn4F21Krxl2bRP9B
#
# 🌸 Xem TRỌN BỘ TẬP FULL tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FMtG4_3bKxsshIs4cpaii3F&si=T113Wt09erCGo6UK
#
# 🎼 Xuân Hạ Thu Đông, rồi lại Xuân là một chương trình thực tế về âm nhạc lần đầu tiên tổ chức tại Việt Nam vào năm 2021, với mong muốn "lan toả âm nhạc chữa lành tâm hồn đến mọi nẻo đường, trên từng góc phố"
# 🌸 Sau 2 mùa nhận được nhiều sự yêu thương và đón nhận nồng nhiệt từ khán giả, Xuân Hạ Thu Đông, rồi lại Xuân chính thức quay trở lại với mùa mới (2024) với chủ đề Street's Harmony - Thanh âm những con phố. Chương trình hứa hẹn mang tới không chỉ những bản nhạc hay mà còn là lời nhắn nhủ: "Bốn mùa sẽ qua đi, mùa xuân rồi sẽ trở lại. Món quà cho những nỗ lực vượt qua mùa đông khó khăn sẽ là những ngày xuân tươi đẹp rạng rỡ."
#
# 💿 XUÂN HẠ THU ĐÔNG, RỒI LẠI XUÂN 3 được phát sóng định kỳ vào mỗi tối thứ 7 hàng tuần, lúc 20:00 trên kênh HTV7 và 20:30 trên kênh YouTube FOREST STUDIO.
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #NooPhuocThinh #BuiCongNam #AnhTu #LamBaoNgoc
# #ForestStudio #xuanhathudongroilaixuan #xhtdrlx #xhtđrlx #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
#
# Noo Phước Thịnh 9p bất lực, 1p nuông chiều khi Anh Tú sơ hở là thả thính | HẬU TRƯỜNG XHTDRLX3 - _TRDvhDIpaQ - 2025-03-26T05:00:23Z
# Noo Phước Thịnh 9 phần bất lực, 1 phần nuông chiều khi Anh Tú sơ hở là thả thính | HẬU TRƯỜNG XHTDRLX3
#
# 🌸 Xem TRỌN BỘ TẬP FULL tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FMtG4_3bKxsshIs4cpaii3F&si=T113Wt09erCGo6UK
#
# 🎼 Xuân Hạ Thu Đông, rồi lại Xuân là một chương trình thực tế về âm nhạc lần đầu tiên tổ chức tại Việt Nam vào năm 2021, với mong muốn "lan toả âm nhạc chữa lành tâm hồn đến mọi nẻo đường, trên từng góc phố"
# 🌸 Sau 2 mùa nhận được nhiều sự yêu thương và đón nhận nồng nhiệt từ khán giả, Xuân Hạ Thu Đông, rồi lại Xuân chính thức quay trở lại với mùa mới (2024) với chủ đề Street's Harmony - Thanh âm những con phố. Chương trình hứa hẹn mang tới không chỉ những bản nhạc hay mà còn là lời nhắn nhủ: "Bốn mùa sẽ qua đi, mùa xuân rồi sẽ trở lại. Món quà cho những nỗ lực vượt qua mùa đông khó khăn sẽ là những ngày xuân tươi đẹp rạng rỡ."
#
# 💿 XUÂN HẠ THU ĐÔNG, RỒI LẠI XUÂN 3 được phát sóng định kỳ vào mỗi tối thứ 7 hàng tuần, lúc 20:00 trên kênh HTV7 và 20:30 trên kênh YouTube FOREST STUDIO.
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #NooPhuocThinh #AnhTu #BuiCongNam #LamBaoNgoc
# #ForestStudio #xuanhathudongroilaixuan #xuanhathudong #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
#
# Anh Tú tái hiện lại Mạnh Mẽ Lên Cô Gái 😎 #xhtdrlx3 #anhtu #manhmelencogai #xuanhathudongroilaixuan3 - vEQYp8t9qo0 - 2025-03-24T14:01:15Z
# [XHTDRLX3] Mạnh Mẽ Lên Cô Gái - Anh Tú x Lâm Bảo Ngọc live tại Xuân Hạ Thu Đông, rồi lại Xuân 3
# ❉ Ca khúc: Mạnh Mẽ Lên Cô Gái.
# ❉ Sáng tác: Hùng Quân.
# ❉ Trình bày: Anh Tú x Lâm Bảo Ngọc.
#
# 🌸 NGHE TRỌN NHẠC tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FNC1Q7AG1GsLF5tLCUuDAkQ&si=ihRGX1D7nnDxF7kE
#
# 🌸 Xem TRỌN BỘ TẬP FULL tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FMtG4_3bKxsshIs4cpaii3F&si=T113Wt09erCGo6UK
#
# 🎼 Xuân Hạ Thu Đông, rồi lại Xuân là một chương trình thực tế về âm nhạc lần đầu tiên tổ chức tại Việt Nam vào năm 2021, với mong muốn "lan toả âm nhạc chữa lành tâm hồn đến mọi nẻo đường, trên từng góc phố"
# 🌸 Sau 2 mùa nhận được nhiều sự yêu thương và đón nhận nồng nhiệt từ khán giả, Xuân Hạ Thu Đông, rồi lại Xuân chính thức quay trở lại với mùa mới (2024) với chủ đề Street's Harmony - Thanh âm những con phố. Chương trình hứa hẹn mang tới không chỉ những bản nhạc hay mà còn là lời nhắn nhủ: "Bốn mùa sẽ qua đi, mùa xuân rồi sẽ trở lại. Món quà cho những nỗ lực vượt qua mùa đông khó khăn sẽ là những ngày xuân tươi đẹp rạng rỡ."
#
# 💿 XUÂN HẠ THU ĐÔNG, RỒI LẠI XUÂN 3 được phát sóng định kỳ vào mỗi tối thứ 7 hàng tuần, lúc 20:00 trên kênh HTV7 và 20:30 trên kênh YouTube FOREST STUDIO.
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #ManhMeLenCoGai #AnhTu #LamBaoNgoc
# #ForestStudio #xuanhathudongroilaixuan #xuanhathudong #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
#
# [XHTDRLX3] Mashup | Miền An Nhiên x Nhớ Mãi Chuyến Đi Này - Bùi Công Nam, Anh Tú, Lâm Bảo Ngọc - sfEYJrGh2YY - 2025-03-24T13:01:25Z
# [XHTDRLX3] Mashup | Miền An Nhiên x Nhớ Mãi Chuyến Đi Này - Bùi Công Nam, Anh Tú, Lâm Bảo Ngọc
# ❉ Mashup: Miền An Nhiên x Nhớ Mãi Chuyến Đi Này.
# ❉ Ca khúc: Nhớ Mãi Chuyến Đi Này. Sáng tác: Bùi Công Nam
# ❉ Ca khúc: Miền An Nhiên. Sáng tác: Phạm Minh Thành
# ❉ Trình bày: Bùi Công Nam, Anh Tú, Lâm Bảo Ngọc.
#
# 🌸 NGHE TRỌN NHẠC tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FNC1Q7AG1GsLF5tLCUuDAkQ&si=ihRGX1D7nnDxF7kE
#
# 🌸 Xem TRỌN BỘ TẬP FULL tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FMtG4_3bKxsshIs4cpaii3F&si=T113Wt09erCGo6UK
#
# 🎼 Xuân Hạ Thu Đông, rồi lại Xuân là một chương trình thực tế về âm nhạc lần đầu tiên tổ chức tại Việt Nam vào năm 2021, với mong muốn "lan toả âm nhạc chữa lành tâm hồn đến mọi nẻo đường, trên từng góc phố"
# 🌸 Sau 2 mùa nhận được nhiều sự yêu thương và đón nhận nồng nhiệt từ khán giả, Xuân Hạ Thu Đông, rồi lại Xuân chính thức quay trở lại với mùa mới (2024) với chủ đề Street's Harmony - Thanh âm những con phố. Chương trình hứa hẹn mang tới không chỉ những bản nhạc hay mà còn là lời nhắn nhủ: "Bốn mùa sẽ qua đi, mùa xuân rồi sẽ trở lại. Món quà cho những nỗ lực vượt qua mùa đông khó khăn sẽ là những ngày xuân tươi đẹp rạng rỡ."
#
# 💿 XUÂN HẠ THU ĐÔNG, RỒI LẠI XUÂN 3 được phát sóng định kỳ vào mỗi tối thứ 7 hàng tuần, lúc 20:00 trên kênh HTV7 và 20:30 trên kênh YouTube FOREST STUDIO.
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #NhoMaiChuyenDiNay #MienAnNhien #BuiCongNam #AnhTu #LamBaoNgoc
# #ForestStudio #xuanhathudongroilaixuan #xuanhathudong #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
#
# Nào cười lên em như chưa vấp ngã ~ #lambaongoc #anhtu #manhmelencogai #xhtdrlx3 - 1csuJDB3yhc - 2025-03-24T12:00:03Z
# [XHTDRLX3] Mạnh Mẽ Lên Cô Gái - Anh Tú x Lâm Bảo Ngọc live tại Xuân Hạ Thu Đông, rồi lại Xuân 3
# ❉ Ca khúc: Mạnh Mẽ Lên Cô Gái.
# ❉ Sáng tác: Hùng Quân.
# ❉ Trình bày: Anh Tú x Lâm Bảo Ngọc.
#
# 🌸 NGHE TRỌN NHẠC tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FNC1Q7AG1GsLF5tLCUuDAkQ&si=ihRGX1D7nnDxF7kE
#
# 🌸 Xem TRỌN BỘ TẬP FULL tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FMtG4_3bKxsshIs4cpaii3F&si=T113Wt09erCGo6UK
#
# 🎼 Xuân Hạ Thu Đông, rồi lại Xuân là một chương trình thực tế về âm nhạc lần đầu tiên tổ chức tại Việt Nam vào năm 2021, với mong muốn "lan toả âm nhạc chữa lành tâm hồn đến mọi nẻo đường, trên từng góc phố"
# 🌸 Sau 2 mùa nhận được nhiều sự yêu thương và đón nhận nồng nhiệt từ khán giả, Xuân Hạ Thu Đông, rồi lại Xuân chính thức quay trở lại với mùa mới (2024) với chủ đề Street's Harmony - Thanh âm những con phố. Chương trình hứa hẹn mang tới không chỉ những bản nhạc hay mà còn là lời nhắn nhủ: "Bốn mùa sẽ qua đi, mùa xuân rồi sẽ trở lại. Món quà cho những nỗ lực vượt qua mùa đông khó khăn sẽ là những ngày xuân tươi đẹp rạng rỡ."
#
# 💿 XUÂN HẠ THU ĐÔNG, RỒI LẠI XUÂN 3 được phát sóng định kỳ vào mỗi tối thứ 7 hàng tuần, lúc 20:00 trên kênh HTV7 và 20:30 trên kênh YouTube FOREST STUDIO.
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #ManhMeLenCoGai #AnhTu #LamBaoNgoc
# #ForestStudio #xuanhathudongroilaixuan #xuanhathudong #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
#
# [XHTDRLX3] Làm Ơn - Bùi Công Nam chìm đắm cảm xúc trong bản hoà âm cuối cùng - wIkVu3-ytpc - 2025-03-24T11:01:24Z
# [XHTDRLX3] Làm Ơn - Bùi Công Nam chìm đắm cảm xúc trong bản hoà âm cuối cùng
# ❉ Ca khúc: Làm Ơn.
# ❉ Sáng tác: Trần Trung Đức.
# ❉ Trình bày: Bùi Công Nam.
#
# 🌸 NGHE TRỌN NHẠC tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FNC1Q7AG1GsLF5tLCUuDAkQ&si=ihRGX1D7nnDxF7kE
#
# 🌸 Xem TRỌN BỘ TẬP FULL tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FMtG4_3bKxsshIs4cpaii3F&si=T113Wt09erCGo6UK
#
# 🎼 Xuân Hạ Thu Đông, rồi lại Xuân là một chương trình thực tế về âm nhạc lần đầu tiên tổ chức tại Việt Nam vào năm 2021, với mong muốn "lan toả âm nhạc chữa lành tâm hồn đến mọi nẻo đường, trên từng góc phố"
# 🌸 Sau 2 mùa nhận được nhiều sự yêu thương và đón nhận nồng nhiệt từ khán giả, Xuân Hạ Thu Đông, rồi lại Xuân chính thức quay trở lại với mùa mới (2024) với chủ đề Street's Harmony - Thanh âm những con phố. Chương trình hứa hẹn mang tới không chỉ những bản nhạc hay mà còn là lời nhắn nhủ: "Bốn mùa sẽ qua đi, mùa xuân rồi sẽ trở lại. Món quà cho những nỗ lực vượt qua mùa đông khó khăn sẽ là những ngày xuân tươi đẹp rạng rỡ."
#
# 💿 XUÂN HẠ THU ĐÔNG, RỒI LẠI XUÂN 3 được phát sóng định kỳ vào mỗi tối thứ 7 hàng tuần, lúc 20:00 trên kênh HTV7 và 20:30 trên kênh YouTube FOREST STUDIO.
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #LamOn #BuiCongNam
# #ForestStudio #xuanhathudongroilaixuan #xuanhathudong #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
#
# Người dân phát hiện 1 chàng chí phèo tại bờ sông Sài Gòn 🧐 #xhtdrlx3 #chipheo #buicongnam - rrulYV0GxEI - 2025-03-24T10:37:46Z
# [XHTDRLX3] Chí Phèo - Bùi Công Nam cùng Anh Tú tái hiện lại bản HIT đầu tay
# ❉ Ca khúc: Chí Phèo.
# ❉ Sáng tác: Bùi Công Nam.
# ❉ Trình bày: Bùi Công Nam, Anh Tú
#
# 🌸 NGHE TRỌN NHẠC tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FNC1Q7AG1GsLF5tLCUuDAkQ&si=ihRGX1D7nnDxF7kE
#
# 🌸 Xem TRỌN BỘ TẬP FULL tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FMtG4_3bKxsshIs4cpaii3F&si=T113Wt09erCGo6UK
#
# 🎼 Xuân Hạ Thu Đông, rồi lại Xuân là một chương trình thực tế về âm nhạc lần đầu tiên tổ chức tại Việt Nam vào năm 2021, với mong muốn "lan toả âm nhạc chữa lành tâm hồn đến mọi nẻo đường, trên từng góc phố"
# 🌸 Sau 2 mùa nhận được nhiều sự yêu thương và đón nhận nồng nhiệt từ khán giả, Xuân Hạ Thu Đông, rồi lại Xuân chính thức quay trở lại với mùa mới (2024) với chủ đề Street's Harmony - Thanh âm những con phố. Chương trình hứa hẹn mang tới không chỉ những bản nhạc hay mà còn là lời nhắn nhủ: "Bốn mùa sẽ qua đi, mùa xuân rồi sẽ trở lại. Món quà cho những nỗ lực vượt qua mùa đông khó khăn sẽ là những ngày xuân tươi đẹp rạng rỡ."
#
# 💿 XUÂN HẠ THU ĐÔNG, RỒI LẠI XUÂN 3 được phát sóng định kỳ vào mỗi tối thứ 7 hàng tuần, lúc 20:00 trên kênh HTV7 và 20:30 trên kênh YouTube FOREST STUDIO.
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #ChiPheo #BuiCongNam #AnhTu
# #ForestStudio #xuanhathudongroilaixuan #xuanhathudong #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
#
# [XHTDRLX3] Những Kẻ Mộng Mơ - Noo Phước Thịnh x Lâm Bảo Ngọc "tái sinh" ca khúc vạn người mê - vC9v-pbJRGE - 2025-03-24T05:00:49Z
# [XHTDRLX3] Những Kẻ Mộng Mơ - Noo Phước Thịnh x Lâm Bảo Ngọc "tái sinh" ca khúc vạn người mê
# ❉ Ca khúc: Những Kẻ Mộng Mơ.
# ❉ Sáng tác: Nguyễn Bảo Trọng.
# ❉ Trình bày: Noo Phước Thịnh, Lâm Bảo Ngọc.
#
# 🌸 NGHE TRỌN NHẠC tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FNC1Q7AG1GsLF5tLCUuDAkQ&si=ihRGX1D7nnDxF7kE
#
# 🌸 Xem TRỌN BỘ TẬP FULL tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FMtG4_3bKxsshIs4cpaii3F&si=T113Wt09erCGo6UK
#
# 🎼 Xuân Hạ Thu Đông, rồi lại Xuân là một chương trình thực tế về âm nhạc lần đầu tiên tổ chức tại Việt Nam vào năm 2021, với mong muốn "lan toả âm nhạc chữa lành tâm hồn đến mọi nẻo đường, trên từng góc phố"
# 🌸 Sau 2 mùa nhận được nhiều sự yêu thương và đón nhận nồng nhiệt từ khán giả, Xuân Hạ Thu Đông, rồi lại Xuân chính thức quay trở lại với mùa mới (2024) với chủ đề Street's Harmony - Thanh âm những con phố. Chương trình hứa hẹn mang tới không chỉ những bản nhạc hay mà còn là lời nhắn nhủ: "Bốn mùa sẽ qua đi, mùa xuân rồi sẽ trở lại. Món quà cho những nỗ lực vượt qua mùa đông khó khăn sẽ là những ngày xuân tươi đẹp rạng rỡ."
#
# 💿 XUÂN HẠ THU ĐÔNG, RỒI LẠI XUÂN 3 được phát sóng định kỳ vào mỗi tối thứ 7 hàng tuần, lúc 20:00 trên kênh HTV7 và 20:30 trên kênh YouTube FOREST STUDIO.
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #NhungKeMongMo #NooPhuocThinh #LamBaoNgoc
# #ForestStudio #xuanhathudongroilaixuan #xuanhathudong #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
#
# [XHTDRLX3] Ánh Sao Và Bầu Trời - Noo Phước Thịnh thổi làn gió mới vào bản HIT của T.R.I x Cá - MOYRrs_Mv20 - 2025-03-23T04:30:11Z
# [XHTDRLX3] Ánh Sao Và Bầu Trời - Noo Phước Thịnh thổi làn gió mới vào bản HIT của T.R.I x Cá
# ❉ Ca khúc: Ánh Sao Và Bầu Trời.
# ❉ Sáng tác: T.R.I, Cá.
# ❉ Trình bày: Noo Phước Thịnh.
#
# 🌸 NGHE TRỌN NHẠC tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FNC1Q7AG1GsLF5tLCUuDAkQ&si=ihRGX1D7nnDxF7kE
#
# 🌸 Xem TRỌN BỘ TẬP FULL tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FMtG4_3bKxsshIs4cpaii3F&si=T113Wt09erCGo6UK
#
# 🎼 Xuân Hạ Thu Đông, rồi lại Xuân là một chương trình thực tế về âm nhạc lần đầu tiên tổ chức tại Việt Nam vào năm 2021, với mong muốn "lan toả âm nhạc chữa lành tâm hồn đến mọi nẻo đường, trên từng góc phố"
# 🌸 Sau 2 mùa nhận được nhiều sự yêu thương và đón nhận nồng nhiệt từ khán giả, Xuân Hạ Thu Đông, rồi lại Xuân chính thức quay trở lại với mùa mới (2024) với chủ đề Street's Harmony - Thanh âm những con phố. Chương trình hứa hẹn mang tới không chỉ những bản nhạc hay mà còn là lời nhắn nhủ: "Bốn mùa sẽ qua đi, mùa xuân rồi sẽ trở lại. Món quà cho những nỗ lực vượt qua mùa đông khó khăn sẽ là những ngày xuân tươi đẹp rạng rỡ."
#
# 💿 XUÂN HẠ THU ĐÔNG, RỒI LẠI XUÂN 3 được phát sóng định kỳ vào mỗi tối thứ 7 hàng tuần, lúc 20:00 trên kênh HTV7 và 20:30 trên kênh YouTube FOREST STUDIO.
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #AnhSaoVaBauTroi #NooPhuocThinh
# #ForestStudio #xuanhathudongroilaixuan #xuanhathudong #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
#
# [XHTDRLX3] Xa Em - Anh Tú tự tin khoe giọng hát trước chính chủ Noo Phước Thịnh - CmeEAAmWABA - 2025-03-23T03:00:11Z
# [XHTDRLX3] Xa Em - Anh Tú tự tin khoe giọng hát trước chính chủ Noo Phước Thịnh
# ❉ Ca khúc: Xa Em.
# ❉ Sáng tác: Nguyễn Đức Tùng.
# ❉ Trình bày: Anh Tú.
#
# 🌸 NGHE TRỌN NHẠC tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FNC1Q7AG1GsLF5tLCUuDAkQ&si=ihRGX1D7nnDxF7kE
#
# 🌸 Xem TRỌN BỘ TẬP FULL tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FMtG4_3bKxsshIs4cpaii3F&si=T113Wt09erCGo6UK
#
# 🎼 Xuân Hạ Thu Đông, rồi lại Xuân là một chương trình thực tế về âm nhạc lần đầu tiên tổ chức tại Việt Nam vào năm 2021, với mong muốn "lan toả âm nhạc chữa lành tâm hồn đến mọi nẻo đường, trên từng góc phố"
# 🌸 Sau 2 mùa nhận được nhiều sự yêu thương và đón nhận nồng nhiệt từ khán giả, Xuân Hạ Thu Đông, rồi lại Xuân chính thức quay trở lại với mùa mới (2024) với chủ đề Street's Harmony - Thanh âm những con phố. Chương trình hứa hẹn mang tới không chỉ những bản nhạc hay mà còn là lời nhắn nhủ: "Bốn mùa sẽ qua đi, mùa xuân rồi sẽ trở lại. Món quà cho những nỗ lực vượt qua mùa đông khó khăn sẽ là những ngày xuân tươi đẹp rạng rỡ."
#
# 💿 XUÂN HẠ THU ĐÔNG, RỒI LẠI XUÂN 3 được phát sóng định kỳ vào mỗi tối thứ 7 hàng tuần, lúc 20:00 trên kênh HTV7 và 20:30 trên kênh YouTube FOREST STUDIO.
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #XaEm #AnhTu
# #ForestStudio #xuanhathudongroilaixuan #xuanhathudong #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
#
# [XHTDRLX3] Mashup | Mưa Rơi Lặng Thầm x Lặng Thầm - Noo Phước Thịnh, Anh Tú, Bùi Công Nam - eTj1xh4N8tI - 2025-03-22T14:30:18Z
# [XHTDRLX3] Mashup | Mưa Rơi Lặng Thầm x Lặng Thầm - Noo Phước Thịnh, Anh Tú, Bùi Công Nam
# ❉ Mashup: Mưa Rơi Lặng Thầm x Lặng Thầm.
# ❉ Ca khúc: Mưa Rơi Lặng Thầm. Sáng tác: Lê Việt Khánh.
# ❉ Ca khúc: Lặng Thầm. Sáng tác: Nguyễn Hoàng Duy.
# ❉ Trình bày: Noo Phước Thịnh, Anh Tú, Bùi Công Nam.
#
# 🌸 NGHE TRỌN NHẠC tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FNC1Q7AG1GsLF5tLCUuDAkQ&si=ihRGX1D7nnDxF7kE
#
# 🌸 Xem TRỌN BỘ TẬP FULL tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FMtG4_3bKxsshIs4cpaii3F&si=T113Wt09erCGo6UK
#
# 🎼 Xuân Hạ Thu Đông, rồi lại Xuân là một chương trình thực tế về âm nhạc lần đầu tiên tổ chức tại Việt Nam vào năm 2021, với mong muốn "lan toả âm nhạc chữa lành tâm hồn đến mọi nẻo đường, trên từng góc phố"
# 🌸 Sau 2 mùa nhận được nhiều sự yêu thương và đón nhận nồng nhiệt từ khán giả, Xuân Hạ Thu Đông, rồi lại Xuân chính thức quay trở lại với mùa mới (2024) với chủ đề Street's Harmony - Thanh âm những con phố. Chương trình hứa hẹn mang tới không chỉ những bản nhạc hay mà còn là lời nhắn nhủ: "Bốn mùa sẽ qua đi, mùa xuân rồi sẽ trở lại. Món quà cho những nỗ lực vượt qua mùa đông khó khăn sẽ là những ngày xuân tươi đẹp rạng rỡ."
#
# 💿 XUÂN HẠ THU ĐÔNG, RỒI LẠI XUÂN 3 được phát sóng định kỳ vào mỗi tối thứ 7 hàng tuần, lúc 20:00 trên kênh HTV7 và 20:30 trên kênh YouTube FOREST STUDIO.
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #MuaRoiLangTham #LangTham #NooPhuocThinh #AnhTu #BuiCongNam
# #ForestStudio #xuanhathudongroilaixuan #xuanhathudong #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
#
# [FULL TẬP 16] XUÂN HẠ THU ĐÔNG RỒI LẠI XUÂN 3 | Khép lại hành trình "Street's Harmony" đáng nhớ - Qirh20c6u-s - 2025-03-22T13:30:07Z
# [FULL TẬP 16] XUÂN HẠ THU ĐÔNG RỒI LẠI XUÂN 3 | Khép lại hành trình "Street's Harmony" đáng nhớ
#
# Bốn mùa rồi sẽ qua đi, mùa Xuân rồi sẽ trở lại. Cảm ơn vì đã là một phần thật đẹp của Bản hoà âm Xuân Hạ Thu Đông, rồi lại Xuân mùa 3 💗
#
# 🌸 Xem TRỌN BỘ TẬP FULL tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FMtG4_3bKxsshIs4cpaii3F&si=T113Wt09erCGo6UK
#
# 00:00 Mở đầu
# 00:34 Giây phút chia tay
# 06:09 Mashup | Mưa Rơi Lặng Thầm x Lặng Thầm - Noo Phước Thịnh, Anh Tú, Bùi Công Nam
# 11:04 Highlight bài hát | Bản hoà âm số 08: Bản hoà âm Xuân Hạ Thu Đông
# 13:01 Tập luyện | Ánh Sao Và Bầu Trời
# 17:09 Ánh Sao Và Bầu Trời - Noo Phước Thịnh
# 22:46 Xa Em - Anh Tú
# 30:15 Tập luyện | Những Kẻ Mộng Mơ
# 33:26 Những Kẻ Mộng Mơ - Noo Phước Thịnh x Lâm Bảo Ngọc
# 40:20 Làm Ơn - Bùi Công Nam
# 45:22 Mashup | Miền An Nhiên x Nhớ Mãi Chuyến Đi Này - Nhóm Xuân Hạ Thu Đông
# 52:58 Nhớ Mãi Chuyến Đi Này - Hẹn gặp lại ~
#
# 🎼 Xuân Hạ Thu Đông, rồi lại Xuân là một chương trình thực tế về âm nhạc lần đầu tiên tổ chức tại Việt Nam vào năm 2021, với mong muốn "lan toả âm nhạc chữa lành tâm hồn đến mọi nẻo đường, trên từng góc phố"
# 🌸 Sau 2 mùa nhận được nhiều sự yêu thương và đón nhận nồng nhiệt từ khán giả, Xuân Hạ Thu Đông, rồi lại Xuân chính thức quay trở lại với mùa mới (2024) với chủ đề Street's Harmony - Thanh âm những con phố. Chương trình hứa hẹn mang tới không chỉ những bản nhạc hay mà còn là lời nhắn nhủ: "Bốn mùa sẽ qua đi, mùa xuân rồi sẽ trở lại. Món quà cho những nỗ lực vượt qua mùa đông khó khăn sẽ là những ngày xuân tươi đẹp rạng rỡ."
#
# 💿 XUÂN HẠ THU ĐÔNG, RỒI LẠI XUÂN 3 được phát sóng định kỳ vào mỗi tối thứ 7 hàng tuần, lúc 20:00 trên kênh HTV7 và 20:30 trên kênh YouTube FOREST STUDIO.
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #NooPhuocThinh #AnhTu #BuiCongNam #LamBaoNgoc
# #ForestStudio #xuanhathudongroilaixuan #xuanhathudong #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# #Nhavanhoa #bunglenvantiecvui #vanmonngonbungvi
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
#
# 😍 Một ca khúc mới Noo Phước Thịnh mang đến Xuân Hạ Thu Đông rồi lại Xuân 3 #xhtdrlx3 #noophuocthinh - Dh-qwUiD3L4 - 2025-03-22T05:30:04Z
# [XHTDRLX3] Thương - Noo Phước Thịnh mang ca khúc mới đến "sân khấu chữa lành"
# ❉ Ca khúc: Thương.
# ❉ Sáng tác: Mộc.
# ❉ Trình bày: Noo Phước Thịnh.
#
# 🌸 NGHE TRỌN NHẠC tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FNC1Q7AG1GsLF5tLCUuDAkQ&si=ihRGX1D7nnDxF7kE
#
# 🌸 Xem TRỌN BỘ TẬP FULL tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FMtG4_3bKxsshIs4cpaii3F&si=T113Wt09erCGo6UK
#
# 🎼 Xuân Hạ Thu Đông, rồi lại Xuân là một chương trình thực tế về âm nhạc lần đầu tiên tổ chức tại Việt Nam vào năm 2021, với mong muốn "lan toả âm nhạc chữa lành tâm hồn đến mọi nẻo đường, trên từng góc phố"
# 🌸 Sau 2 mùa nhận được nhiều sự yêu thương và đón nhận nồng nhiệt từ khán giả, Xuân Hạ Thu Đông, rồi lại Xuân chính thức quay trở lại với mùa mới (2024) với chủ đề Street's Harmony - Thanh âm những con phố. Chương trình hứa hẹn mang tới không chỉ những bản nhạc hay mà còn là lời nhắn nhủ: "Bốn mùa sẽ qua đi, mùa xuân rồi sẽ trở lại. Món quà cho những nỗ lực vượt qua mùa đông khó khăn sẽ là những ngày xuân tươi đẹp rạng rỡ."
#
# 💿 XUÂN HẠ THU ĐÔNG, RỒI LẠI XUÂN 3 được phát sóng định kỳ vào mỗi tối thứ 7 hàng tuần, lúc 20:00 trên kênh HTV7 và 20:30 trên kênh YouTube FOREST STUDIO.
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #Thuong #NooPhuocThinh
# #ForestStudio #xuanhathudongroilaixuan #xuanhathudong #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
#
# Chí Phèo ngoài đời thật đây sao?! 💥 #buicongnam #xhtdrlx3 #chipheo #xuanhathudongroilaixuan3 - PZssq7jjeLo - 2025-03-22T04:00:17Z
# [XHTDRLX3] Chí Phèo - Bùi Công Nam cùng Anh Tú tái hiện lại bản HIT đầu tay
# ❉ Ca khúc: Chí Phèo.
# ❉ Sáng tác: Bùi Công Nam.
# ❉ Trình bày: Bùi Công Nam, Anh Tú
#
# 🌸 NGHE TRỌN NHẠC tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FNC1Q7AG1GsLF5tLCUuDAkQ&si=ihRGX1D7nnDxF7kE
#
# 🌸 Xem TRỌN BỘ TẬP FULL tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FMtG4_3bKxsshIs4cpaii3F&si=T113Wt09erCGo6UK
#
# 🎼 Xuân Hạ Thu Đông, rồi lại Xuân là một chương trình thực tế về âm nhạc lần đầu tiên tổ chức tại Việt Nam vào năm 2021, với mong muốn "lan toả âm nhạc chữa lành tâm hồn đến mọi nẻo đường, trên từng góc phố"
# 🌸 Sau 2 mùa nhận được nhiều sự yêu thương và đón nhận nồng nhiệt từ khán giả, Xuân Hạ Thu Đông, rồi lại Xuân chính thức quay trở lại với mùa mới (2024) với chủ đề Street's Harmony - Thanh âm những con phố. Chương trình hứa hẹn mang tới không chỉ những bản nhạc hay mà còn là lời nhắn nhủ: "Bốn mùa sẽ qua đi, mùa xuân rồi sẽ trở lại. Món quà cho những nỗ lực vượt qua mùa đông khó khăn sẽ là những ngày xuân tươi đẹp rạng rỡ."
#
# 💿 XUÂN HẠ THU ĐÔNG, RỒI LẠI XUÂN 3 được phát sóng định kỳ vào mỗi tối thứ 7 hàng tuần, lúc 20:00 trên kênh HTV7 và 20:30 trên kênh YouTube FOREST STUDIO.
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #ChiPheo #BuiCongNam #AnhTu
# #ForestStudio #xuanhathudongroilaixuan #xuanhathudong #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
#
# Nếu yêu ai cũng buồn đến thế, thì Noo đã không... #xhtdrlx3 #xuanhathudongroilaixuan3 #noophuocthinh - mg9vA_Wtj0U - 2025-03-21T13:01:12Z
# [XHTDRLX3] Yêu Một Người Sao Buồn Đến Thế - Noo Phước Thịnh, Anh Tú “over hợp” trong lần đầu kết hợp
# ❉ Ca khúc: Yêu Một Người Sao Buồn Đến Thế.
# ❉ Sáng tác: Nguyễn Minh Cường.
# ❉ Trình bày: Noo Phước Thịnh, Anh Tú.
#
# 🌸 NGHE TRỌN NHẠC tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FNC1Q7AG1GsLF5tLCUuDAkQ&si=ihRGX1D7nnDxF7kE
#
# 🌸 Xem TRỌN BỘ TẬP FULL tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FMtG4_3bKxsshIs4cpaii3F&si=T113Wt09erCGo6UK
#
# 🎼 Xuân Hạ Thu Đông, rồi lại Xuân là một chương trình thực tế về âm nhạc lần đầu tiên tổ chức tại Việt Nam vào năm 2021, với mong muốn "lan toả âm nhạc chữa lành tâm hồn đến mọi nẻo đường, trên từng góc phố"
# 🌸 Sau 2 mùa nhận được nhiều sự yêu thương và đón nhận nồng nhiệt từ khán giả, Xuân Hạ Thu Đông, rồi lại Xuân chính thức quay trở lại với mùa mới (2024) với chủ đề Street's Harmony - Thanh âm những con phố. Chương trình hứa hẹn mang tới không chỉ những bản nhạc hay mà còn là lời nhắn nhủ: "Bốn mùa sẽ qua đi, mùa xuân rồi sẽ trở lại. Món quà cho những nỗ lực vượt qua mùa đông khó khăn sẽ là những ngày xuân tươi đẹp rạng rỡ."
#
# 💿 XUÂN HẠ THU ĐÔNG, RỒI LẠI XUÂN 3 được phát sóng định kỳ vào mỗi tối thứ 7 hàng tuần, lúc 20:00 trên kênh HTV7 và 20:30 trên kênh YouTube FOREST STUDIO.
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #YeuMotNguoiSaoBuonDenThe #NooPhuocThinh #AnhTu
# #ForestStudio #xuanhathudongroilaixuan #xuanhathudong #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
#
# ...
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #BuiCongNam #AnhTu #LamBaoNgoc #HuongTram
# #ForestStudio #xuanhathudongroilaixuan #xuanhathudong #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
#
# 😍 Ngồi Hát Đỡ Buồn cùng nhóm Xuân Hạ Thu Đông #xhtdrlx3 #xuanhathudongroilaixuan3 #buicongnam - GfkFPF2b5IY - 2025-03-04T13:00:22Z
# [XHTDRLX3] Ngồi Hát Đỡ Buồn - Bùi Công Nam, Anh Tú, Lâm Bảo Ngọc
# ❉ Ca khúc: Ngồi Hát Đỡ Buồn.
# ❉ Sáng tác: Nguyễn Hải Phong.
# ❉ Trình bày: Bùi Công Nam, Anh Tú, Lâm Bảo Ngọc.
#
# 🌸 NGHE TRỌN NHẠC tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FNC1Q7AG1GsLF5tLCUuDAkQ&si=ihRGX1D7nnDxF7kE
#
# 🌸 Xem TRỌN BỘ TẬP FULL tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FMtG4_3bKxsshIs4cpaii3F&si=T113Wt09erCGo6UK
#
# 🎼 Xuân Hạ Thu Đông, rồi lại Xuân là một chương trình thực tế về âm nhạc lần đầu tiên tổ chức tại Việt Nam vào năm 2021, với mong muốn "lan toả âm nhạc chữa lành tâm hồn đến mọi nẻo đường, trên từng góc phố"
# 🌸 Sau 2 mùa nhận được nhiều sự yêu thương và đón nhận nồng nhiệt từ khán giả, Xuân Hạ Thu Đông, rồi lại Xuân chính thức quay trở lại với mùa mới (2024) với chủ đề Street's Harmony - Thanh âm những con phố. Chương trình hứa hẹn mang tới không chỉ những bản nhạc hay mà còn là lời nhắn nhủ: "Bốn mùa sẽ qua đi, mùa xuân rồi sẽ trở lại. Món quà cho những nỗ lực vượt qua mùa đông khó khăn sẽ là những ngày xuân tươi đẹp rạng rỡ."
#
# 💿 XUÂN HẠ THU ĐÔNG, RỒI LẠI XUÂN 3 được phát sóng định kỳ vào mỗi tối thứ 7 hàng tuần, lúc 20:00 trên kênh HTV7 và 20:30 trên kênh YouTube FOREST STUDIO.
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #NgoiHatDoBuon #BuiCongNam #AnhTu #LamBaoNgoc
# #ForestStudio #xuanhathudongroilaixuan #xhtdrlx #xhtđrlx #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
#
# 💥 Hương Tràm trở lại với Em Gái Mưa phiên bản Anh - Việt #xhtdrlx3 #huongtram #emgaimua - CBByOKAyCwc - 2025-03-04T11:00:26Z
# [XHTDRLX3] Em Gái Mưa - Hương Tràm tái xuất với phiên bản Anh - Việt của bản HIT một thời
# ❉ Ca khúc: Em Gái Mưa.
# ❉ Sáng tác: Mr. Siro.
# ❉ Trình bày: Hương Tràm.
#
# 🌸 NGHE TRỌN NHẠC tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FNC1Q7AG1GsLF5tLCUuDAkQ&si=ihRGX1D7nnDxF7kE
#
# 🌸 Xem TRỌN BỘ TẬP FULL tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FMtG4_3bKxsshIs4cpaii3F&si=T113Wt09erCGo6UK
#
# 🎼 Xuân Hạ Thu Đông, rồi lại Xuân là một chương trình thực tế về âm nhạc lần đầu tiên tổ chức tại Việt Nam vào năm 2021, với mong muốn "lan toả âm nhạc chữa lành tâm hồn đến mọi nẻo đường, trên từng góc phố"
# 🌸 Sau 2 mùa nhận được nhiều sự yêu thương và đón nhận nồng nhiệt từ khán giả, Xuân Hạ Thu Đông, rồi lại Xuân chính thức quay trở lại với mùa mới (2024) với chủ đề Street's Harmony - Thanh âm những con phố. Chương trình hứa hẹn mang tới không chỉ những bản nhạc hay mà còn là lời nhắn nhủ: "Bốn mùa sẽ qua đi, mùa xuân rồi sẽ trở lại. Món quà cho những nỗ lực vượt qua mùa đông khó khăn sẽ là những ngày xuân tươi đẹp rạng rỡ."
#
# 💿 XUÂN HẠ THU ĐÔNG, RỒI LẠI XUÂN 3 được phát sóng định kỳ vào mỗi tối thứ 7 hàng tuần, lúc 20:00 trên kênh HTV7 và 20:30 trên kênh YouTube FOREST STUDIO.
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #EmGaiMua #HuongTram
# #ForestStudio #xuanhathudongroilaixuan #xhtdrlx #xhtđrlx #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
#
# Lâm Bảo Ngọc hé lộ ca khúc mới tại Xuân Hạ Thu Đông, rồi lại Xuân 3 #imsorry #ForestStudio #xhtdrlx3 - QIYe4RhnFf0 - 2025-03-04T05:16:58Z
# [XHTDRLX3] I'm Sorry - Lâm Bảo Ngọc da diết với ca khúc mới tại Xuân Hạ Thu Đông, rồi lại Xuân 3
# ❉ Ca khúc: I'm Sorry.
# ❉ Sáng tác: Sync Project, Noh JiHoon, Bò.
# ❉ Trình bày: Lâm Bảo Ngọc.
#
# 🌸 NGHE TRỌN NHẠC tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FNC1Q7AG1GsLF5tLCUuDAkQ&si=ihRGX1D7nnDxF7kE
#
# 🌸 Xem TRỌN BỘ TẬP FULL tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FMtG4_3bKxsshIs4cpaii3F&si=T113Wt09erCGo6UK
#
# 🎼 Xuân Hạ Thu Đông, rồi lại Xuân là một chương trình thực tế về âm nhạc lần đầu tiên tổ chức tại Việt Nam vào năm 2021, với mong muốn "lan toả âm nhạc chữa lành tâm hồn đến mọi nẻo đường, trên từng góc phố"
# 🌸 Sau 2 mùa nhận được nhiều sự yêu thương và đón nhận nồng nhiệt từ khán giả, Xuân Hạ Thu Đông, rồi lại Xuân chính thức quay trở lại với mùa mới (2024) với chủ đề Street's Harmony - Thanh âm những con phố. Chương trình hứa hẹn mang tới không chỉ những bản nhạc hay mà còn là lời nhắn nhủ: "Bốn mùa sẽ qua đi, mùa xuân rồi sẽ trở lại. Món quà cho những nỗ lực vượt qua mùa đông khó khăn sẽ là những ngày xuân tươi đẹp rạng rỡ."
#
# 💿 XUÂN HẠ THU ĐÔNG, RỒI LẠI XUÂN 3 được phát sóng định kỳ vào mỗi tối thứ 7 hàng tuần, lúc 20:00 trên kênh HTV7 và 20:30 trên kênh YouTube FOREST STUDIO.
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #ImSorry #LamBaoNgoc
# #ForestStudio #xuanhathudongroilaixuan #xhtdrlx #xhtđrlx #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
#
# [XHTDRLX3] Em Gái Mưa - Hương Tràm tái xuất với phiên bản Anh - Việt của bản HIT một thời - ebGCYvl3gSQ - 2025-03-03T03:30:19Z
# [XHTDRLX3] Em Gái Mưa - Hương Tràm tái xuất với phiên bản Anh - Việt của bản HIT một thời
# ❉ Ca khúc: Em Gái Mưa.
# ❉ Sáng tác: Mr. Siro.
# ❉ Trình bày: Hương Tràm.
#
# 🌸 NGHE TRỌN NHẠC tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FNC1Q7AG1GsLF5tLCUuDAkQ&si=ihRGX1D7nnDxF7kE
#
# 🌸 Xem TRỌN BỘ TẬP FULL tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FMtG4_3bKxsshIs4cpaii3F&si=T113Wt09erCGo6UK
#
# 🎼 Xuân Hạ Thu Đông, rồi lại Xuân là một chương trình thực tế về âm nhạc lần đầu tiên tổ chức tại Việt Nam vào năm 2021, với mong muốn "lan toả âm nhạc chữa lành tâm hồn đến mọi nẻo đường, trên từng góc phố"
# 🌸 Sau 2 mùa nhận được nhiều sự yêu thương và đón nhận nồng nhiệt từ khán giả, Xuân Hạ Thu Đông, rồi lại Xuân chính thức quay trở lại với mùa mới (2024) với chủ đề Street's Harmony - Thanh âm những con phố. Chương trình hứa hẹn mang tới không chỉ những bản nhạc hay mà còn là lời nhắn nhủ: "Bốn mùa sẽ qua đi, mùa xuân rồi sẽ trở lại. Món quà cho những nỗ lực vượt qua mùa đông khó khăn sẽ là những ngày xuân tươi đẹp rạng rỡ."
#
# 💿 XUÂN HẠ THU ĐÔNG, RỒI LẠI XUÂN 3 được phát sóng định kỳ vào mỗi tối thứ 7 hàng tuần, lúc 20:00 trên kênh HTV7 và 20:30 trên kênh YouTube FOREST STUDIO.
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #EmGaiMua #HuongTram
# #ForestStudio #xuanhathudongroilaixuan #xhtdrlx #xhtđrlx #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
#
# [XHTDRLX3] I'm Sorry - Lâm Bảo Ngọc da diết với ca khúc mới tại Xuân Hạ Thu Đông, rồi lại Xuân 3 - 5dYD4OT2t0c - 2025-03-02T13:00:06Z
# [XHTDRLX3] I'm Sorry - Lâm Bảo Ngọc da diết với ca khúc mới tại Xuân Hạ Thu Đông, rồi lại Xuân 3
# ❉ Ca khúc: I'm Sorry.
# ❉ Sáng tác: Sync Project, Noh JiHoon, Bò.
# ❉ Trình bày: Lâm Bảo Ngọc.
#
# 🌸 NGHE TRỌN NHẠC tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FNC1Q7AG1GsLF5tLCUuDAkQ&si=ihRGX1D7nnDxF7kE
#
# 🌸 Xem TRỌN BỘ TẬP FULL tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FMtG4_3bKxsshIs4cpaii3F&si=T113Wt09erCGo6UK
#
# 🎼 Xuân Hạ Thu Đông, rồi lại Xuân là một chương trình thực tế về âm nhạc lần đầu tiên tổ chức tại Việt Nam vào năm 2021, với mong muốn "lan toả âm nhạc chữa lành tâm hồn đến mọi nẻo đường, trên từng góc phố"
# 🌸 Sau 2 mùa nhận được nhiều sự yêu thương và đón nhận nồng nhiệt từ khán giả, Xuân Hạ Thu Đông, rồi lại Xuân chính thức quay trở lại với mùa mới (2024) với chủ đề Street's Harmony - Thanh âm những con phố. Chương trình hứa hẹn mang tới không chỉ những bản nhạc hay mà còn là lời nhắn nhủ: "Bốn mùa sẽ qua đi, mùa xuân rồi sẽ trở lại. Món quà cho những nỗ lực vượt qua mùa đông khó khăn sẽ là những ngày xuân tươi đẹp rạng rỡ."
#
# 💿 XUÂN HẠ THU ĐÔNG, RỒI LẠI XUÂN 3 được phát sóng định kỳ vào mỗi tối thứ 7 hàng tuần, lúc 20:00 trên kênh HTV7 và 20:30 trên kênh YouTube FOREST STUDIO.
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #ImSorry #LamBaoNgoc
# #ForestStudio #xuanhathudongroilaixuan #xhtdrlx #xhtđrlx #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
#
# [XHTDRLX3] Mashup | Xe Đạp x Có Bao Giờ - Bùi Công Nam, Anh Tú, Lâm Bảo Ngọc kết hợp siêu cuốn - 8yRVy61054Y - 2025-03-02T05:58:49Z
# [XHTDRLX3] Mashup | Xe Đạp x Có Bao Giờ - Bùi Công Nam, Anh Tú, Lâm Bảo Ngọc kết hợp siêu cuốn
# ❉ Mashup: Xe Đạp x Có Bao Giờ.
# ❉ Sáng tác: MINAKO KAWAE, Lê Hà Nguyên.
# ❉ Trình bày: Bùi Công Nam, Anh Tú, Lâm Bảo Ngọc.
#
# 🌸 NGHE TRỌN NHẠC tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FNC1Q7AG1GsLF5tLCUuDAkQ&si=ihRGX1D7nnDxF7kE
#
# 🌸 Xem TRỌN BỘ TẬP FULL tại đây: https://youtube.com/playlist?list=PLxNMBnO9F8FMtG4_3bKxsshIs4cpaii3F&si=T113Wt09erCGo6UK
#
# 🎼 Xuân Hạ Thu Đông, rồi lại Xuân là một chương trình thực tế về âm nhạc lần đầu tiên tổ chức tại Việt Nam vào năm 2021, với mong muốn "lan toả âm nhạc chữa lành tâm hồn đến mọi nẻo đường, trên từng góc phố"
# 🌸 Sau 2 mùa nhận được nhiều sự yêu thương và đón nhận nồng nhiệt từ khán giả, Xuân Hạ Thu Đông, rồi lại Xuân chính thức quay trở lại với mùa mới (2024) với chủ đề Street's Harmony - Thanh âm những con phố. Chương trình hứa hẹn mang tới không chỉ những bản nhạc hay mà còn là lời nhắn nhủ: "Bốn mùa sẽ qua đi, mùa xuân rồi sẽ trở lại. Món quà cho những nỗ lực vượt qua mùa đông khó khăn sẽ là những ngày xuân tươi đẹp rạng rỡ."
#
# 💿 XUÂN HẠ THU ĐÔNG, RỒI LẠI XUÂN 3 được phát sóng định kỳ vào mỗi tối thứ 7 hàng tuần, lúc 20:00 trên kênh HTV7 và 20:30 trên kênh YouTube FOREST STUDIO.
#
# 💬 Cập nhật thông tin chương trình tại Fanpage: https://www.facebook.com/roilaixuan
#
# #xuanhathudongroilaixuan3 #XeDap #CoBaoGio #BuiCongNam #AnhTu #LamBaoNgoc
# #ForestStudio #xuanhathudongroilaixuan #xhtdrlx #xhtđrlx #xhtdrlx3 #xhtđrlx3
# #streetsharmony #musicshow #busking #realityshow
# _______
# © Bản quyền thuộc về Forest Studio JSC
# © Copyright by Forest Studio JSC
#
# 🚫 Bất cứ hình thức Re-upload nào đều bị vi phạm.
# 🚫 Vui lòng không đăng tải video reaction khi chưa có sự đồng ý từ Forest Studio.
#
# 🚫 Any forms of re-upload are not permitted.
# 🚫 Please DO NOT post any Reaction Videos without permissions from Forest Studio.
#
# 🚫 포레스트 스튜디오의 콘텐츠의 저작권은 포레스트 스튜디오에 있습니다.
# 포레스트 스튜디오의 동의없이 재업로드, 재가공 등의 행위는 법적으로 금지되어 있습니다.
#
# 📣 Đừng quên subscribe để xem nhiều video mới nhất và hay nhất nhé!
# 🎈 YouTube: https://www.youtube.com/c/FORESTSTUDIOO​
#
# More about Forest Studio
# ☞ Facebook Forest Studio: https://www.facebook.com/forestudiovn
#
# More about Mùi Vị Những Chuyến Đi
# ☞ Facebook MVNCD: https://www.facebook.com/muivinhungchuyendi
#
# More about EYE Contact LIVE
# ☞ Facebook ECL: https://www.facebook.com/@eyecontact.live/
#
# Contact us:
# info@forest-studio.vn
